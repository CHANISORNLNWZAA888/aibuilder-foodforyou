# %% [markdown]
# โค้ดนี้จะเป็นการแก้เรื่องเมนูอาหารที่ขึ้น Total calories for เส้นใหญ่ผัดซีอิ๊วไก่: 0

# %%
import pandas as pd
import json
from google.colab import drive
from IPython.display import display
from difflib import get_close_matches

# %%
recipe_file_path = "เมนูไม่มีจุดแล้ว.csv"
recipe_data = pd.read_csv(recipe_file_path, nrows = 3)

nutrition_file_path = "ingredientdnewnew.csv"
nutrition_data = pd.read_csv(nutrition_file_path)

# %%
import pandas as pd

# Load the CSV
df = pd.read_csv("recipe_original.csv")

dish_list = [
    "แกงเขียวหวาน", "แกงส้ม", "แกงไตปลา", "แกงเลียง", "แกงมัสมั่น", "แกงเทโพ",
    "แกงจืดตำลึงหมูสับ", "แกงจืดวุ้นเส้นหมูสับ", "ขนมจีนน้ำยา", "ขนมผักกาด", "ขนมปังหน้าหมู",
    "ขนมครก", "ข้าวหมูแดง ไมโครเวฟ", "ข้าวมันไก่", "ข้าวหน้าเป็ด", "ข้าวผัดหมู", "ข้าวผัดปู",
    "ข้าวผัดน้ำพริกลงเรือ", "ข้าวเหนียวหมูปิ้ง", "ข้าวเหนียวไก่ย่าง", "ข้าวยำปักษ์ใต้",
    "ข้าวต้มหมู", "ข้าวแช่", "ข้าวซอย", "ข้าวราดแกง", "ไข่เจียวหมูสับ", "ไข่ดาวทรงเครื่อง",
    "ไข่กระทะ", "คั่วกลิ้งหมู", "ก๋วยเตี๋ยวคั่วไก่", "ไก่ทอดหาดใหญ่", "ไก่อบโอ่ง", "ไก่ผัดเม็ดมะม่วงหิมพานต์",
    "กะเพราเนื้อ", "กะเพราหมูสับ", "กะเพรากุ้ง", "กะเพราทะเล", "กะเพราไก่ไข่ดาว", "ฉู่ฉี่กุ้ง",
    "ฉู่ฉี่ปลา", "ต้มแซ่บกระดูกหมูอ่อน", "ต้มยำกุ้ง", "ทอดมันกุ้ง", "น้ำพริกกะปิ", "น้ำพริกปลาทู",
    "บัวลอยไข่หวาน", "ปลานึ่งซีอิ๊ว", "ปลาย่างเกลือ", "ปลาหมึกนึ่งมะนาว", "ปลาหมึกผัดไข่เค็ม",
    "ปลาเผา", "ปลาแดดเดียวทอด", "ปูหลน", "ผัดไทยกุ้งสด", "ผัดเปรี้ยวหวาน", "ผัดซีอิ๊ว",
    "ผัดกะเพราหมูกรอบ", "ผัดผักรวมมิตร", "ผัดยอดมะระน้ำมันหอย", "ผัดเผ็ดหมูป่า",
    "ผัดเผ็ดปลาดุก", "ผัดเผ็ดไก่", "ผัดฟักทองใส่ไข่", "ผัดพริกแกงถั่วหมูกรอบ", "ผัดพริกแกงหมู",
    "ผัดคะน้าหมูกรอบ", "ผัดถั่วงอกเต้าหู้", "ผัดหน่อไม้ใส่ไข่", "พะโล้ไข่พะโล้", "เย็นตาโฟ",
    "ยำวุ้นเส้น", "ยำปลากระป๋อง", "ยำปลาทู", "ยำปูม้า", "ยำหมูยอ", "ยำแหนมข้าวทอด",
    "ราดหน้าหมู", "ราดหน้าทะเล", "ราดหน้าเนื้อ", "ลาบไก่", "ลาบเนื้อ", "ส้มตำไทย",
    "ส้มตำปูปลาร้า", "ส้มตำไทยไข่เค็ม", "ส้มตำปูม้า", "สะเต๊ะหมู", "สะเต๊ะไก่", "สุกี้แห้ง",
    "สุกี้น้ำ", "หมูกรอบผัดพริกแกง", "หมูแดดเดียว", "หมูย่างน้ำตก", "ห่อหมกปลากราย",
    "หอยลายผัดพริกเผา", "หอยแมลงภู่ทอด", "หอยทอด", "เต้าหู้น้ำแดง", "ไก่ทอดกระเทียม",
    "หมูผัดพริกหยวก", "เนื้อผัดน้ำมันหอย", "ผัดขี้เมาทะเล", "ผัดผักบุ้งไฟแดง", "ยำสามกรอบ",
    "ข้าวไข่ข้นหมูสับ"
]

matched = df[df["ชื่ออาหาร"].str.contains('|'.join(dish_list), na=False)]


for _, row in matched.iterrows():
    dish = row['ชื่ออาหาร']
    ingredients = str(row['วัตถุดิบ']).strip().replace('"', '\\"').replace('\n', '\\n')
    print(f"{{\n    'ชื่ออาหาร': '{dish}',")
    print(f"    'ingredient_full_json': \"\\\"{ingredients}\\\"\"\n}},")
# Out:
# {
#     'ชื่ออาหาร': 'ก๋วยเตี๋ยวคั่วไก่ แบบง่าย',
#     'ingredient_full_json': "\"เส้นใหญ่300กรัม\nไข่ไก่2 ฟอง\nซีอิ๊วขาว2 ช้อนโต๊ะ\nน้ำตาล2 ช้อนชา\nเกลือ 1/2 ช้อนชา1/2 ช้อนชา\nต้นหอม ผักชีซอย1 ช้อนโต๊ะ\nน้ำมันพืชหรือน้ำมันหมูเล็กน้อย\n--เครื่องปรุงหมักไก่--\nอกไก่หั่นชิ้นพอคำ200 กรัม\nน้ำตาลทราย1 ช้อนชา\nแป้งมัน1 ช้อนโต๊ะ\nพริกไทย1/2 ช้อนชา\""
# },
# {
#     'ชื่ออาหาร': 'ขนมจีนน้ำยากะทิตีนไก่',
#     'ingredient_full_json': "\"เนื้อไก่บดละเอียด3 ขีด\nน้ำกะทิคั้นครึ่งโล\nพริกแกงเผ็ด2 ขีด\nกระชาย1 หัว\nใบมะกรูด4-5 ใบ\nตีนไก่1 โล\nเลือดไก่1 ก้อน\nลูกชิ้นปลาครึ่งโล\nน้ำตาลทรายแดง3 ช้อนโต๊ะ\nเกลือ1 ช้อนโต๊ะ\nรสดี1 ช้อนโต๊ะ\nขนมจีน1 โล\nผักเคียงตามชอบ\""
# },
# {
#     'ชื่ออาหาร': 'ก๋วยเตี๋ยวคั่วไก่ แบบง่าย แต่อร่อย',
# ...

# %% [markdown]
# เมนูอาหารที่ขึ้นแต่ไม่สามารถคำณวนได้ โดยจะดึงเมนูออกจากไฟล์ recipe_original และจัดอยู่ใน format อีกที

# %%
print(f"Total matched recipes: {matched.shape[0]}")
# Out:
# Total matched recipes: 133

# %% [markdown]
# นำมาใส่สารอาหาร เมนูไหนขึ้น 0 จะมาบวกมือเอง

# %%
import pandas as pd
from difflib import get_close_matches

nutrition_data = pd.read_csv("ingredientdnewnew.csv")

new_recipe_data=[{
    'ชื่ออาหาร': 'ก๋วยเตี๋ยวคั่วไก่ แบบง่าย',
    'ingredient_full_json': "\"เส้นใหญ่300กรัม\nไข่ไก่2 ฟอง\nซีอิ๊วขาว2 ช้อนโต๊ะ\nน้ำตาล2 ช้อนชา\nเกลือ 1/2 ช้อนชา1/2 ช้อนชา\nต้นหอม ผักชีซอย1 ช้อนโต๊ะ\nน้ำมันพืชหรือน้ำมันหมูเล็กน้อย\n--เครื่องปรุงหมักไก่--\nอกไก่หั่นชิ้นพอคำ200 กรัม\nน้ำตาลทราย1 ช้อนชา\nแป้งมัน1 ช้อนโต๊ะ\nพริกไทย1/2 ช้อนชา\""
},
{
    'ชื่ออาหาร': 'ข้าวหมูแดง ไมโครเวฟ',
    'ingredient_full_json': "\"สันในหมู 400 กรัม\nน้ำมันงา 1 ช้อนโต๊ะ\nซอสหอยนางรม 1 ช้อนโต๊ะ\nซีอิ๊วขาว 1 ช้อนโต๊ะ\nผงหมักหมูแดง 4 ช้อนโต๊ะ\nน้ำผึ้ง 1 ช้อนโต๊ะ\nเหล้าจีน 1 ช้อนโต๊ะ\nน้ำเปล่า 1 ถ้วยตวง\nรากผักชี กระเทียม พริกไทย โขลก 2 ช้อนโต๊ะ\nแป้งข้าวโพด 1 ช้อนโต๊ะ\""
},
{
    'ชื่ออาหาร': 'ข้าวไข่ข้นกุ้ง',
    'ingredient_full_json': "\"ไข่ไก่ 3 ฟอง\nกุ้งสด 5 ตัว\nเห็ดหอม 3 ดอก\nนมสด 3 ช้อนโต๊ะ\nซีอี๊วขาว 1 ช้อนชา\nน้ำมันหอย 1 ช้อนชา\nซอสปรุงรส 1 ช้อนชา\nน้ำมัน 1 ช้อนชา\nข้าวสวย 1 ถ้วย\nพาร์สลีย์ สำหรับตกแต่ง\""
},
{
    'ชื่ออาหาร': 'แกงเขียวหวานไก่ ไมโครเวฟ',
    'ingredient_full_json': "\"กะทิสำเร็จรูป 1 กล่อง\nน้ำพริกแกงเขียวหวาน 2 ช้อนโต๊ะ\nน้ำ 1/2 ถ้วย\nน้ำปลา 1 ช้อนโต๊ะ\nน้ำตาลปี๊บ 1 ช้อนโต๊ะ\nเนื้อไก่ หั่นเป็นชิ้น 200 กรัม\nมะเขือเปราะ หั่นสี่ส่วน 4 ลูก\nใบมะกรูดฉีก 3 ใบ\nใบโหระพา 1 ถ้วย\nพริกชี้ฟ้าแดงซอย 1 เม็ด\""
},
{
    'ชื่ออาหาร': 'แกงจืดเต้าหู้หมูสับ',
    'ingredient_full_json': "\"หมูสับปรุงรส 100 กรัม\n\n2. เต้าหู้ไข่ 1 หลอด\n\n3. น้ำซุปเข้มข้น 3 ช้อนโต๊ะ\n\n4. ผักกาดขาว หั่นชิ้น 200 กรัม\n\n5. แครอท หั่นแว่น 100 กรัม\n\n6. ขึ้นฉ่าย หั่นเป็นท่อน 1 ต้น\n\n7. ซีอิ๊วขาว 1 ช้อนโต๊ะ\n\n8. น้ำตาลทราย ½ ช้อนชา\n\n9. ผักชีซอย สำหรับโรยหน้า\n\n10. ต้นหอมซอย สำหรับโรยหน้า\n\nวัตถุดิบหมูสับปรุงรส\n1. หมูสับ 100 กรัม\n\n2. กระเทียม 1 ช้อนโต๊ะ\n\n3. รากผักชี หั่นหยาบ 3 ราก\n\n4. เกลือป่น ½ ช้อนชา\n\n5. น้ำมันหอย 1 ช้อนโต๊ะ\""
},
{
    'ชื่ออาหาร': 'ต้มยำกุ้งน้ำข้นยอดมะพร้าว',
    'ingredient_full_json': "\"กุ้งสด 400 กรัม\nเห็ดตามชอบ 100 กรัม\nมะเขือเทศ 4 ลูก\nพริกขี้หนู 10 เม็ด\nใบมะกรูด 3-4 ใบ\nตะไคร้ 1 ก้าน\nยอดมะพร้าว 120 กรัม\nข่าหั่นแว่น 4 ชิ้น\nมะนาว 2 ลูก\nน้ำพริกเผา 4 ช้อนโต๊ะ\nนมข้นจืด 100 กรัม\nน้ำปลา 2 ช้อนโต๊ะ\nน้ำเปล่า 1 ลิตร\nผักชีฝรั่ง ตามชอบ\""
},
{
    'ชื่ออาหาร': 'แกงเลียงกุ้งสด',
    'ingredient_full_json': "\"\""
},
{
    'ชื่ออาหาร': 'แกงเลียงกุ้งสด',
    'ingredient_full_json': "\"กุ้งสดปอกเปลือกผ่าหลัง250กรัม\nข้าวโพดอ่อนหั่น80กรัม\nฟักทองหั่นชิ้นพอดีคำ240กรัม\nบวบหั่นเป็นชิ้นๆ230กรัม\nเห็ดรวม (ตามชอบ)250กรัม\nใบแมงลัก1ถ้วย\nน้ำซุป4ถ้วย\nน้ำปลา2ช้อนโต๊ะ\nซีอิ๊วขาว1ช้อนโต๊ะ\nน้ำตาล1ช้อนชา\n---พริกแกงเลียง--\nหอมแดง6หัว\nกุ้งแห้งป่น3ช้อนโต๊ะ\nกุ้งสดลวก3ตัว\nกระชาย3แง่ง\nพริกไทยเม็ด1ช้อนโต๊ะ\nกะปิ1 1/2ช้อนโต๊ะ\nพริกขี้หนูสวน8เม็ด\nรากผักชี1ราก\""
},
{
    'ชื่ออาหาร': 'แกงเหลือง',
    'ingredient_full_json': "\"ปลากะพง 1 ตัว\nมะละกอดิบ 1 ลูก\nพริกแห้ง 15 เม็ด\nพริกขี้หนู 15 เม็ด\nกระเทียม 5 กลีบ\nขมิ้นสด 2 แง่ง\nหอมแดง 2 หัว\nข่า 2 ช้อนโต๊ะ\nเกลือ 1 ช้อนชา\nกะปิ 1 ช้อนโต๊ะ\nน้ำมะขามเปียก 2 ช้อนโต๊ะ\nมะนาว 1 ลูก\""
},
{
    'ชื่ออาหาร': 'แกงเลียงกุ้งสด',
    'ingredient_full_json': "\"กุ้งสดปอกเปลือกผ่าหลัง: 250กรัม\nข้าวโพดอ่อนหั่น: 80กรัม\nฟักทองหั่นชิ้นพอดีคำ: 240กรัม\nบวบหั่นเป็นชิ้นๆ: 230กรัม\nเห็ดรวม (ตามชอบ): 250กรัม\nใบแมงลัก: 1ถ้วย\nน้ำซุป: 4ถ้วย\nน้ำปลา: 2ช้อนโต๊ะ\nซีอิ๊วขาว: 1ช้อนโต๊ะ\nน้ำตาล: 1ช้อนชา\n---พริกแกงเลียง--: \nหอมแดง: 6หัว\nกุ้งแห้งป่น: 3ช้อนโต๊ะ\nกุ้งสดลวก: 3ตัว\nกระชาย: 3แง่ง\nพริกไทยเม็ด: 1ช้อนโต๊ะ\nกะปิ: 1 1/2ช้อนโต๊ะ\nพริกขี้หนูสวน: 8เม็ด\nรากผักชี: 1ราก\""
},
{
    'ชื่ออาหาร': 'ปลานึ่งมะนาว',
    'ingredient_full_json': "\"ปลา ตามชอบ ปลากะพง ปลาทับทิม ปลานิล ฯลฯ: 1ตัว\nน้ำปลา: 2 ช้อนโต๊ะ\nมะนาว (ชิมตามความเปรี้ยว): 3-4 ช้อนโต๊ะ\nน้ำตาล: 1 ช้อนชา\nพริกขี้หนูสับ: 2 ช้อนโต๊ะ\nกระเทียมสับ: 2 ช้อนโต๊ะ\nผักชี: 1ต้น\nตะไคร้: ครึ่งต้น\""
},
{
    'ชื่ออาหาร': 'มาม่าผัดขี้เมาทะเล',
    'ingredient_full_json': "\"กุ้ง เนื้อปลา ปลาหมึก: ไม่ต้องเยอะมากอะ กะเอาเอง\nมาม่าบิ๊กแพ๊ครสต้มยำ: 1 ซอง\nใบโหระพา: \nเม็ดพริกไทย: \nไข่ไก่: \nพริกขี้หนูสด: \nกระเทียม: \nซีอิ๊วดำ:\""
},
{
    'ชื่ออาหาร': 'แกงเขียวหวานหมู (มือใหม่หัดแกง)',
    'ingredient_full_json': "\"เนื้อหมู: 1 Kg\nพริกแกงเขียวหวาน: 2 ขีด\nหัวกะทิ: 500 ml\nใบโหระพา: \nมะเขือเปราะ: \nมะเขือพวง: \nพริกชี้ฟ้า: \nใบมะกรูด: \nน้ำตาลมะพร้าว: \nน้ำปลา: \nน้ำมันพืช:\""
},
{
    'ชื่ออาหาร': 'แกงป่า',
    'ingredient_full_json': "\"เนื้อไก่: 200 g\nพริกไทย: ตามชอบ\nพริกแดง: ตามชอบ\nผงปรุงรส: 1 Tbs\nพริกแกง: 20 g\nใบกะเพรา: 1กำมือ\nมะเขือเปาะ: 7ผล\nมะเขือพวง: 2พวง\nกระชาย: ตามชอบ\nถั่งฝักยาว: 2ฝัก\nน้ำตาล: เล็กน้อย\""
},
{
    'ชื่ออาหาร': 'แกงส้มปลากระพงผักรวม (แกงส้มปักษ์ใต้)',
    'ingredient_full_json': "\"ปลากระพง(ประมาณ1กิโล): 1ตัว\nพริกแกงเหลือง: 3-4ช้อนโต๊ะ\nผักตามชอบ(มะละกอ แครอท ถั่วฟักยาว: ตามชอบ\nส้มแขก: 4-5ชิ้น\nน้ำปลา: 3-4ช้อนโต๊ะ\nน้ำตาล: 2-3ช้อนโต๊ะ\""
},
{
    'ชื่ออาหาร': 'ต้มยำกุ้งน้ำใส',
    'ingredient_full_json': "\"กุ้งไซส์กลาง-ใหญ่ 6 ตัว: \nเห็ดฟาง 200 กรัม: \nข่าหั่นเป็นชิ้นบางๆ 15 ชิ้น: \nตะไคร้ 3 ต้น: \nใบมะกรูด 5 ใบ: \nหอมแดง 5 หัว: \nพริกขี้หนูสวน 10 เม็ด: \nคนอร์ขวดซอสข้นปรุงรส 2 ช้อนโต๊ะ: \nมะนาว 6 ช้อนโต๊ะ: \nน้ำปลา 2 ช้อนโต๊ะ:\""
},
{
    'ชื่ออาหาร': 'แกงส้มใต้',
    'ingredient_full_json': "\"มะละกอ: 1 ลูก\nปลาทับทิม: 1 ตัว\nน้ำพริกแกงส้มใต้: 1 ซอง\nน้ำมะขามเปียก: 5 ช้อนโต๊ะ\nน้ำปลา: 3 ช้อนโต๊ะ\nเกลือ: 1 ช้อนชา\nน้ำตาลปีบ: 1 ช้อนโต๊ะ\""
},
{
    'ชื่ออาหาร': 'ปลาเผาผักสด/เมี่ยงปลาเผา/ปลานิลเผาเกลือ แบบใช้เตาอบ',
    'ingredient_full_json': "\"ปลา: 1 ตัว\nเกลือป่น: 250 กรัม\nแป้งสาลีเอนกประสงค์หรือแป้งมัน: 1 ช้อนโต๊ะ\nตะไคร้: 2ต้น\nใบเตย: 2 ใบ\nผักแกล้มผักต่างๆตามชอบ: \nซีฟู้ดกุ้ง,ปลาหมึก ตามชอบ: \nเส้นหมี่ ตามชอบ:\""
},
{
    'ชื่ออาหาร': 'น้ำพริกกะปิสูตรคุณยาย',
    'ingredient_full_json': "\"กะปิ: 1 ทัพพี\nน้ำตาลปี๊บ: 1 ทัพพี\nพริกสด: 1 กำมือ\nกระเทียม: 1 กำมือ\nมะเขือพวง: 1/2 ถ้วย\nน้ำมะนาวคั้นสด: 1 ทัพพี\nน้ำเปล่า: 1 ทัพพี\""
},
{
    'ชื่ออาหาร': 'แกงเขียวหวานไก่',
    'ingredient_full_json': "\"น้ำพริกแกงเขียวหวาน(สำเร็จรูป): \nกะทิ (กล่องใหญ่1 กล่อง+กล่องเล็กสุด 1 กล่อง): \nไก่สด+เครื่องใน: \nเลือดไก่(ก้อน): \nมะเขือเปราะ: \nมะเขือพวง: \nใบโหระพา: \nพริกชีฟ้าสีแดง: \nพริกขี้หนูสด: \nน้ำตาล:\""
},
{
    'ชื่ออาหาร': 'แกงส้มมะละกอปลากระป๋อง',
    'ingredient_full_json': "\"มะละกอออกสีแต้มๆ ลูกกลางๆ: 1ลูก\nปลากระป๋อง: 1กระป๋อง\nน้ำตาลปี๊บ: 2ทัพพี\nน้ำส้มมะขาม ตามความชอบ: 1ทัพพี\nน้ำปลา แล้วแต่ชอบ: \nน้ำเปล่า: 2ถ้วยตวง\nพริกแกงส้ม: 1ทัพพี\nผักชี:\""
},
{
    'ชื่ออาหาร': 'พริกแกงเหลือง (แกงส้มใต้)',
    'ingredient_full_json': "\"พริกจินดาแห้ง(ใช้พริกขี้หนูสดได้): 30 เม็ด\nกระเทียมไทย: 30 กลีบ\nขมิ้นยาว 2 นิ้ว: 1 ชิ้น\nกะปิ: 1 ช้อนโต๊ะ\nเกลือ: 1 ช้อนชา\""
},
{
    'ชื่ออาหาร': 'น้ำพริกกะปิสูตรอร่อยเด็ด',
    'ingredient_full_json': "\"กระเทียม: 1 ช้อนโต๊ะ\nกะปิ: 1 ช้อนโต๊ะ\nน้ำตาลปี๊บ: 1/2 ช้อนโต๊ะ\nพริกขี้หนูสวน: 20 เม็ด\nมะเขือพวง: 1 ช้อนโต๊ะ\nน้ำมะนาวคั้นสด: 4 1/2 ช้อนโต๊ะ\""
},
{
    'ชื่ออาหาร': 'แกงส้มชะอมกุ้งพริกแกงใต้',
    'ingredient_full_json': "\"กุ้ง: 5 ขีด\nชะอม: 1 กำ\nพริกแกงส้มใต้: 2-3 ช้อน\nไข่ไก่: 4 ฟอง\nน้ำตาลปีบ: 1-2 ช้อน\nน้ำปลา: ตามรสชาติที่ชอบ\nน้ำมัน: 1 ถ้วย\nน้ำมะขามเปียก: ตามรสชาติที่ชอบ\""
},
{
    'ชื่ออาหาร': 'ยำปลากระป๋องแบบบ้าน',
    'ingredient_full_json': "\"ปลากระป๋อง: 3 กระป๋อง\nหอมแดงซอย: 2 ช้อนโต๊ะ\nพริกขี้หนู: 2 กรัม\nมะนาว: 2 ลูก\""
},
{
    'ชื่ออาหาร': 'น้ำพริกกะปิ ปลาทูทอด',
    'ingredient_full_json': "\"น้ำพริกกะปิ: \nกระเทียม: 4 กลีบใหญ่\nพริก: 6 เม็ด\nน้ำตาลแว่น/น้ำตาลมะพร้าว: 1.5 แว่น\nกะปิอย่างดี: 1 ช้อนพูนๆ\nมะนาว: 1.5 ลูกเล็ก\nผักต้ม: \nถั่วฝักยาว: 5 ต้น\nผักบุ้ง: 4 ต้น\nน้ำเปล่า: สำหรับลวก\nน้ำเย็นจัด: สำหรับแช่ผัก\nปลาทูทอด: \nปลาทูขนาดกลาง: 2 ตัว\nน้ำมันปาล์ม: 1 ถ้วย\""
},
{
    'ชื่ออาหาร': 'แกงเขียวหวานไก่ใส่ฟัก',
    'ingredient_full_json': "\"สะโพกไก่: 2 ชิ้น\nฟักแก่: 3 ขีด\nตีนไก่: 2 ขีด\nพริกแกงเขียวหวาน: 1.5 ขีด\nกระทิสด: 1 โล\nมะเขือ: 3-4 ลูก\nใบโหระพา: 1 กำเล็ก\nพริกชี้ฟ้า: 4-5 เม็ด\nน้ำปลา: 2 ช้อน\nน้ำตาลปีบ: 1/2 ช้อน\nมะเขือพวง: 1 ขีด\""
},
{
    'ชื่ออาหาร': 'ไข่เจียวหมูสับหน้ากรอบ',
    'ingredient_full_json': "\"เนื้อหมูสับ: 2-3ขีด\nไข่ไก่: 5 ฟอง\nน้ำปลา: ตามชอบ\nซอสหอยนางรม: ตามชอบ\nน้ำตาล: ตามชอบ\""
},
{
    'ชื่ออาหาร': 'เทคนิค กะเพราหมูสับ แบบแห้ง อร่อยกว่าร้าน',
    'ingredient_full_json': "\"หมูสับ: 1 ถ้วย\nพริกเขียว + กระเทียม สับ: 1 ถ้วย\nใบกะเพรา: 2-3 ต้น\nซีอิ๊วขาว: 2-3 ช้อนชา\nน้ำปลา: 1 ช้อนชา\nพริกไทย: 2-3 เหยาะ\""
},
{
    'ชื่ออาหาร': 'แกงเขียวหวานไก่ผัดแห้ง',
    'ingredient_full_json': "\"เนื้อไก่หั่นเป็นชิ้น: 140 กรัม\nมะเขือเปราะหั่น: 200 กรัม\nมะเขือพวง: 2 ช้อนโต๊ะ\nพริกแดงหั่นแฉลบ: 4 เม็ด\nใบโหระพา: 1 ถ้วย\nพริกแกงเขียวหวาน: 2 ช้อนโต๊ะ\nน้ำตาลปี๊บ: 1 /2ช้อนโต๊ะ\nใบมะกรูดฉีก: 4-5ใบ\nนมข้นจืด.: 6 ช้อนโต๊ะ\nน้ำมันพืช.: เล็กน้อย\nน้ำเปล่า: เล็กน้อย\""
},
{
    'ชื่ออาหาร': 'ขนมจีนน้ำยาปลาทู',
    'ingredient_full_json': "\"ปลาทูนึงแกะเอาแต่เนื้อ: 2 ตัว\nน้ำพริกแกงเผ็ดใต้: 100 กรัม\nกะทิ: 250 กรัม\nลูกชิ้นปลา: 6-7 ลูก\nกระชาย ล้างให้สะอาด ตำให้ละเอียด: 100 กรัม\nขนมจีน: \nผักเครื่องเคียงตามชอบ: \nน้ำตาลมะพร้าว: 2 ช้อนโต๊ะ\nน้ำปลา: 2 ช้อนโต๊ะ\""
},
{
    'ชื่ออาหาร': 'แกงส้มปลาหน่อไม้ดอง',
    'ingredient_full_json': "\"ปลาทับทิม: 1 ตัว\nเครื่องแกงส้ม: 1 ขีด\nหน่อไม้ดอง: 1/2 กก.\nกะปิ: 1 ช้อนพูน\nน้ำตาลมะพร้าว: 1 ช้อนโต๊ะ\nเกลือ: 1 ช้อนชา\nน้ำปลา: 1 ช้อนโต๊ะ\nน้ำมะขามเปียก: 1 ถ้วย\nมะนาว: 1.5 ลูก\""
},
{
    'ชื่ออาหาร': 'พริกแกงมัสมั่น​',
    'ingredient_full_json': "\"เม็ดผักชีคั่วป่น: 1+1/2 ช้อนชา\nเม็ดยี่หร่าคั่วป่น: 1/2 ช้อนชา\nเม็ดกระวานคั่วป่น​ (แกะเอาเฉพาะเม็ดที่อยู่ด้านใน)​: 4 เม็ด\nกานพลูคั่วป่น: 4 ดอก\nลูกจันทน์​คั่วป่น: 1 ลูก\nดอกจันทน์​คั่วป่น: 1 ดอก\nอบเชยท่อน​ 1 นิ้ว​ คั่วป่น: 1 ท่อน\nพริกชี้ฟ้าแช่น้ำซับแห้ง: 10 เม็ด\nเกลือสมุทร​: 1 ช้อนชา\nข่าแก่หั่นละเอียด: 1 ช้อนโต๊ะ​\nตะไคร้หั่นละเอียด: 2 ต้น\nผิวมะกรูด: 1 ช้อนชา\nกระเทียม​ไทย: 20​ กลีบ\nหอมแดง: 5 หัว\nกะปิห่อใบตองย่างจนหอม: 1 ช้อนชา\nพริกไทยขาวเม็ดคั่วป่น: 1/2 ช้อนชา\""
},
{
    'ชื่ออาหาร': 'ขนมครกสิงคโปร์',
    'ingredient_full_json': "\"แป้งสาลี: 2ถ้วย\nแป้งมัน: 1ถ้วย\nนมสดรสจืด: 1ถ้วย\nใบเตย12ใบแก่ๆ คั้นน้ำกรองกาก: 1ถ้วย\nผงฟู: 2ช้อนกาแฟพูนๆ\nเกลือ: 1ช้อนกาแฟพูนๆ\nน้ำตาลทราย: 1ถ้วย\nน้ำมันพืช: 1ช้อนกาแฟ\nไข่ไก่: 2ฟอง\""
},
{
    'ชื่ออาหาร': 'ไก่ผัดเม็ดมะม่วงหิมพานต์ (น้ำพริกเผา) Gai Pad Med Mamuang',
    'ingredient_full_json': "\"เนื้อไก่หั่นชิ้นพอดีคำ: 400 กรัม\nแป้งทอดกรอบ: 1/2 ถต.\nเม็ดมะม่วงหิมพานต์ทอด: 100 กรัม\nพริกทอดกรอบ หั่นท่อน: 10 เม็ด\nหอมหัวใหญ่: 1 หัว\nพริกหวานสามสี (3 สี แดง เหลือง เขียว ใช้สีละอย่างละ: 1/2 ลูก\nพุทราเชื่อม/พุทราอบแห้ง (ใข้พุทราเชื่อมอร่อยกว่า) ส่วนนี้ไม่ใส่ก็ได้: 50 กรัม\nต้นหอมหั่นท่อน (มากน้อยตามชอบ): 5 ต้น\nกระเทียมสับละเอียด: 1 ช้อนโต๊ะ\nซอสหอยนางรม: 2 ช้อนโต๊ะ\nซีอิ้วขาว/ซอสปรุงรส: 1 ช้อนโต๊ะ\nน้ำตาลทราย(ความหวานปรับเพิ่มลดได้ตามความชอบ): 1 1/2 ช้อนโต๊ะ\nน้ำพริกเผา (ถ้าทำให้เด็กทานด้วยสามารถลดในส่วนนี้ลงได้): 2 ช้อนโต๊ะ\""
},
{
    'ชื่ออาหาร': 'แกงส้มผักบุ้งกุ้งลอยน้ำ',
    'ingredient_full_json': "\"กุ้งสดตัวใหญ่: 3 ขีด\nพริกแกงส้ม: 1 ช้อนโต๊ะ\nผักบุ้ง: 2 กำ\nน้ำปลา: 1 ช้อนชา\nหัวหอม: 2 หัว\nกระชาย: 1 ต้น\nกะปิ: ครึ่งช้อนชา\nน้ำตาลทราย: 1 ช้อนชา\nมะขามเปียก: 4 ฝัก\nใบมะกรูด: 4 - 5 ใบ\""
},
{
    'ชื่ออาหาร': 'ข้าวผัดซีอิ๊วดำ',
    'ingredient_full_json': "\"ข้าวสวย: 3 ถ้วย\nเนื้อหมู: 50กรัม\nไข่ไก่: 2ฟอง\nคะน้า: 30กรัม\nมะเขือเทศ: 1ลูก\nหอมหัวใหญ่: 1/2หัว\nกระเทียมสับ: 4กลีบ\nซีอิ๊วดำ: 1ช้อนโต๊ะ\nซีอิ๊วขาว: 1/2ช้อนโต๊ะ\nน้ำปลา: 1ชต\nน้ำตาลทราย: 1ช้อนชา\nน้ำมันพืช:\""
},
{
    'ชื่ออาหาร': 'ขนมจีนน้ำยากะทิไก่',
    'ingredient_full_json': "\"กะทิ: 1 Kg\nเนื้อไก่ส่วนหน้าอกต้ม: 500 กรัม\nพริกแห้ง: 15-20 เม็ด\nกระชายหั่น: 7 หัว\nตะไคร้ซอย: 3 ต้น\nหัวหอมแดงหั่น: 7 หัว\nข่าหั่น: 1 หัว\nกระเทียมซอย: 3 หัว\nน้ำซุปที่เหลือจากต้มไก่: 2 ถ้วยตวง\nเกลือป่น: 1 ช้อนโต๊ะ\nน้ำปลา: 4 ช้อนโต๊ะ\nน้ำตาลทราย: 2 ช้อนโต๊ะ\nใบมะกรูด: 10 ใบ\nลูกชิ้นปลา: 300 กรัม\nขนมจีน: 1 Kg\""
},
{
    'ชื่ออาหาร': 'น้ำพริกหนุ่ม',
    'ingredient_full_json': "\"พริกหนุ่ม: 15 เม็ด\nหอมแดง: 10 หัว\nกระเทียม: 5 หัว\nเกลือ: 1/2 ช้อนชา\nมะนาว: 2 ลูก\nน้ำตาล: 1/2 ช้อนชา\nผงคนอร์(รสหมู): 1 ช้อนโต๊ะ\nผงชูรส (ไม่ชอบไม่ต้องใส่): 1/2 ช้อนชา\""
},
{
    'ชื่ออาหาร': 'หมูฮ้อง',
    'ingredient_full_json': "\"หมูสามชั้น: 500 g\nพริกไทยดำ-ขาว อย่างละ: 1 ช้อนโต๊ะ\nกระเทียม: 2 ช้อนโต๊ะ\nรากผักชี: 2 ช้อนโต๊ะ\nอบเชย: 2 แท่ง\nดอกจันทร์: 3 ดอก\nซีอิ้วขาว: 3 ช้อนโต๊ะ\nซีอิ้วดำ: 1 ช้อนโต๊ะ\nน้ำตาลทรายแดง: 2 ช้อนโต๊ะ\nน้ำตาลปี๊บ: 1 ช้อนโต๊ะ\nเกลือ: 1/2 ช้อนชา\nซุปรสหมูก้อนคนอร์: 1 ก้อน\""
},
{
    'ชื่ออาหาร': 'ผัดกะเพราเนื้อสับ',
    'ingredient_full_json': "\"เนื้อบด: 2 ขีด\nใบกะเพรา: 10 ใบ\nกระเทียม: 5 กลีบ\nพริกขี้หนูสวน: ตามใจชอบ\nน้ำปลา: 1 ช้อนโต๊ะ\nซอสปรุงรส: 1 ช้อนโต๊ะ\nซอสหอยนางรม: 1 1/2 ช้อนโต๊ะ\nน้ำตาล: 1 ช้อนชา\nน้ำต้มสุก: 2-3 ช้อนโต๊ะ\""
},
{
    'ชื่ออาหาร': 'แกงเขียวหวานตีนไก่',
    'ingredient_full_json': "\"ตีนไก่: 1 กิโล\nเนื้อไก่ส่วนสะโพก: 200 กรัม\nกระทิคั้น(ซื้อที่ตลาด): 1 กิโล\nพริกแกงเขียวหวาน: 300 กรัม\nหน่อไม้ หรือ ยอดมะพร้าว: 200 กรัม\nพริกชี้ฟ้าแดง: 5-6 เม็ด\nใบมะกรูด: 5 ใบ\nใบโหระพา: 2-3 กำมือ\""
},
{
    'ชื่ออาหาร': 'ต้มยำปลาทู',
    'ingredient_full_json': "\"ปลาทูแม่กลอง (ตัวเล็ก): 10 ตัว\nเครื่องต้มยำ / ข่า / ตะไคร้ /ใบมะกรูด: มีขายเป็นชุดๆ ใช้ 1 ชุด\nมะนาว: 2 ลูก\nมะเขือเทศ: 1 ลูก\nพริกชี้ฟ้า: 3-4 เม็ด\nเกลือ: 1 ช้อนชา\nผงปรุงรส: ตามใจชอบ\nน้ำปลา: 2 ช้อนโต๊ะ\""
},
{
    'ชื่ออาหาร': 'ข้าวคลุกกะปิ',
    'ingredient_full_json': "\"กะปิ: \nข้าวสวย: \nหมูสามชั้น: \nน้ำตาล: \nกระเทียม: \nเนื้อสัปปะรด: \nกุนเชียง: \nไข่ไก่: \nไข่เค็ม: \nปลาทู: \nถั่วฝักยาว: \nหอมแดง: \nพริกขี้หนู: \nมะม่วง: \nกุ้งแห้ง: \nผักชี: \nซีอิ้วดำ:\""
},
{
    'ชื่ออาหาร': 'มาม่าผัดกะเพราหมูสับ',
    'ingredient_full_json': "\"บะหมี่กึ่งสำเร็จรูป(มาม่า)ลวก: 70 กรัม\nหมูสับ: 40 กรัม\nใบกะเพรา: 1 ถ้วย\nคนอร์ซอสข้นปรุงรส รสหมู: 1 ช้อนโต๊ะ\nน้ำตาลทราย: 1 ช้อนชา\nซีอิ๊วดำ: 1 ช้อนชา\nกระเทียม.: 4 กลีบ\nพริกแดงจินดา: 8 เม็ด\nน้ำมันพืช.: เล็กน้อย\nน้ำเปล่า: เล็กน้อย\""
},
{
    'ชื่ออาหาร': 'ฉู่ฉี่ปลาทูสด',
    'ingredient_full_json': "\"ปลาทูสด: 2 ตัวใหญ่\nพริกแกงฉูฉี่: 1+1/2 ช้อนโต๊ะ\nกะทิ: 1 ถ้วย(กล่องเล็ก)\nใบมะกรูดซอย: 3 ใบ\nพริกชี้ฟ้าหั่น: 2 เม็ด\nน้ำปลา: 1/2-1 ช้อนโต๊ะ\nน้ำตาลปี๊บ: 1/2-1 ช้อนโต๊ะ\nผงคนอร์อร่อยชัวร์: 1 ช้อนชา\""
},
{
    'ชื่ออาหาร': 'มาม่าผัดต้มยำกุ้ง',
    'ingredient_full_json': "\"เส้นบะหมี่กึ่งสำเร็จรูป: 50กรัม\nเห็ดฟาง: 40กรัม\nกุ้งสดปอกเปลือกผ่าหลัง: 3ตัว\nพริกเผา: 1ช้อนโต๊ะ\nซอสหอยนางรม: 1ช้อนโต๊ะ\nน้ำปลา: 1ช้อนโต๊ะ\nน้ำตาลทราย: 1ช้อนชา\nตะไคร้ทุบหั่นท่อนเล็ก: 2ต้า\nหอมแดง: 3หัว\nข่าสับ: 1ช้อนโต๊ะ\nใบมะกรูดฉีก: 6ใบ\nพริกแดงจินดา: 8เม็ด\nกระเทียม: 5กลีบ\nคนอร์ อร่อยชัวร์ ผงรสไก่: 1ช้อนชา\nมะนาว: 1/2ลูก\nน้ำมันพืช:\""
},
{
    'ชื่ออาหาร': 'โรลข้าวน้ำพริกกะปิ',
    'ingredient_full_json': "\"น้ำพริกกะปิ: 1 ถ้วยตวง\nปลาทูย่างสุก: 2 ตัว\nแตงกวา: 2 ลูก\nแครอท: 1 ลูก\nชะอม (หั่นซอย): 1 ถ้วยตวง\nไข่ไก่: 1 ฟอง\nข้าวสวย: 1 ถ้วยตวง\""
},
{
    'ชื่ออาหาร': 'แกงส้มผักรวมเจ',
    'ingredient_full_json': "\"พริกแกงส้มเจ: 3 ช้อนโต๊ะ\nถั่วเน่า(ใช้แทนกะปิ): 1/2 แผ่น\nขาเห็ดนางฟ้าต้ม: 10 ขา\nน้ำตาลปี๊บ: 1 ช้อนชา\nน้ำมะขามเปียก: 3 ช้อนโต๊ะ\nเกลือ: 1 ช้อนชา\nผงปรุงรสเห็ดหอมเจ: 1 ช้อนชา\nถั่วฟักยาว: 5 ฟัก\nหัวไชเท้า: 1/2 หัว\nเห็ดนางฟ้าส่วนดอก: 10 ดอก\nกวางตุ้ง: 3 ต้น\nดอกแค: 1 ถ้วย\nน้ำเปล่า: 6 ถ้วย\""
},
{
    'ชื่ออาหาร': 'ผัดไทยกุ้งสด หัวกุ้งทอดกรอบ',
    'ingredient_full_json': "\"เส้นหมี่: 1 ห่อ 200 กรัม\nกุ้งสด: 8 ตัว\nกุยช่าย: ตามชอบ\nหอมแดง: 5 หัว\nพริกแห้ง: 5\nกระเทียม: 3 หัว\nน้ำมะขาม: 3 ช้อนโต๊ะ\nน้ำตาลทราย: 1 ช้อนโต๊ะ\nเต้าหู้ขาว: ตามชอบ\nถั่วงอก: ตามชอบ\nน้ำปลา:\""
},
{
    'ชื่ออาหาร': 'ขนมจีนน้ำยาไก่',
    'ingredient_full_json': "\"เนื้อไก่: ครึ่งโล\nกระทิ: ครึ่งโล\nข่า ตะไคร้ ใบมะกรูด: 1 กำ\nตีนไก่: ครึ่งโล\nลูกชิ้นปลาอย่างดี: 1 ถุงเล็ก\nพริกแกงเผ็ด: 2 ขีด\nเกลือ: 1 ช้อน\nกระชาย: 2 ขีด\nเส้นขนมจีนสด: 1 ห่อ\""
},
{
    'ชื่ออาหาร': 'ต้มยำกุ้งน้ำข้น',
    'ingredient_full_json': "\"กุ้ง: 10 ตัว\nตะไคร้: 2 ต้น\nใบมะกรูด: 1 กำ\nข่า: 1/2 หัว\nเห็ดฟาง: 1 ขีด\nคนอร์ต้มยำ: 1 ก้อน\nนมจืด: 1/2 กล่อง\nน้ำพริกเผา: 2 ช้อน\nน้ำพริกเผาเผ็ด: 1 ช้อน\nพริก: 1 กำ\nเกลือ: \nน้ำปลา: \nน้ำตาล: \nมะนาว: 2 ลูก\""
},
{
    'ชื่ออาหาร': 'ข้าวผัดแกงเขียวหวาน',
    'ingredient_full_json': "\"เนื้อหมู: 100 กรัม\nข้าวสวย: 1 ถ้วย\nน้ำพริกแกงเขียวหวาน: 1/2 ช้อนโต๊ะ\nมะเขือเปราะหั่น 4 หรือ 6: 1 ลูก\nมะเขือพวงเด็ด: 10 เม็ด\nใบโหระพา(เด็ดเป็นใบ): 10-15 ใบ\nพริกชี้ฟ้าแดงหั่นเฉียง: 5 ชิ้น\nกะทิ: 2 ช้อนโต๊ะ\nน้ำตาลปี๊บ: 1 ช้อนชา\nน้ำปลา: 2 ช้อนชา\""
},
{
    'ชื่ออาหาร': 'ต้มยำปลากระป๋อง',
    'ingredient_full_json': "\"ปลากระป๋อง: 3 กระป๋อง\nตะไคร้: 6 ท่อน\nข่า: 2 กิ่ง\nใบมะกรูด: 2 กิ่ง\nเห็ดนางฟ้า: 200 กรัม\nหอมแดง: 10 หัว\nผักชีฝรั่ง: 5 ต้น\nผงปรุงรส: 2 ก้อน\nพริกป่น: 1 ช้อนโต๊ะ\nพริกจินดา: 10 เม็ด\nมะนาว: 4 ลูก\""
},
{
    'ชื่ออาหาร': 'ข้าวผัดน้ำพริกลงเรือสูตรโบราณแกล้มหมูกรอบทอดน้ำปลา',
    'ingredient_full_json': "\"หมูสามชั้น: 1 ชิ้น\nปลาดุกฟู: 1 ถ้วยตวง\nพริกขี้หนู: 15 เม็ด\nกะปิย่าง: 2 ช้อนโต๊ะ\nน้ำตาลปีบ: 2 ช้อนชา\nกระเทียมกลีบเล็ก: 3 กลีบ\nถั่วฝักยาว: 1/3 ถ้วยตวง\nไข่เค็ม: 1 ฟอง\nแครอทต้มสุก: 1/3 ถ้วยตวง\nน้ำปลา: 3 ช้อนโต๊ะ\nซอสหอยนางรม: 1 ช้อนโต๊ะ\nซอสปรุงรส: 2 ช้อนโต๊ะ\nน้ำตาลทราย: 2 ช้อนโต๊ะ\""
},
{
    'ชื่ออาหาร': 'ต้มยำกุ้งน้ำข้น',
    'ingredient_full_json': "\"กุ้งขาว: 200\nข่า: 5 แว่น\nตะไคร้: 3 ต้น\nใบมะกรูด: 4 ใบ\nหอมแดง: 5 หัว\nนมข้นจืด: 1/4-1/2 ถ้วย\nน้ำพริกเผา: 1 ช้อนโต๊ะ\nน้ำเปล่า: 3 ถ้วย\nเห็ดต่างๆ: ตามชอบ\nคนอร์ซุปต้มยำ(ก้อน): 2 ก้อน\nผักชีฝรั่ง: 2 ต้น\nต้นหอม: 2 ต้น\nพริกแห้งทอด: 4 เม็ด\nน้ำปลา: \nน้ำมะนาว:\""
},
{
    'ชื่ออาหาร': 'แกงส้มผักรวม',
    'ingredient_full_json': "\"ผักสด (ตามสะดวก): \nปลา(ตามสะดวก): \nพริกแห้ง: \nหอมแดง: \nกะปิ: \nน้ำตาลปี๊บ: \nน้ำปลา: \nเกลือ: \nน้ำมะขามเปียก:\""
},
{
    'ชื่ออาหาร': 'ข้าวมันไก่เด็กหอ',
    'ingredient_full_json': "\"น่องไก่ติดสะโพก: 2น่อง\nข้าว: 4กรัม\nกระเทียม: 1หัว\nขิง: 1แง่ง\nพริกสด: 1ขีด\nน้ำตาลทราย: 3ช้อน\nมะนาว: 3ลูก\nซอสปรุงรสสูตร1: 2ช้อน\nเต้าเจี้ยว: 4ช้อน\nซุปคนอร์: 2ก้อน\""
},
{
    'ชื่ออาหาร': 'แกงส้มปลาทูสด',
    'ingredient_full_json': "\"ปลาทูสด: 4ตัว\nพริกแกงส้ม: 2ช้อนโต๊ะ\nน้ำปลา: 1 1/2ช้อนโต๊ะ\nน้ำตาล: 1ช้อนโต๊ะ\nน้ำมะขามเปียก: 2ช้อนโต๊ะ\nผักบุ้ง: 1กำ\""
},
{
    'ชื่ออาหาร': 'เครื่องในไก่ทอดกระเทียม',
    'ingredient_full_json': "\"เครื่องในไก่: \nพริกไทยขาวป่น: \nผงปรุงรส: \nแป้งชุบทอด: \nกระเทียม: \nน้ำมันพืช:\""
},
{
    'ชื่ออาหาร': 'ต้มยำกุ้งน้ำใส',
    'ingredient_full_json': "\"กุ้ง 3 ตัว: 250 กรัม\nเห็ดนางรมหลวง: 60 กรัม\nตะไคร้: 2 ต้น\nใบมะกรูด: 6 ใบ\nพริกขี้หนูสวน สีแดง: 15 เม็ด\nน้ำมะนาว: 1.5 ช้อนโต๊ะ\nซีอิ๊วขาว: 1.5 ช้อนโต๊ะ\nน้ำสต๊อก: 350 กรัม\nข่าแก่: 6 แว่น\""
},
{
    'ชื่ออาหาร': 'ข้าวกะเพราเนื้อไข่ดาว เมนูนี้ไม่มีเบื่อ',
    'ingredient_full_json': "\"ไข่ไก่: 1 ฟอง\nเนื้อสับ หรือหั่นเป็นชิ้น/หรือจะใช้เนื้อสัตว์อย่างอื่นก็ได้ค่ะ: 250 กรัม\nซอสหอยนางรม: 1 ช้อนชา\nน้ำปลา หรือ ซอสปรุงรส: 1 ช้อนชา\nน้ำตาล: 1/2 ช้อนชา\nใบกระเพรา: 2 กำมือ\nกระเทียม: 3 กลีบ\nพริก: 3-4 เม็ด\""
},
{
    'ชื่ออาหาร': 'ผัดกะเพราโบราณ, ผัดกะเพราเนื้อสับ',
    'ingredient_full_json': "\"เนื้อสับ: 300 กรัม\nพริกขี้หนูเน้นสีแดง: 35 เม็ด\nกระเทียมจีน: 1 หัว\nใบกะเพรา: ตามชอบ\nซอสปรุงรส: 2 ช้อนโต๊ะ\nน้ำปลา: 1/2 ช้อนโต๊ะ\nน้ำตาลทราย: 1 ช้อนชา\nซอสหอยนางรม: 1 ช้อนโต๊ะ\nน้ำดื่ม: 1 ทัพพี\""
},
{
    'ชื่ออาหาร': 'แกงเทโพหมูสามชั้น',
    'ingredient_full_json': "\"หมู 3 ชั้น: 400 g.\nพริกแกงใต้(แกงเผ็ด): 100 g.\nน้ำตาลมะพร้าว: 20 กรัม\nใบมะกรูด: 3 ใบ\nมะขามเปียก: 1/2 ช้อนโต๊ะ\nน้ำปลาแท้: 2 ช้อนโต๊ะ\nผักบุ้งไทย: 8-10 ต้น\nน้ำมันพืช: 1 ช้อนชา\nกะทิ: 250 ml.\""
},
{
    'ชื่ออาหาร': 'แกงเลียงปลากรอบ',
    'ingredient_full_json': "\"ปลากรอบเอาไปปิ้งหรือเอาไปอบให้หอม แกะเอาแต่เนื้อ: 1 ตัว\nน้ำเต้าปอกเปลือก ล้างให้สะอาด หั่นเป็นชิ้นพอดีคำ: 1 ลูกเล็ก\nบวบ ฝานคมออกให้หมด ล้างน้ำให้สะอาด หั่นชิ้นพอดีคำ: 1/2 ลูก\nข้าวโพดอ่อน หั่นชิ้นพอดีคำ: 2-3 ฝัก\nใบแมงลักเด็ด ล้างน้ำให้สะอาด สะเด็ดน้ำ: 1/2 ถ้วย\nพริกไทยเม็ด: 1/2 ช้อนโต๊ะ\nหอมแดง: 4-5 หัว\nกุ้งแห้งแช่น้ำให้นิ่ม สะเด็ดน้ำ: 25 กรัม\nพริกขี้หนูสด: 10 เม็ด\nกะปิ: 1/2 ช้อนโต๊ะ\""
},
{
    'ชื่ออาหาร': 'ปลากะพงทอดน้ำปลา',
    'ingredient_full_json': "\"ปลากระพง: 1 ตัว\nน้ำมันสำหรับทอด: \nน้ำปลา: 2 ช้อนโต๊ะ\nน้ำตาลปี๊บ: 2 ช้อนโต๊ะ\nน้ำเปล่า: 1/4 ถ้วย\nเม็ดมะม่วงหิมพานต์ ถั่วลิสง: สำหรับโรย\nใบผักชี: สำหรับโรย\""
},
{
    'ชื่ออาหาร': 'แกงบวดฟักทอง',
    'ingredient_full_json': "\"ฟักทอง: 100 g\nน้ำตาลทราย: 3 ช้อนโต๊ะ\nกะทิ: 100 มล.\nเกลือ: เล็กน้อย\""
},
{
    'ชื่ออาหาร': 'แกงส้มผักกระเฉด',
    'ingredient_full_json': "\"ผักกระเฉด: 300กรัม\nกุ้งผ่าหลัง: 5-6ตัว\nปลากระป๋อง: 2กระป๋อง\nพริกสด: 50กรัม\nพริกแห้งป่น: 2ช้อนชา\nหอมแดง: 7-8หัว\nกระชาย: 2ช้อนโต๊ะ\nกระปิ: 2ช้อนโต๊ะ\nเกลือป่น: 1/2ช้อนชา\nน้ำตาล: 1ช้อนโต๊ะ\nน้ำปลา: 3ช้อนโต๊ะ\nน้ำมะขามเปียก: 4ช้อนโต๊ะ\nมะนาว: 3ลูก\""
},
{
    'ชื่ออาหาร': 'ก๋วยเตี๋ยวคั่วไก่',
    'ingredient_full_json': "\"เส้นใหญ่: \nอกไก่: \nเห็ดหูหนูขาว (ใช้แทนหมึกกรอบ): \nากผักชี, กระเทียม, พริกไทย (สำหรับหมักไก่): \nไข่ไก่: \nซีอิ๊วขาว, ซีอิ๊วดำ, น้ำปลา, ซอสพริก: \nผักกาดหอม: \nพริกเหลือง, น้ำส้มสายชู (สำหรับทำพริกดอง): \nไก่เชียง, หนังไก่ (เครื่องโรยหน้า):\""
},
{
    'ชื่ออาหาร': 'แกงเขียวหวานสำเร็จรูป',
    'ingredient_full_json': "\"หมูสันใน: 200 กรัม\nผงปรุงรสแกงเขียวหวาน: 1 ซอง\nน้ำกะทิ: 100 มล.\nใบมะกรูด: \nโหระพา: \nพริกชี้ฟ้าแดง: \nมะแว้งเขียว: 150 กรัม\nน้ำเปล่า: 50 มล.\""
},
{
    'ชื่ออาหาร': 'แกงมัสมั่นไก่',
    'ingredient_full_json': "\"สะโพกไก่: 500 กรัม\nพริกแกงมัสมั่น: 60 กรัม\nกะทิเรียลไทย: 750 มล\nถั่วลิสงคั่ว: 50 กรัม\nมันฝรั่ง (หั่นเต๋า): 4-5 ลูก\nหอมใหญ่: 2 หัว\nน้ำตาลมะพร้าว: 2-3 ชต\nน้ำปลาดี: 1-2 ชต\nน้ำมะขามเปียก น้ำส้มซ่า: 2-3 ชต\nอบเชย โป๊ยกั๊ก: \nลูกกระวาน ใบกระวาน: \nเกลือ: 1/2 ชช\""
},
{
    'ชื่ออาหาร': 'ข้าวกะเพราไก่ไข่ดาว',
    'ingredient_full_json': "\"เนื้อไก่สับ: 70กรัม\nใบกะเพรา: 1ถ้วย\nพริกแดงจินดา: 8เม็ด\nกระเทียม: 5กลีบ\nซีอิ๊วดำ: 1/2 ชช\nซอสหอยนางรม: 1/2 ช้อนโต๊ะ\nน้ำปลา: 1/2 ชต\nน้ำตาลทราย: 1ช้อนชา\nคนอร์ เนเชอรัล ผงรสหมูสูตรไม่ใส่ผงชูรส: 1ช้อนชา\nไข่ไก่: 1ฟอง\nน้ำมันพืช: \nข้าวสวย: 1ถ้วย\""
},
{
    'ชื่ออาหาร': 'แกงส้มกุ้งสับปะรด',
    'ingredient_full_json': "\"กุ้งขาว: 4 ขีด\nสับปะรดเปรี้ยวอมหวาน: 1/2 ลูกเล็ก\nเครื่องแกงส้มใต้: 2 ช้อนโต๊ะ\nกะปิ: 1.5ช้อนโต๊ะ\nน้ำปลา: 1.5 ช้อนโต๊ะ\nเกลือป่น: 1 หยิบมือ\nน้ำตาล: 1.5 ช้อนโต๊ะ\nน้ำมะขามเปียก: 1 ถ้วยน้ำซุป\nมะนาว: 1.5 ลูก\""
},
{
    'ชื่ออาหาร': 'พะแนงเนื้อ',
    'ingredient_full_json': "\"เนื้อวัว: ครึ่งกิโล\nพริกแกงพะแนง: 1ขีด\nกะทิชาวเกาะ: 1กล่อง\nมะเขือพวง: \nใบมะกรูด: \nพริกแดง: \nน้ำตาล: \nเกลือ:\""
},
{
    'ชื่ออาหาร': 'แกงเขียวหวาน สันในหมู',
    'ingredient_full_json': "\"เครื่องแกงเขียวหวาน: 100g\nสันในหมู: 400g\nมะเขือเปราะ: 100g\nมะเขือพวง (ไม่ใส่เพราะไม่ชอบครับ): 0\nพริกชี้ฟ้า: นิดหน่อย\nโหระพา: นิดหน่อย\nกะทิ: 500ml\nซอสหอยนางรม: 3 ชต\nน้ำปลา: 4 ชต\nน้ำตาล: 4-5 ชช\""
},
{
    'ชื่ออาหาร': 'ฉู่ฉี่ปลาทู',
    'ingredient_full_json': "\"ปลาทูสด: 3ตัว\nกะทิกล่องอร่อยดี: 250 ml.\nพริกแกงเผ็ด: 3 ชต\nน้ำปลา: 2 ช้อนโต๊ะ\nน้ำตาลปี้บ: 1/2 ช้อนโต๊ะ\nใบมะกรูด: \nพริกแดง:\""
},
{
    'ชื่ออาหาร': 'แกงเลียงกะทิสด',
    'ingredient_full_json': "\"กุ้งขาวแกะเปลือกผ่าหลัง: 2 ขีด\nหัวหอมแดง: 3 หัว\nข่า(ใส่ดับกลิ่นคาวนิดนึง): 1ช้อนชา\nกระชาย: 2ช้อนชา\nกะปิ: 1ช้อนชา\nพริกไทยขาวเม็ด: 2-3 ช้อนชา\nกุ้งแห้ง: 2 ช้อนชา\nฟักทอง: \nข้าวโพดอ่อน: \nบวบ: \nเห็ดโคนญี่ปุ่น: \nใบแมงลัก: 1ขีด\nกะทิสด: 1/2 ถ้วย\nน้ำปลา ตามชอบ เราใส่แค่: 1ช้อน\""
},
{
    'ชื่ออาหาร': 'ปลาทอดขมิ้น',
    'ingredient_full_json': "\"ปลาทะเล ขอดเกล็ด ควักไส้ บั้ง: \nกระเทียม: \nขมิ้น:\""
},
{
    'ชื่ออาหาร': 'ฉู่ฉี่ปลานิล (สูตรคุณยาย)',
    'ingredient_full_json': "\"ปลานิล: 1 ตัว\nพริกแกงเผ็ด: 3 ช้อนโต๊ะ\nใบมะกรูดหั่นฝอย ประมาณ: 1 ½ ช้อนโต๊ะ\nน้ำปลา: 3 ช้อนโต๊ะ\nน้ำตาล: 1 ½ ช้อนโต๊ะ\nผงชูรส: 1 ช้อนชา\nน้ำมันพืช:\""
},
{
    'ชื่ออาหาร': 'ต้มโคล้งปลากรอบ',
    'ingredient_full_json': "\"ปลาทับทิมทอดกรอบ: 1 ตัว\nเห็ดฟาง: 5 ลูก\nใบกระเพรา: 1 ก้าน\nผักชีฝรั่ง: 2 ต้น\nมะเขือเทศ: 3 ลูก\nหอมแดง: 4 หัว\nข่า: 5 แว่น\nตะไคร้: 1 ต้น\nพริกแดง: 5 ดอก\nพริกแห้ง: 2ดอก\nใบมะกรูด: 2ใบ\nมะนาว: 5 ช้อนโต๊ะ\nน้ำเปล่า: 1 ถ้วยตวง\nน้ำปลา: 5 ช้อนโต๊ะ\nน้ำตาล: 2 ช้อนชา\nเกลือ: 1/2 ช้อนชา\""
},
{
    'ชื่ออาหาร': 'แกงส้มผักรวมปลากระพง',
    'ingredient_full_json': "\"เนื้อปลากระพง: 250 g.\nพริกแกงส้ม: 2-3 ช้อนโต๊ะ\nมะละกอ: 100 g.\nหัวไชเท้า,แครอท: 100 g.\nผักบุ้งไทย: 100 g.\nถั่วฝักยาว,ถั่วพู: 100 g.\nน้ำมะขามเปียก: 4-5 ช้อนโต๊ะ\nน้ำตาลมะพร้าว: 1-2 ช้อนโต๊ะ\nน้ำปลาดี: 3 ช้อนโต๊ะ\nเกลือ: 1/2 ช้อนชา\nน้ำเปล่า: 3 ถต.\""
},
{
    'ชื่ออาหาร': 'น้ำตกเนื้อ',
    'ingredient_full_json': "\"เนื้อสันนอกติดมัน: 1 ชิ้น\nน้ำปลาดี: 2 ชต\nมะนาว: 1-2 ลูก\nพริกป่น: 1 ชต\nข้าวคั่ว: 1 ชต\nหอมแดง: 5 หัว\nต้นหอม: 2 ต้น\nผักชีฝรั่ง,สะระแหน่: \nใบมะกรูดซอย: 4-5 ใบ\nพริกขี้หนู,กระเทียม: \nผงคนอร์อร่อยชัวร์: 1 ชช\""
},
{
    'ชื่ออาหาร': 'ขนมจีนน้ำยากะทิไก่ข้น (หลัวรักหลัวหลง)',
    'ingredient_full_json': "\"เนื้ออกไก่: \nกะทิ: \nน้ำปลา: \nปลาร้า (ตามชอบ): \nพริกแห้ง หอมแดง กระเทียม ตะไคร้ ใบมะกรูด กระชาย:\""
},
{
    'ชื่ออาหาร': 'ขนมจีนแกงไตปลา',
    'ingredient_full_json': "\"ไตปลา: 1 ถ้วย\nข่า: 6 แว่น\nตะไคร้: 3 ต้น\nใบมะกรูด: 10 ใบ\nน้ำเปล่า: 4 ถ้วย\nพริกแกงไตปลา: 1/4 ถ้วย\nเนื้อปลาย่าง: 1 ถ้วย\nหน่อไม้ต้ม: 1 ถ้วย\nฟักทอง: 1 ถ้วย\nถั่วฟักยาว: 1/2 ถ้วย\nมะเขือเปราะ: 1/2 ถ้วย\nมะเขือพวง: 1/4 ถ้วย\n้น้ำมะขามเปียก: 1/4 ถ้วย\nน้ำตาลปี๊บ: 1 ช้อนโต๊ะ\nขนมจีน: ตามชอบ\""
},
{
    'ชื่ออาหาร': 'ต้มจืดมะระยัดไส้',
    'ingredient_full_json': "\"มะระ: \nหมูสับ: \nวุ้นเส้น: \nพริกไทย: \nซอสหอยนางรม: \nผงปรุงรส: \nซุปก้อน: \nน้ำเปล่า: \nรากผักชี: \nผักชี: \nเก๋ากี้: \nเห็ดหอม:\""
},
{
    'ชื่ออาหาร': 'ผัดกะเพรากุ้ง',
    'ingredient_full_json': "\"กุ้งแกะเปลือก: 15 ตัว\nพริกชี้ฟ้าและกระเทียมโขลก: 1 ช้อนโต๊ะ\nใบกะเพรา: ตามชอบ\nน้ำตาลทราย: 2 ช้อนชา\nน้ำปลา: 1 ช้อนโต๊ะ\nน้ำมันรำข้าวสำหรับผัด:\""
},
{
    'ชื่ออาหาร': 'ข้าวกะเพราเนื้อสับ-ไข่ดาว',
    'ingredient_full_json': "\"เนื้อวัวสับ: 70กรัม\nพริกแดงจินดา: 4 เม็ด\nกระเทียมสับ: 3 กลีบ\nน้ำปลา: 1 ช้อนโต๊ะ\nซีอิ๊วขาว: 1/2 ช้อนโต๊ะ\nน้ำตาลทราย: 1 ช้อนชา\nใบกะเพรา (ตามชอบ): 1กำ\nน้ำมันรำข้าว 2 ช้อนโต๊ะ: 2 ช้อนโต๊ะ\""
},
{
    'ชื่ออาหาร': 'ผัดกะเพรากุ้ง',
    'ingredient_full_json': "\"กุ้งสดปอกเปลือก: 500 กรัม\nผงปรุงรสผัดกะเพราสำเร็จรูป: 1 ช้อนโต๊ะ\nน้ำตาลทราย: 1/2 ช้อนชา\nกะเพรา: 1 กำมือ\nพริกชี้ฟ้าเขียว: 1 ดอก\nพริกขี้หนูสด: 2 ดอก\nกระเทียมสับ 5-6 กลีบ: 1-2 ช้อนชา\nน้ำมันมะกอก: 1 ช้อนโต๊ะ\nน้ำอุ่น: 50 มล.\""
},
{
    'ชื่ออาหาร': 'ข้าวขาหมู',
    'ingredient_full_json': "\"ขาหมู: 1-2 kg\nโป๊ยกั๊ก: 10 ดอก\nแท่งอบเชย: 3 แท่ง\nกระเทียมทุบ: 10 กลีบ\nรากผักชี: 5 ราก\nพริกไทยดำเม็ด: 1 ช้อนโต๊ะ\nเห็ดหอม: 10-15 ชิ้น\nผงพะโล้: 5-10 กรัม\nซีอิ๋วดำหวาน: 3 ช้อนโต๊ะ\nซีอิ๋วขาว: 1/4 ถ้วย\nซอสปรุงรสฝาเขียว: 3 ช้อนโต๊ะ\nน้ำตาบปี๊บ: 200 กรัม\nน้ำสะอาด: 3 ลิตร\""
},
{
    'ชื่ออาหาร': 'น้ำจิ้มปลาเผา (มะขาม)',
    'ingredient_full_json': "\"มะขาม: 1 ปั้น\nน้ำตาลปิ้บ: 1 ช้อนโต๊ะ\nน้ำเปล่า: 1 ถ้วย\nพริกขี้หนู: 10 เม็ด\nหอมแดง: 8 หัว\""
},
{
    'ชื่ออาหาร': 'แกงส้มผักรวมน้ำข้น',
    'ingredient_full_json': "\"น้ำ: 1/2ลิตร\nหัวไชเท้า: 1หัว\nแครอท: 1หัว\nถั่วฝักยาว: 1กำ\nเนื้อปลาดอลลี่แช่แข็ง(หรือจะใช้ปลาชนิดอื่นได้ แต่ควรเป็นปลาเนื้ออ่อน): 2ชิ้น\nผงทำแกงส้มคนอร์: 1ซอง\nน้ำมะขามเปียก (ตอนอยู่ที่อเมริกาไม่มี เราแอบใช้น้ำส้มสายชูแทน แต่ถ้าหาได้น้ำมะขามจะหอมกว่าเยอะ): 1ถ้วยเล็ก\nน้ำตาลทราย: 2ช้อนโต๊ะ\nน้ำปลา: 1ช้อนโต๊ะ\""
},
{
    'ชื่ออาหาร': 'แกงส้มปลาทู (แกงส้มใต้)',
    'ingredient_full_json': "\"ปลาทู: 3 ตัว\nมะละกอ: 300 กรัม\nผักบุ้งไทย: 100 กรัม\nน้ำมะขามเปียก: 2 ช้อนโต๊ะ\nน้ำตาลทราย: 1 ช้อนชา\nน้ำสะอาด: 600 มล\nเครื่องแกงส้มใต้: 1 1/2 ช้อนโต๊ะ\nกะปิ: 1 ช้อนชา\nมะนาว: 1 ลูก\""
},
{
    'ชื่ออาหาร': 'ขนมจีนน้ำยาปลาช่อน X ตีนไก่+ลูกชิ้นปลา',
    'ingredient_full_json': "\"ขนมจีน: 2กก\nปลาช่อน: 1ตัว\nกะทิหัวหาง: 1กก\nพริกแกงเผ็ด: 2ขีด\nกระชายซอย: 20บาท\nปลาอินทรีย์เค็ม: 1ชิ้น\nกะปิ: 1ชต\nน้ำปลา: 1-2ถ้วย\nผักสดต่างๆ: \nผักกาดดอง: \nใบแมงลัก: \nพริกแห้ง:\""
},
{
    'ชื่ออาหาร': 'เส้นใหญ่ผัดซีอิ๊วไก่',
    'ingredient_full_json': "\"เส้นใหญ่: 350 กรัม\nไก่หั่นเป็นชิ้น: 200 กรัม\nไข่ไก่: 2 ฟอง\nคะน้าหั่นท่อน: 3 ต้น\nกระเทียมสับ: 1 ช้อนโต๊ะ\nซีอิ๊วดำ: 2 ช้อนโต๊ะ\nน้ำปลา: 1 ช้อนโต๊ะ\nซอสปรุงรส: 2 ช้อนชา\nซีอิ๊วขาว: 1 ช้อนโต๊ะ\nน้ำมันพืช: \nมะนาว. พริกไทย:\""
},
{
    'ชื่ออาหาร': 'ยำวุ้นเส้นเครื่องล้น',
    'ingredient_full_json': "\"วุ้นเส้นสด: 1ห่อ\nหมูสับ: 2กรัม\nเห็ดเข็มทอง: 1ห่อ\nหอมแขก: ครึ่งหัว\nขึ้นช่าย: 2ต้น\nแครอท: เล็กน้อย\nผักกาดขาว: 3ใบ\nน้ำปลา: 2ช้อนโต๊ะ\nน้ำมะนาวสด: 2ช้อนโต๊ะ\nน้ำตาล: 1ช้อนชา\nพริกป่น: 1ช้อนโต๊ะ\""
},
{
    'ชื่ออาหาร': 'ต้มยำปลาคัง',
    'ingredient_full_json': "\"เนื้อปลาคัง+หัวปลาคัง: 500 กรัม\nตะไคร้: 3 ต้น\nใบมะกรูด: 10 ใบ\nข่าหั่นแว่น: 5 แว่น\nต้นหอม: 2ต้น\nผักชีฝรั่ง: 2ต้น\nผักชี: 2ต้น\nน้ำปลา: 1ช้อนโต๊ะ\nน้ำมะนาว: 3ช้อนโต๊ะ\nพริกขี้หนูทุบ: 15 เม็ด\nพริกขี้หนูแห้งคั่ว: 15เม็ด\nหอมแดง: 5หัว\nซีอิ๋วขาว: 1ช้อนโต๊ะ\nน้ำเปล่า: 500 มล.\nมะเขือเทศ: 2ลูก\nผงปรุงรสคนอร์ แบบก้อน: 1ก้อน\nกระเทียม: 4 กลีบ\""
},
{
    'ชื่ออาหาร': 'ไก่ผัดขิง',
    'ingredient_full_json': "\"เนื่อไก่: 1/2 กิโล\nขิงอ่อน: 1/2 กิโล\nเห็ดหูหนู: 3 ขีด\nต้นหอม: 2 ขีด\nหัวหอมใหญ่: 2 หัว\nกระเทียมจีน: 5 กลีบ\nพริกชี้ฟ้า: 10 เม็ด\""
},
{
    'ชื่ออาหาร': 'น้ำพริกกะปิกุ้งแห้ง',
    'ingredient_full_json': "\"กะปิอย่างดี: 30 กรัม\nกุ้งแห้ง: 1+1/2 ช้อนโต๊ะ\nพริกขี้หนูสวน: 25 เม็ด\nกระเทียมไทยกลีบเล็ก: 15 กลีบ\nน้ำปลา: ตามชอบ\nน้ำตาลปี๊บ: ตามชอบ\nน้ำมะนาว: ตามชอบ\nน้ำเปล่าต้มสุก: 1 ช้อนโต๊ะ\nใบตองหรือใบต้นกระชาย: 1 ใบ\nมะเขือพวง: 10 เม็ด\""
},
{
    'ชื่ออาหาร': 'น้ำพริกกะปิปลาทู',
    'ingredient_full_json': "\"กะปิ 5 ช้อนโต๊ะ: \nน้ำตาลปี๊บ 1 ช้อนโต๊ะ: \nมะนาว 7 ช้อนโต๊ะ: \nกระเทียม 6 ช้อนโต๊ะ: \nพริกขี้หนู 20 เม็ด: \nปลาทู 2 ตัว: \nน้ำต้มสุก 6 ช้อนโต๊ะ:\""
},
{
    'ชื่ออาหาร': 'ยำไข่ดาว',
    'ingredient_full_json': "\"ไข่ไก่: จำนวนตามด้องการ\nพริกขี้หนูซอย: 1 ช้อนโต๊ะ\nมะเขือเทศหั่นเสี้ยว: 1-2 ลูก\nหอมใหญ่สไลด์: 1-2 ลูก\nต้นหอมกับขึ้นฉ่ายหั่นท่อน: 3-4 ต้น\nน้ำมะนาว: 2 ช้อนโต๊ะ\nน้ำกระเทียมดอง: 2 ช้อนโต๊ะ\nน้ำปลา: 2 ช้อนโต๊ะ\nน้ำตาลทราย: เล็กน้อย\""
},
{
    'ชื่ออาหาร': 'แกงส้มไหลบัวปลากระพงปักษ์ใต้',
    'ingredient_full_json': "\"ไหลบัว: 8 เส้น\nพริกป่นแบบใต้ที่ละเอียด: 2 ช้อนโต๊ะ\nกะปิ: 1 ช้อนโต๊ะ\nเกลือ: 1/2 ช้อนชา\nปลากระพงหั่นชิ้นขนาดพอคำ: 1 ตัว\nมะนาว: 7 ช้อนโต๊ะ\nพริกไทยเม็ดดำ: 10 เม็ด\""
},
{
    'ชื่ออาหาร': 'ข้าวต้มหมูทรงเครื่อง',
    'ingredient_full_json': "\"ข้าวสวย: 2 ถ้วย\nหมูสับปั้นเป็นก้อนกลม: 150 กรัม\nคนอร์ซุปก้อน: 1 ก้อน\nน้ำเปล่า: 3-4 ถ้วย\nขิงแก่ซอย: 2 ช้อนโต๊ะ\nกระเทียมสดแกะเปลือก: 1 ช้อนโต๊ะ\nกุ้งแห้ง: 1 ช้อนโต๊ะ\nปลาหมึกแห้ง: 1 ช้อนโต๊ะ\nคื่นช่ายหั่นซอย: 1 ช้อนโต๊ะ\nพริกไทยป่น: \nเกลือ: 1/3 ช้อนชา\nซอลแม็กกี้: 1 1/2 ช้อนชา\""
},
{
    'ชื่ออาหาร': 'ต้มยำกุ้งแม่น้ำ (น้ำข้น)',
    'ingredient_full_json': "\"กุ้งแม่น้ำ: 5ขีด\nเม็ดฟาง: \nข่า: \nตะไคร้: \nใบมะกรูด: \nมะนาว: \nพริก: \nน้ำปลา: \nน้ำตาล: \nนมสดจืด:\""
},
{
    'ชื่ออาหาร': 'ผัดเผ็ดไก่มะเขือเปาะ',
    'ingredient_full_json': "\"อกไก่: 1อก\nตับไก่: 20บาท\nมะเขือเปาะ: 6-8ลูก\nโหระพา: 5บาท\nใบมะกรูดฉีก: 5-6ใบ\nพริกแกงเผ็ด: 10บาท\nกะทิกล่องเล็ก: 1กล่อง\nน้ำตาลปึก: 2/4:ก้อน\nน้ำปลา: 3-5ชต\""
},
{
    'ชื่ออาหาร': 'แกงส้มฟักแม้วกุ้งสด',
    'ingredient_full_json': "\"ฟักแม้ว: 2 หัว\nปลานิล: 1 ตัว\nพริกแกงส้ม: 1 ขีด\nน้ำมะขามเปียก: 5 ช้อน\nน้ำปลา: 4 ช้อน\nน้ำตาลปีบ: 1 ช้อน\nกุ้ง: 6-7 ตัว\nเกลือป่น: 1/2\""
},
{
    'ชื่ออาหาร': 'แกงเขียวหวานหน่อไม้ไก่',
    'ingredient_full_json': "\"เนื้อสะโพกไก่: 3 ชิ้น\nพริกแกงเขียวหวานสำเร็จรูปตามตลาดสด: 10 บาท\nกะทิ: 0.5 กิโล\nใบโหระพา: 5 บาท\nหน่อไม้ดอง: 0.5 กิโล\nน้ำปลา: ตามชอบ\nน้ำตาล: ตามชอบ\""
},
{
    'ชื่ออาหาร': 'ขนมจีนน้ำยา สูตรเด็ด',
    'ingredient_full_json': "\"ปลาทับทิม: 1 โล\nกะทิ: 1 โล\nหางกะทิ: 1 โล\nลูกชิ้นปลา: ตามใจชอบ\nกระชาย: 2 ขีด\nกะปิ: 1 ช้อนโต๊ะ\nน้ำปลา: 1 ช้อนโต๊ะ\nพริกแกงน้ำยา: 2 ขีด\nคนอร์: 2 ก้อน\nน้ำตาลปี๊บ: 1 ช้อนชา\""
},
{
    'ชื่ออาหาร': 'ข้าวผัดต้มยำกุ้ง',
    'ingredient_full_json': "\"ข้าวสวย: 1ถ้วย\nกุ้งสดปอกเปลือกผ่าหลัง: 40กรัม\nข่าซอย: 1ช้อนโต๊ะ\nตะไคร้ซอย: 2ต้น\nใบมะกรูดซอย: 1ช้อนโต๊ะ\nหอมแดงซอย: 2หัว\nมะเขือเทศหั่นเต๋าเล็ก: 1ช้อนโต๊ะ\nน้ำมะนาว: 1ช้อนโต๊ะ\nพริกแดงซอย: 1ช้อนโต๊ะ\nเห็ดฟาง: ตามชอบ\nกระเทียมสับ: 1ช้อนโต๊ะ\nน้ำพริกเผา: 1 1/2 ช้อนโต๊ะ\nน้ำปลา: 1/2ชต\nน้ำตาลทราย: 1/2ช้อนชา\nน้ำมันพืช: \nต้นหอมซอย:\""
},
{
    'ชื่ออาหาร': 'แกงส้มชะอมไข่ใส่ปลาทู',
    'ingredient_full_json': "\"ชะอมเด็ดเอาแต่ใบ: 1ถ้วย\nไข่ไก่: 1ฟอง\nผักกาดขาว: 1หัว\nหัวไชเท้า: 1หัว\nพริกแกงส้มตามสูตรเคยที่ให้ไว้นะคะ: 3 ช้อน\nน้ำมะขามเปียก: 5 ช้อน\nน้ำตาลปีบ: 2ช้อน\nน้ำปลา: 3ช้อน\nน้ำมันพืชสำหรับทำไข่ชะอม: 1 ช้อนชา\nปลาทูย่างแกะเอาแต่เนื้อ: 2 ตัว\""
},
{
    'ชื่ออาหาร': 'ต้มยำปลากระป๋อง',
    'ingredient_full_json': "\"1.ปลากระป๋อง: 2 กระป๋อง\n2.ข่า: 8 แว่น\n3.ตะไคร้: 3 ต้น\n4.ใบมะกรูด: 5-6 ใบ\n5.หอมแดง: 3 หัว\n6.น้ำเปล่า: 3 ถ้วย\n7.มะนาว: 2 ลูก\n8.น้ำปลา: 1+1/2 ช้อนโต๊ะ\n9.ซุปคนอร์ก้อน: 1 ก้อน\n10.พริกขี้หนูบุบ: 10 เม็ด\n11.ผักชีใบเลื่อย: 3 ใบ\n12.เห็ดนางฟ้า: 1 ถ้วย\""
},
{
    'ชื่ออาหาร': 'แกงส้มใต้มันขี้หนู',
    'ingredient_full_json': "\"มันขี้หนู: 300 กรัม\nปลาทูสดหรือปลาอะไรก็ได้: 4-5 ตัว\nน้ำพริกแกงเหลือง: 2 ช้อนโต๊ะ\nน้ำเปล่า: 4 ถ้วย\nน้ำปลา: 3 ช้อนโต๊ะ\nน้ำตาลปี๊บ: 1 ช้อนโต๊ะ\nน้ำมะขามเปียก: 3 ช้อนโต๊ะ\nส้มแขก: 3 ชิ้น\nน้ำมะนาว: ตามชอบ\nกะปิ: 2 ช้อนชา\""
},
{
    'ชื่ออาหาร': 'สูตร แกงเลียง ระดับเทพ อร่อยกว่าร้านดังแน่นอน',
    'ingredient_full_json': "\"ผักหวาน: 1 กำ\nกวางตุ้งแบบมีดอก: 1 กำ\nชะอม: 1 กำ\nใบแมงลัก: 1 กำ\nบวบ: 5-6 อัน\nฟักทอง: ซีกนึง\nเห็ดนางฟ้า: 1 กำ\nเห็ดหูหนู: 1 กำ\nเห็ดเข็มทอง: 1 กำ\nเห็ดฟาง: 1 กำ\nกุ้ง: ครึ่ง กก\nกระดูกหมู: 1 กิโลกรัม\nพริกกระเหรี่ยง: 1 กำ\nกระชาย: 1 กำ\nหอมแดง: 1 กำ\nกระปิอย่างดี: 2 ช้อนโต๊ะ\nพริกไทยขาว: 2 ช้อนโต๊ะ\nปลาทูนึ่ง: 12 ตัว\nน้ำปลาตราปลาหมึก: ตามความชอบ\""
},
{
    'ชื่ออาหาร': 'ข้าวขาหมู',
    'ingredient_full_json': "\"เนื้อขาหมูที่เลาะกระดูกแล้ว ล้างน้ำให้สะอาด ผึ่งให้หมาด: 1.5 กิโลกรัม\nไข่ต้มแข็ง: 4 ฟอง\nเห็ดหอมแห้งแช่น้ำจนนิ่ม: 8-9 ดอก\nยอดคะน้า: 10-12 ยอด\nโป๊ยกั๊ก: 5 ดอก\nอบเชย: 2 แท่ง\nพริกไทย กระเทียม รากผักชี ตำรวมกัน: 3 ช้อนโต๊ะ\nน้ำเปล่า: 3-4 ลิตร\nน้ำตาลมะพร้าว: 3-4 ช้อนโต๊ะ\nน้ำปลา: 3-4 ช้อนโต๊ะ\nซอสปรุงรส: 3-4 ช้อนโต๊ะ\nซีอิ๊วดำหวาน: 2 ช้อนโต๊ะ\""
},
{
    'ชื่ออาหาร': 'แกงเขียวหวานไก่',
    'ingredient_full_json': "\"เนื้ออกไก่: 2 กิโลกรัม\nเลือดไก่: 2 ก้อน\nเครื่องในไก่: 5-6 พวง\nน้ำพริกแกงเขียวหวาน: 6-8 ขีด แล้วแต่ความเผ็ด\nมะเขือเปราะ: 1/2 กิโลกรัม\nหัวกะทิ: 1 กิโลกรัม\nหางกะทิ: 2 กิโลกรัม\nน้ำปลา: 6 ช้อนโต๊ะ\nเกลือ: 1-2 ช้อนโต๊ะ\nใบโหระพาเด็ด: ปริมาณตามชอบ\nพริกชี้ฟ้าหั่นแฉลบ: ปริมาณตามชอบ\nน้ำตาลปี๊บ: เล็กน้อย\""
},
{
    'ชื่ออาหาร': 'ขนมจีนน้ำยากะทิไก่ไม่เผ็ดสำหรับเด็ก',
    'ingredient_full_json': "\"เนื้อไก่บด (ไก่ต้มที่ได้จากทำน้ำสต็อก): 100 กรัม\nกะทิ (แบ่ง 2ส่วน ส่วนละ150มล): 300 มล.\nพริกแกงเด็ก(ตามสูตรที่ลงไว้): 80 กรัม\nน้ำสต็อกไก่: 2 ถ้วย\nเลือดไก่: 80 กรัม\nน้ำปลา: 2 ช้อนโต๊ะ\nน้ำตาลปี๊บ: 1/2 ช้อนโต๊ะ\nต้นหอมหั่น: 2 ต้น\nใบมะกรูดฉีก: 3 ใบ\nน้ำมันพืช: 1 ช้อนโต๊ะ\nเส้นขนมจีนอัญชัน: ตามชอบ\nผักเครื่องเคียง: ตามชอบ\nไข่ต้ม:\""
},
{
    'ชื่ออาหาร': 'ยำปลากระป๋องทอดกร๊อบกรอบ',
    'ingredient_full_json': "\"ปลากระป๋อง: 3 กระป๋อง\nมะนาว: 3 ลูก\nน้ำปลา: 1 ช้อนโต๊ะ\nต้นหอมหั่นท่อน: 4 ต้น\nพริกขี้หนูซอย: 3 ช้อนโต๊ะ\nแครอทซอยเป็นเส้นๆ: 1 ถ้วย\nขึ้นฉ่ายหั่นท่อน: 1 ต้น\nน้ำตาลทราย: 1 ช้อนชา\nไข่ไก่: 1 ฟอง\nเกล็ดขนมปัง: 1 จาน\nแป้งเอนกประสงค์: 1 จาน\nน้ำมัน:\""
},
{
    'ชื่ออาหาร': 'แกงส้มดอกแคเนื้อปลานินทอดกรอบ',
    'ingredient_full_json': "\"พริกแกงส้ม: 2ขีด\nน้ำเปล่า: 1ลิตร\nน้ำมะขามเปียก: 1ถ้วยเล็ก\nน้ำตาลปี้ป: 1/2ทัพพี\nดอกแค: 20ดอก\nน้ำปลา: 2 ช้อนโต๊ะ\nเนื้อปลานิน: 1ตัว\""
},
{
    'ชื่ออาหาร': 'ผัดเผ็ดปลาดุกพริกสด',
    'ingredient_full_json': "\"ปลาดุก: \nมะเขือเจ้าพระยา: \nใบมะกรูด: \nกระชาย: \nพริกไทยอ่อน: \nซอสปรุงรส: \nน้ำมันหอย: \nผงปรุงรส: \nกระเทียม: \nพริกขี้หนู:\""
},
{
    'ชื่ออาหาร': 'แกงส้มไข่ปลาเรียวเซียว',
    'ingredient_full_json': "\"ยอดมะพร้าว: 200กรัม\nไข่ปลาเรียวเซียว: 200กรัม\nเนื้อปลาช่อน: 100กรัม\nน้ำสต็อก: 2ถ้วย\nพริกแกงส้ม: 1ชต\nข่า ตะไคร้ ใบมะกรูด: 1/2 ถ้วย\nน้ำปลา: 1ชต\nน้ำตาลปี๊บ: 1ชต\nมะขามเปียก: 1/2ถ้วย\""
},
{
    'ชื่ออาหาร': 'หอยทอด(ทะเลทอด)',
    'ingredient_full_json': "\"แป้งทอดกรอบ: 1ถ้วย\nกุ้ง: 12ตัว\nหมึก: 3ตัว\nหอยแมงภู่: 100กรัม\nน้ำเย็ดจัด: 1ถ้วย\nนมสด: 1/2ถ้วย\nไข่ไก่: 3ฟอง\nถั่วงอกดิบ: ตามชอบ\nพริกไทยป่น: ตามชอบ\nซีอิ้วขาว: 2ช้อนโต๊ะ\nน้ำปลา: 1ช้อนโต๊ะ\nน้ำตาล: 1ช้อนโต๊ะ\nต้นหอมผักชี: 2-3ต้น\""
},
{
    'ชื่ออาหาร': 'แกงเทโพหมูสามชั้น',
    'ingredient_full_json': "\"หมูสามชั้น: 200 กรัม\nผักบุ้ง: 500 กรัม\nพริกแกงเผ็ด: 100 กรัม\nมะขามเปียก: 1 กำ\nน้ำตาลมะพร้าว: 1 ช้อนโต๊ะ\nน้ำปลา: เหยาะๆ ลงไป\nมะกรูด: 3 ลูก\nใบมะกรูด: 10 ใบ\nกะทิ: 1000 มล\""
},
{
    'ชื่ออาหาร': 'เส้นหมี่ผัดซีอิ๊วหมูนุ่ม',
    'ingredient_full_json': "\"เส้นหมี่สำเร็จรูป: 180 กรัม\nหมูนุ่ม: 200 กรัม\nกระเทียมสับ: 1 ช้อนโต๊ะ\nน้ำมันพืช: 2-3 ช้อนโต๊ะ\nซีอิ๊วดำสำหรับคลุกเส้น: \nซีอิ๊วขาว: 3 ช้อนโต๊ะ\nน้ำปลา: 1 ช้อนโต๊ะ\nน้ำตาลทราย: 1 ช้อนชา\nผักคะน้า: 2 ต้น\nไข่ไก่เบอร์ 1: 3 ฟอง\""
},
{
    'ชื่ออาหาร': 'แกงเผ็ดเป็ดย่าง',
    'ingredient_full_json': "\"เนื้อเป็ดย่างพร้อมหนัง: 1ถ้วย\nมะเขือเทศ: 5-6ลูก\nสับปะรดหั่น: 20 ชิ้น\nมะเขือพวง: 1/4ถ้วย\nใบโหระพาเด็ด: 2ต้น\nพริกแกง: 2-4ช้อนโต๊ะ\nกะทิ: 1กล่อง\nน้ำตาลปิ้บ: 2ช้อนโต๊ะ\nน้ำปลา: 1/4ถ้วย\""
},
{
    'ชื่ออาหาร': 'ต้มยำกุ้งมะพร้าวอ่อน',
    'ingredient_full_json': "\"พริกขี้หนู: 7 เม็ด\nตะไคร้: เล็กน้อย\nใบมะกรูด: เล็กน้อย\nข่า: เล็กน้อย\nผักชีฝรั่ง: เล็กน้อย\nเห็ดนางฟ้า: 70 กรัม\nเห็ดหลินขาว: 40 กรัม\nเห็ดฟาง: 100 กรัม\nเนื้อมะพร้าวอ่อน: 80 กรัม\nน้ำมะพร้าว: 700 ml.\nกุ้งแกะเปลือก: 200 กรัม\nน้ำตาลทราย: 2 ช้อนชา\nน้ำปลา: 6 ช้อนโต๊ะ\nน้ำมะนาว: 6 ช้อนโต๊ะ\nกะทิ: 100 ml.\nน้ำพริกเผา: 2 ช้อนโต๊ะ\nมันกุ้ง: 1 ช้อนโต๊ะ\""
},
{
    'ชื่ออาหาร': 'หมูทอดกระเทียม',
    'ingredient_full_json': "\"หมูสันนอก หั่นชิ้น: 250 กรัม\nรากผักชี กระเทียม พริกไทยโขลกละเอียด: 1/2 ช้อนโต๊ะ\nผงปรุงรส: 1 ช้อนโต๊ะ\nแป้งข้าวโพด: 1 ช้อนโต๊ะ\nน้ำมันพืช: สำหรับทอด\nกระเทียมเจียว (โรยหน้า): ตามชอบ\""
},
{
    'ชื่ออาหาร': 'หน่อไม้ผัดพริกแกงหมูสับ',
    'ingredient_full_json': "\"หน่อไม้ต้ม ซอยบางๆ: 1 ถ้วย\nน้ำพริกแกงเผ็ด: 2 ช้อนโต๊ะ\nหมูสับ: 1/4 ถ้วย\nใบมะกรูดฉีก: 4-5 ใบ\nพริกไทยอ่อนตัดสั้นๆ: 3-4 ฝัก\nพริกชี้ฟ้าซอย: 1 เม็ด\nน้ำตาลทราย: 1/2 ช้อนโต๊ะ\nน้ำปลา: 1-2 ช้อนโต๊ะ\""
},
{
    'ชื่ออาหาร': 'ขนมจีนน้ำพริก',
    'ingredient_full_json': "\"กะทิ: 750 มล\nไตปลา: 3 ชต\nกุ้ง: ½ โล\nพริกแกงแดง: 1 ขีด\nหอมเจียว: 1 ถ้วย\nกระเทียมเจียว: 1 ถ้วย\nถั่วป่น: 1 ถ้วย\nระกำ หรือมะขามเปียก: ตามชอบ\nน้ำตาลปี๊บ: 2 ชต\nผักชี: ตามชอบ\""
},
{
    'ชื่ออาหาร': 'ฉู่ฉี่ปลาหมอ',
    'ingredient_full_json': "\"ปลาหมอตัวใหญ่ๆ: 2 ตัว\nเครื่องแกงผัดเผ็ดภาคกลาง: 200 กรัม\nเครื่องแกงพะแนงกับกระชายสับละเอียด: 100 กรัม\nกระชายซอย: 50 กรัม\nใบมะกรูดซอย: 20 กรัม\nกะทิคั้น: 400 กรัม\nคะไคร้หั่นท่อน: 2 ต้น\nข่า: 20 กรัม\nใบมะกรูดฉีก: 15 กรัม\nพริกขี้หนูสวน: 10-15 เม็ด\""
},
{
    'ชื่ออาหาร': 'แกงเทโพใส่หมูสามชั้น',
    'ingredient_full_json': "\"หมูสามชั้น (หั่นชิ้นพอคำ ไม่ต้องหนามาก): 200 กรัม\nผักบุ้งไทย (หั่นท่อนพอคำ ล้างให้สะอาด): 400 กรัม\nหัวกะทิ: 1 ถ้วย\nหางกะทิ: 2 1/2 ถ้วย\nน้ำมะขามเปียก: 3-4 ช้อนโต๊ะ\nน้ำตาลปี๊บ: 1 ช้อนโต๊ะ\nน้ำปลา: 3 ช้อนโต๊ะ\nมะกรูด ผ่าครึ่ง เอาเมล็ดออก): 2 ลูก\nเกลือ: 1 ช้อนชา\nใบมะกรูด: 4-5 ใบ\nผงปรุงรสคนอร์ อร่อยชัวร์: 2 ช้อนชา\nน้ำพริกแกงเผ็ด: 100 กรัม\""
},
{
    'ชื่ออาหาร': 'ขนมจีนน้ำยาป่าปลาดุกย่าง',
    'ingredient_full_json': "\"ปลาดุกย่าง: 2 ตัว\nกระเทียม: 5 กลีบ\nหอมแดง: 5 หัว\nกระชาย: 8 ราก\nตะไคร้: 2 ต้น\nใบมะกรูด​: 10 ใบ\nพริกแห้ง: 7 เม็ด\nขนมจีน: 1 กิโล​กรัม\nน้ำเปล่า: 6 ถ้วย\nเกลือ: ปรุงรส\""
},
{
    'ชื่ออาหาร': 'ผัดเปรี้ยวหวานไก่กรอบ',
    'ingredient_full_json': "\"สันในไก่หั่นชิ้นพอดีคำ: 2-3 เส้น\nแป้งอเนกประสงค์: 1 ถ้วย\nหอมใหญ่ปอก หั่นเสี้ยว: 1 ลูก\nมะเขือเทศสีดาผ่าครึ่ง: 2-3 ลูก\nพริกหวานหั่นพอดีคำ: 1/2 ลูก\nแตงร้าน ปอกเปลือก หั่นชิ้นพอดีคำ: 1/2 ลูก\nเห็ดหอมสดผ่าสี่: 2 ดอก\nต้นหอมหั่นท่อน: 3-4 ต้น\nกระเทียมสับ: 1 ช้อนโต๊ะ\nน้ำตาลทราย: 1 ช้อนโต๊ะ\nซอสปรุงรส: 1 ช้อนโต๊ะ\nซอสมะเขือเทศ: 1/2 ถ้วย\nน้ำส้มสายชู: 1 ช้อนโต๊ะ\""
},
{
    'ชื่ออาหาร': 'บะหมี่ผัดเย็นตาโฟแห้ง',
    'ingredient_full_json': "\"บะหมี่: 1\nลูกชิ้นปลา: ตามชอบ\nลูกชิ้นกุ้ง: ตามชอบ\nฮื่อก๊วย: ตามชอบ\nเกี๊ยวปลา: ตามชอบ\nปลาหมึกกรอบ: ตามชอบ\nผักบุ้งไทย: ตามชอบ\nซอสเย็นตาโฟ: 1\nพริกแดงจินดา: 4-5 เม็ด\nกระเทียม: 3-4 กลีบ\nซอสหอยนางรม: 1/2 ช้อนโต๊ะ\nน้ำตาล: 1/2 ช้อนชา\nซีอิ๊วขาว: 1/2 ช้อนชา\nน้ำส้มสายชู: 1 ช้อนชา\nน้ำมัน: 1/2 ช้อนโต๊ะ\""
},
{
    'ชื่ออาหาร': 'แกงเขียวหวานไก่ใส่หน่อไม้',
    'ingredient_full_json': "\"ไก่สับ: 1/2 ตัว\nเลือดไก่: 1 ก้อน\nมะเขือเปราะ: 500 กรัม\nหน่อไม้: 1 หน่อ\nโหระพา: 4 กิ่ง\nพริกแกงเขียวหวาน: 150 กรัม\nกะทิ: 1000 มิลลิลิตร\nน้ำตาลปี๊บ: 1 ช้อนโต๊ะ\nผงปรุงรส: 2 ก้อน\nน้ำปลา: 2 ช้อนโต๊ะ\nมะเขือพวง: 50 กรัม\""
}]

new_recipe_df = pd.DataFrame(new_recipe_data)

def parse_ingredient_string(ingredient_str):
    lines = ingredient_str.strip('"').split('\n')
    result = {}
    for line in lines:
        if ':' in line:
            parts = line.split(':', 1)
            name = parts[0].strip()
            quantity = parts[1].strip()
            result[name] = quantity
    return result

new_recipe_df['simplified_ingredients'] = new_recipe_df['ingredient_full_json'].apply(parse_ingredient_string)

def find_closest_match(ingredient, thai_names):
    matches = get_close_matches(ingredient, thai_names, n=1, cutoff=0.3)
    return matches[0] if matches else None

def calculate_calories(fat, protein, carbs):
    return (fat * 9) + (protein * 4) + (carbs * 4)


def process_recipe(row, skip_unmatched=True):
    food_name = row['ชื่ออาหาร']
    raw_ingredients = row['ingredient_full_json']
    ingredients = parse_ingredient_string(raw_ingredients)
    nutrition_info_dict = {}

    print(f"\nProcessing recipe: {food_name}")
    for ing_name, quantity in ingredients.items():
        closest = find_closest_match(ing_name, nutrition_data['Thai_Name'].astype(str))
        if closest:
            nut_info = nutrition_data[nutrition_data['Thai_Name'] == closest]
            try:
                fat = float(nut_info['Fat(g)'].iloc[0])
                protein = float(nut_info['Protein(g)'].iloc[0])
                carbs_raw = nut_info['Carbs(g)'].iloc[0]
                carbs = float(carbs_raw) if carbs_raw not in ['-', ''] else 0
                cal = calculate_calories(fat, protein, carbs)

                nutrition_info_dict[closest] = {
                    'fat': fat,
                    'protein': protein,
                    'carbs': carbs,
                    'calories': cal
                }

                print(f"Matched: {ing_name} → {closest}, Calories: {cal:.2f}")
            except Exception as e:
                print(f"Error parsing values for: {closest} | Error: {e}")
        else:
            if skip_unmatched:
                print(f"Skipped (no match): {ing_name}")
            else:
                raise ValueError(f"No match found for: {ing_name}")


    total_protein = round(sum(info.get('protein', 0) for info in nutrition_info_dict.values()), 1)
    total_fat = round(sum(info.get('fat', 0) for info in nutrition_info_dict.values()), 1)
    total_carbs = round(sum(info.get('carbs', 0) for info in nutrition_info_dict.values()), 1)
    total_calories = round(sum(info.get('calories', 0) for info in nutrition_info_dict.values()), 1)

    print(f"\nTotal protein for {food_name}: {total_protein:.2f} g")
    print(f"Total fat for {food_name}: {total_fat:.2f} g")
    print(f"Total carbs for {food_name}: {total_carbs:.2f} g")
    print(f"Total calories for {food_name}: {total_calories:.2f} kcal")
    return {'total_protein': total_protein, 'total_fat': total_fat,
            'total_carbs': total_carbs, 'total_calories': total_calories}

new_recipe_df = pd.DataFrame(new_recipe_data)

new_recipe_df['nutrition_info'] = new_recipe_df.apply(process_recipe, axis=1)

nutrition_df = pd.DataFrame(new_recipe_df['nutrition_info'].tolist())
final_df = pd.concat([new_recipe_df, nutrition_df], axis=1)

for column in final_df.columns:
    if column != 'simplified_ingredients':
        final_df[column] = final_df[column].astype(str)

from google.colab import sheets
sheet = sheets.InteractiveSheet(df=final_df)
# Out:
# Processing recipe: ก๋วยเตี๋ยวคั่วไก่ แบบง่าย
#
# Total protein for ก๋วยเตี๋ยวคั่วไก่ แบบง่าย: 0.00 g
# Total fat for ก๋วยเตี๋ยวคั่วไก่ แบบง่าย: 0.00 g
# Total carbs for ก๋วยเตี๋ยวคั่วไก่ แบบง่าย: 0.00 g
# Total calories for ก๋วยเตี๋ยวคั่วไก่ แบบง่าย: 0.00 kcal
#
# Processing recipe: ข้าวหมูแดง ไมโครเวฟ
#
# Total protein for ข้าวหมูแดง ไมโครเวฟ: 0.00 g
# Total fat for ข้าวหมูแดง ไมโครเวฟ: 0.00 g
# Total carbs for ข้าวหมูแดง ไมโครเวฟ: 0.00 g
# Total calories for ข้าวหมูแดง ไมโครเวฟ: 0.00 kcal
#
# Processing recipe: ข้าวไข่ข้นกุ้ง
#
# Total protein for ข้าวไข่ข้นกุ้ง: 0.00 g
# Total fat for ข้าวไข่ข้นกุ้ง: 0.00 g
# Total carbs for ข้าวไข่ข้นกุ้ง: 0.00 g
# Total calories for ข้าวไข่ข้นกุ้ง: 0.00 kcal
#
# Processing recipe: แกงเขียวหวานไก่ ไมโครเวฟ
#
# Total protein for แกงเขียวหวานไก่ ไมโครเวฟ: 0.00 g
# Total fat for แกงเขียวหวานไก่ ไมโครเวฟ: 0.00 g
# Total carbs for แกงเขียวหวานไก่ ไมโครเวฟ: 0.00 g
# Total calories for แกงเขียวหวานไก่ ไมโครเวฟ: 0.00 kcal
#
# ...

# %%
#part 2
import pandas as pd
from difflib import get_close_matches

nutrition_data = pd.read_csv("imgrediemtdnewnew.csv")

new_recipe_data = [
   {
    'ชื่ออาหาร': 'ก๋วยเตี๋ยวคั่วไก่ แบบง่าย',
    'ingredient_full_json': "\"เส้นใหญ่300กรัม\nไข่ไก่2 ฟอง\nซีอิ๊วขาว2 ช้อนโต๊ะ\nน้ำตาล2 ช้อนชา\nเกลือ 1/2 ช้อนชา1/2 ช้อนชา\nต้นหอม ผักชีซอย1 ช้อนโต๊ะ\nน้ำมันพืชหรือน้ำมันหมูเล็กน้อย\n--เครื่องปรุงหมักไก่--\nอกไก่หั่นชิ้นพอคำ200 กรัม\nน้ำตาลทราย1 ช้อนชา\nแป้งมัน1 ช้อนโต๊ะ\nพริกไทย1/2 ช้อนชา\""
},
{
    'ชื่ออาหาร': 'ขนมจีนน้ำยากะทิตีนไก่',
    'ingredient_full_json': "\"เนื้อไก่บดละเอียด3 ขีด\nน้ำกะทิคั้นครึ่งโล\nพริกแกงเผ็ด2 ขีด\nกระชาย1 หัว\nใบมะกรูด4-5 ใบ\nตีนไก่1 โล\nเลือดไก่1 ก้อน\nลูกชิ้นปลาครึ่งโล\nน้ำตาลทรายแดง3 ช้อนโต๊ะ\nเกลือ1 ช้อนโต๊ะ\nรสดี1 ช้อนโต๊ะ\nขนมจีน1 โล\nผักเคียงตามชอบ\""
},
{
    'ชื่ออาหาร': 'ก๋วยเตี๋ยวคั่วไก่ แบบง่าย แต่อร่อย',
    'ingredient_full_json': "\"เส้นใหญ่300กรัม\nไข่ไก่2 ฟอง\nซีอิ๊วขาว2 ช้อนโต๊ะ\nน้ำตาล2 ช้อนชา\nเกลือ 1/2 ช้อนชา1/2 ช้อนชา\nต้นหอม ผักชีซอย1 ช้อนโต๊ะ\nน้ำมันพืชหรือน้ำมันหมูเล็กน้อย\n--เครื่องปรุงหมักไก่--\nอกไก่หั่นชิ้นพอคำ200 กรัม\nน้ำตาลทราย1 ช้อนชา\nแป้งมัน1 ช้อนโต๊ะ\nพริกไทย1/2 ช้อนชา\""
},
{
    'ชื่ออาหาร': 'ผัดเผ็ดไก่บ้าน',
    'ingredient_full_json': "\"ไก่บ้านครึ่งกิโลกรัม\nพริกแกง2​ ช้อนโต๊ะ\nน้ำมันพืช2​ ช้อนโต๊ะ\nใบมะกรูด8​ ใบ\nใบกะเพรา1​ กำมือ\nน้ำปลา1​ ช้อนโต๊ะ\nซอสปรุงรส1​ ช้อนชา\nน้ำตาลครึ่งช้อนชา\""
},
{
    'ชื่ออาหาร': 'ข้าวต้มหมูสับ',
    'ingredient_full_json': "\"ข้าวสวย(ข้าวเย็น)2 ถ้วย\nน้ำเปล่า(สำหรับต้มข้าว)ให้ท่วมข้าวที่ต้ม\nส่วนผสมน้ำซุป\nน้ำเปล่า1 ลิตร\nคนอร์ซุปก้อนหมู2 ก้อน\nหมูสับ200 กรัม\nรากผักชี+กระเทียม+พริกไทย2 ช้อนชา\nน้ำปลา1 ช้อนโต๊ะ\nกระเทียมเจียวตามชอบ\nต้นหอมซอย+ผักชีซอยอย่างละ 1 ต้น\nพริกไทยป่นตามชอบ\nพริกน้ำส้ม ตามชอบ\""
},
{
    'ชื่ออาหาร': 'ข้าวต้มหมูสับ',
    'ingredient_full_json': "\"เนื้อหมูสับ2 ขีด\nข้าวสวย1 ทัพพี\nต้นหอม1 ต้น\nผักชี1 ต้น\nซีอิ๊วขาว1 ช้อนชา\nน้ำตาล1 ช้อนชา\nคนอร์ รสหมูสับครึ่งก้อน\""
},
{
    'ชื่ออาหาร': 'เส้นแก้วผัดสุกี้แห้ง',
    'ingredient_full_json': "\"น้ำจิ้มสุกี้สูตรกวางตุ้ง 150 กรัม\nเส้นแก้ว (แบบเส้นเล็ก) 200 กรัม\nกระเทียม 1 ช้อนโต๊ะ\nน้ำมันหอย 1 ช้อนโต๊ะ\nพริกไทย ตามชอบ\nหมูชิ้น 100 กรัม\nกุ้ง 100 กรัม\nผักบุ้ง 50 กรัม\nแคร์รอต 50 กรัม\nผักกาดขาว 50 กรัม\nไข่ไก่ 3 ฟอง\nต้นหอมหั่นท่อน 20 กรัม\nขึ้นฉ่าย 10 กรัม\nน้ำมันพืช 2 ช้อนโต๊ะ\""
},
{
    'ชื่ออาหาร': 'ข้าวมันไก่สามสหาย',
    'ingredient_full_json': "\"ข้าวหอมมะลิ 300 กรัม\nน้ำซุปกระดูกไก่ 390 มิลลิลิตร\nกระเทียม 4-5 กลีบ\nรากผักชี 4-5 ราก \nขิงแก่ฝานแผ่นบาง 6 แผ่น\nน้ำมันพืช 40 มิลลิลิตร สะโพกไก่ 600 กรัม แบ่งเป็น 3 ส่วน \nสามเกลอ 2 ช้อนโต๊ะ สำหรับหมักไก่ \nซอสหอยนางรม 3 ช้อนโต๊ะ สำหรับหมักไก่ \nซอสปรุงรส 3 ช้อนโต๊ะ สำหรับหมักไก่\nน้ำตาล 2 ช้อนโต๊ะ สำหรับหมักไก่\nแป้งทอดกรอบ 200 กรัม สำหรับทำไก่ทอด \nน้ำสะอาด 150 มิลลิลิตร สำหรับทำไก่ทอด\nเกลือ 1 ช้อนชา สำหรับทำไก่ต้ม\nรากผักชี 3-5 ราก สำหรับทำไก่ต้ม \nกระเทียม 5-7 กลีบ สำหรับทำไก่ต้ม\""
},
{
    'ชื่ออาหาร': 'ข้าวหมูแดง ไมโครเวฟ',
    'ingredient_full_json': "\"สันในหมู 400 กรัม\nน้ำมันงา 1 ช้อนโต๊ะ\nซอสหอยนางรม 1 ช้อนโต๊ะ\nซีอิ๊วขาว 1 ช้อนโต๊ะ\nผงหมักหมูแดง 4 ช้อนโต๊ะ\nน้ำผึ้ง 1 ช้อนโต๊ะ\nเหล้าจีน 1 ช้อนโต๊ะ\nน้ำเปล่า 1 ถ้วยตวง\nรากผักชี กระเทียม พริกไทย โขลก 2 ช้อนโต๊ะ\nแป้งข้าวโพด 1 ช้อนโต๊ะ\""
},
{
    'ชื่ออาหาร': 'ไข่ตุ๋นแกงเขียวหวาน',
    'ingredient_full_json': "\"ไข่ไก่สด เบอร์ 2 5\nพริกแกงเขียวหวาน\nน้ำเชื่อม 1 ช้อนโต๊ะ\nน้ำปลา 1 ช้อนโต๊ะ\nนมสดจืด ¼ ถ้วยตวง\nปูอัด 50 กรัม\nไส้กรอกไก่ 50 กรัม\nพริกชี้ฟ้าแดงสำหรับตกแต่ง\nโหระพาสำหรับตกแต่ง\""
},
{
    'ชื่ออาหาร': 'แกงเขียวหวานไก่ ไมโครเวฟ',
    'ingredient_full_json': "\"กะทิสำเร็จรูป 1 กล่อง\nน้ำพริกแกงเขียวหวาน 2 ช้อนโต๊ะ\nน้ำ 1/2 ถ้วย\nน้ำปลา 1 ช้อนโต๊ะ\nน้ำตาลปี๊บ 1 ช้อนโต๊ะ\nเนื้อไก่ หั่นเป็นชิ้น 200 กรัม\nมะเขือเปราะ หั่นสี่ส่วน 4 ลูก\nใบมะกรูดฉีก 3 ใบ\nใบโหระพา 1 ถ้วย\nพริกชี้ฟ้าแดงซอย 1 เม็ด\""
},
{
    'ชื่ออาหาร': 'ต้มยำกุ้งน้ำข้นยอดมะพร้าว',
    'ingredient_full_json': "\"กุ้งสด 400 กรัม\nเห็ดตามชอบ 100 กรัม\nมะเขือเทศ 4 ลูก\nพริกขี้หนู 10 เม็ด\nใบมะกรูด 3-4 ใบ\nตะไคร้ 1 ก้าน\nยอดมะพร้าว 120 กรัม\nข่าหั่นแว่น 4 ชิ้น\nมะนาว 2 ลูก\nน้ำพริกเผา 4 ช้อนโต๊ะ\nนมข้นจืด 100 กรัม\nน้ำปลา 2 ช้อนโต๊ะ\nน้ำเปล่า 1 ลิตร\nผักชีฝรั่ง ตามชอบ\""
},
{
    'ชื่ออาหาร': 'แกงเลียงกุ้งสด',
    'ingredient_full_json': "\"nan\""
},
{
    'ชื่ออาหาร': 'แกงเลียงกุ้งสด',
    'ingredient_full_json': "\"กุ้งสดปอกเปลือกผ่าหลัง250กรัม\nข้าวโพดอ่อนหั่น80กรัม\nฟักทองหั่นชิ้นพอดีคำ240กรัม\nบวบหั่นเป็นชิ้นๆ230กรัม\nเห็ดรวม (ตามชอบ)250กรัม\nใบแมงลัก1ถ้วย\nน้ำซุป4ถ้วย\nน้ำปลา2ช้อนโต๊ะ\nซีอิ๊วขาว1ช้อนโต๊ะ\nน้ำตาล1ช้อนชา\n---พริกแกงเลียง--\nหอมแดง6หัว\nกุ้งแห้งป่น3ช้อนโต๊ะ\nกุ้งสดลวก3ตัว\nกระชาย3แง่ง\nพริกไทยเม็ด1ช้อนโต๊ะ\nกะปิ1 1/2ช้อนโต๊ะ\nพริกขี้หนูสวน8เม็ด\nรากผักชี1ราก\""
},
{
    'ชื่ออาหาร': 'ผัดเปรี้ยวหวานหมู',
    'ingredient_full_json': "\"เนื้อหมูสไลด์250 กรัม\nหอมหัวใหญ่ หั่นชิ้นพอดีคำ1 หัว\nแตงกวาลูกเล็ก หั่วชิ้นพอดีคำ5 ลูก\nมะเขือเทศ หั่นชิ้นพอดีคำ1 ลูก\nกระเทียมสับ1 ช้อนโต๊ะ\nต้นหอม หั่นยาว2 ต้น\nซอสปรุงรสตามชอบ\nน้ำตาลตามชอบ\nซอสมะเขือเทศ3 ช้อนโต๊ะ\nน้ำมันหอยตามชอบ\""
},
{
    'ชื่ออาหาร': 'ผัดพริกแกงหมูสับถั่วฝักยาว',
    'ingredient_full_json': "\"หมูสับ100 กรัม\nน้ำพริกแกงเผ็ด2 ช้อนโต๊ะ\nถั่วฝักยาว ล้างให้สะอาดแล้วหั่นท่อนสั้นๆ1 ถ้วย\nน้ำมันสำหรับผัด2 ช้อนโต๊ะ\nน้ำตาลทราย1 ช้อนโต๊ะ\nน้ำปลา1 ช้อนโต๊ะ\""
},
{
    'ชื่ออาหาร': 'ผัดเผ็ดไก่หน่อไม้ดอง',
    'ingredient_full_json': "\"เนื้ออกไก่ (เลาะหนังออก)1 อกใหญ่\nหน่อไม้ดอง1/2 กก.\nพริกชี้ฟ้าแดงและเขียว30 เม็ด หรือตามชอบ\nกระเทียม20 กลีบ\nใบโหระพาเด็ด2 ต้น\nน้ำปลา2 ช้อนโต๊ะ\nน้ำตาล1 ช้อนโต๊ะ\nน้ำมันหอย2 ช้อนโต๊ะ\nน้ำเปล่า (ไว้สำหรับล้างพริกแกงก้นครก)3-4 ช้อนโต๊ะ\""
},
{
    'ชื่ออาหาร': 'ผัดกะเพราหมูสับไข่ดาว',
    'ingredient_full_json': "\"ซอสผัดกะเพราพริกแห้ง 60 กรัม\nหมูสับ 200 กรัม\nใบกะเพรา 50 กรัม\nไข่ไก่ 1 ฟอง\nน้ำสะอาดเล็กน้อย\""
},
{
    'ชื่ออาหาร': 'แกงส้มผักรวมกุ้งสด',
    'ingredient_full_json': "\"พริกแกงส้ม 1 ช้อนโต๊ะ\nน้ำเปล่า 3-4 ถ้วยตวง\nกุ้งสด 5 ตัว\nน้ำมะขามเปียกข้น ๆ 1 ช้อนโต๊ะ\nน้ำตาลปี๊บ 1 ช้อนโต๊ะ\nน้ำปลา 1 ช้อนโต๊ะ\nผักรวม เช่น แครอท ข้าวโพดอ่อน กะหล่ำปลี ถั่วฝักยาว อย่างละ ¼ ถ้วยตวง\""
},
{
    'ชื่ออาหาร': 'ก๋วยเตี๋ยวคั่วไก่ สูตรคลีน',
    'ingredient_full_json': "\"เนื้อไก่ 100 กรัม\nน้ำตาลทรายไม่ขัดสี ½ ช้อนชา\nพริกไทยป่น 1 ช้อนชา\nซีอิ๊ว Low Sodium 1 ช้อนชา เครื่องปรุงก๋วยเตี๋ยวคั่วไก่\nเส้นแครอท 1 ถ้วยตวง\nไข่ไก่ 1 ฟอง\nซีอิ๊วขาว Low Sodium 1 ช้อนชา\nซอสหอยนางรม Low Sodium 1 ช้อนชา\nน้ำมันพืช สำหรับผัด 1 ช้อนชา\nต้นหอมซอย 1 ต้น\nพริกไทยป่น 1 ช้อนชา\""
},
{
    'ชื่ออาหาร': 'แกงส้มผักรวมกุ้งสด',
    'ingredient_full_json': "\"พริกแกงส้ม 1 ช้อนโต๊ะ\nน้ำเปล่า 3-4 ถ้วยตวง\nกุ้งสด 5 ตัว\nน้ำมะขามเปียกข้น ๆ 1 ช้อนโต๊ะ\nน้ำตาลปี๊บ 1 ช้อนโต๊ะ\nน้ำปลา 1 ช้อนโต๊ะ\nผักรวม เช่น แครอท ข้าวโพดอ่อน กะหล่ำปลี ถั่วฝักยาว อย่างละ ¼ ถ้วยตวง\""
},
{
    'ชื่ออาหาร': 'ไข่เจียวหมูสับผัดกะเพรา',
    'ingredient_full_json': "\"ไข่ไก่ 4 ฟอง \nหมูสับ 100 กรัม \nใบกะเพรา 50 กรัม \nพริกสับ 2 ช้อนโต๊ะ \nกระเทียมสับ 2 ช้อนโต๊ะ \nซอสหอยนางรม 1 ช้อนโต๊ะ \nน้ำปลา 1 ช้อนโต๊ะ \nน้ำตาล 1 ช้อนชา\""
},
{
    'ชื่ออาหาร': 'แกงเลียงกุ้งสด',
    'ingredient_full_json': "\"กุ้งสดปอกเปลือกผ่าหลัง: 250กรัม\nข้าวโพดอ่อนหั่น: 80กรัม\nฟักทองหั่นชิ้นพอดีคำ: 240กรัม\nบวบหั่นเป็นชิ้นๆ: 230กรัม\nเห็ดรวม (ตามชอบ): 250กรัม\nใบแมงลัก: 1ถ้วย\nน้ำซุป: 4ถ้วย\nน้ำปลา: 2ช้อนโต๊ะ\nซีอิ๊วขาว: 1ช้อนโต๊ะ\nน้ำตาล: 1ช้อนชา\n---พริกแกงเลียง--: \nหอมแดง: 6หัว\nกุ้งแห้งป่น: 3ช้อนโต๊ะ\nกุ้งสดลวก: 3ตัว\nกระชาย: 3แง่ง\nพริกไทยเม็ด: 1ช้อนโต๊ะ\nกะปิ: 1 1/2ช้อนโต๊ะ\nพริกขี้หนูสวน: 8เม็ด\nรากผักชี: 1ราก\""
},
{
    'ชื่ออาหาร': 'มาม่าผัดขี้เมาทะเล',
    'ingredient_full_json': "\"กุ้ง เนื้อปลา ปลาหมึก: ไม่ต้องเยอะมากอะ กะเอาเอง\nมาม่าบิ๊กแพ๊ครสต้มยำ: 1 ซอง\nใบโหระพา: \nเม็ดพริกไทย: \nไข่ไก่: \nพริกขี้หนูสด: \nกระเทียม: \nซีอิ๊วดำ:\""
},
{
    'ชื่ออาหาร': 'ผัดพริกแกงหมูสับถั่วฝักยาว',
    'ingredient_full_json': "\"หมูสับ: 100 กรัม\nน้ำพริกแกงเผ็ด: 2 ช้อนโต๊ะ\nถั่วฝักยาว ล้างให้สะอาดแล้วหั่นท่อนสั้นๆ: 1 ถ้วย\nน้ำมันสำหรับผัด: 2 ช้อนโต๊ะ\nน้ำตาลทราย: 1 ช้อนโต๊ะ\nน้ำปลา: 1 ช้อนโต๊ะ\""
},
{
    'ชื่ออาหาร': 'ผัดเผ็ดไก่หน่อไม้ดอง',
    'ingredient_full_json': "\"เนื้ออกไก่ (เลาะหนังออก): 1 อกใหญ่\nหน่อไม้ดอง: 1/2 กก.\nพริกชี้ฟ้าแดงและเขียว: 30 เม็ด หรือตามชอบ\nกระเทียม: 20 กลีบ\nใบโหระพาเด็ด: 2 ต้น\nน้ำปลา: 2 ช้อนโต๊ะ\nน้ำตาล: 1 ช้อนโต๊ะ\nน้ำมันหอย: 2 ช้อนโต๊ะ\nน้ำเปล่า (ไว้สำหรับล้างพริกแกงก้นครก): 3-4 ช้อนโต๊ะ\""
},
{
    'ชื่ออาหาร': 'แกงเขียวหวานหมู (มือใหม่หัดแกง)',
    'ingredient_full_json': "\"เนื้อหมู: 1 Kg\nพริกแกงเขียวหวาน: 2 ขีด\nหัวกะทิ: 500 ml\nใบโหระพา: \nมะเขือเปราะ: \nมะเขือพวง: \nพริกชี้ฟ้า: \nใบมะกรูด: \nน้ำตาลมะพร้าว: \nน้ำปลา: \nน้ำมันพืช:\""
},
{
    'ชื่ออาหาร': 'แกงส้มปลากระพงผักรวม (แกงส้มปักษ์ใต้)',
    'ingredient_full_json': "\"ปลากระพง(ประมาณ1กิโล): 1ตัว\nพริกแกงเหลือง: 3-4ช้อนโต๊ะ\nผักตามชอบ(มะละกอ แครอท ถั่วฟักยาว: ตามชอบ\nส้มแขก: 4-5ชิ้น\nน้ำปลา: 3-4ช้อนโต๊ะ\nน้ำตาล: 2-3ช้อนโต๊ะ\""
},
{
    'ชื่ออาหาร': 'ต้มยำกุ้งน้ำใส',
    'ingredient_full_json': "\"กุ้งไซส์กลาง-ใหญ่ 6 ตัว: \nเห็ดฟาง 200 กรัม: \nข่าหั่นเป็นชิ้นบางๆ 15 ชิ้น: \nตะไคร้ 3 ต้น: \nใบมะกรูด 5 ใบ: \nหอมแดง 5 หัว: \nพริกขี้หนูสวน 10 เม็ด: \nคนอร์ขวดซอสข้นปรุงรส 2 ช้อนโต๊ะ: \nมะนาว 6 ช้อนโต๊ะ: \nน้ำปลา 2 ช้อนโต๊ะ:\""
},
{
    'ชื่ออาหาร': 'แกงส้มใต้',
    'ingredient_full_json': "\"มะละกอ: 1 ลูก\nปลาทับทิม: 1 ตัว\nน้ำพริกแกงส้มใต้: 1 ซอง\nน้ำมะขามเปียก: 5 ช้อนโต๊ะ\nน้ำปลา: 3 ช้อนโต๊ะ\nเกลือ: 1 ช้อนชา\nน้ำตาลปีบ: 1 ช้อนโต๊ะ\""
},
{
    'ชื่ออาหาร': 'ปลาเผาผักสด/เมี่ยงปลาเผา/ปลานิลเผาเกลือ แบบใช้เตาอบ',
    'ingredient_full_json': "\"ปลา: 1 ตัว\nเกลือป่น: 250 กรัม\nแป้งสาลีเอนกประสงค์หรือแป้งมัน: 1 ช้อนโต๊ะ\nตะไคร้: 2ต้น\nใบเตย: 2 ใบ\nผักแกล้มผักต่างๆตามชอบ: \nซีฟู้ดกุ้ง,ปลาหมึก ตามชอบ: \nเส้นหมี่ ตามชอบ:\""
},
{
    'ชื่ออาหาร': 'น้ำพริกกะปิสูตรคุณยาย',
    'ingredient_full_json': "\"กะปิ: 1 ทัพพี\nน้ำตาลปี๊บ: 1 ทัพพี\nพริกสด: 1 กำมือ\nกระเทียม: 1 กำมือ\nมะเขือพวง: 1/2 ถ้วย\nน้ำมะนาวคั้นสด: 1 ทัพพี\nน้ำเปล่า: 1 ทัพพี\""
},
{
    'ชื่ออาหาร': 'แกงเขียวหวานไก่',
    'ingredient_full_json': "\"น้ำพริกแกงเขียวหวาน(สำเร็จรูป): \nกะทิ (กล่องใหญ่1 กล่อง+กล่องเล็กสุด 1 กล่อง): \nไก่สด+เครื่องใน: \nเลือดไก่(ก้อน): \nมะเขือเปราะ: \nมะเขือพวง: \nใบโหระพา: \nพริกชีฟ้าสีแดง: \nพริกขี้หนูสด: \nน้ำตาล:\""
},
{
    'ชื่ออาหาร': 'แกงส้มมะละกอปลากระป๋อง',
    'ingredient_full_json': "\"มะละกอออกสีแต้มๆ ลูกกลางๆ: 1ลูก\nปลากระป๋อง: 1กระป๋อง\nน้ำตาลปี๊บ: 2ทัพพี\nน้ำส้มมะขาม ตามความชอบ: 1ทัพพี\nน้ำปลา แล้วแต่ชอบ: \nน้ำเปล่า: 2ถ้วยตวง\nพริกแกงส้ม: 1ทัพพี\nผักชี:\""
},
{
    'ชื่ออาหาร': 'พริกแกงเหลือง (แกงส้มใต้)',
    'ingredient_full_json': "\"พริกจินดาแห้ง(ใช้พริกขี้หนูสดได้): 30 เม็ด\nกระเทียมไทย: 30 กลีบ\nขมิ้นยาว 2 นิ้ว: 1 ชิ้น\nกะปิ: 1 ช้อนโต๊ะ\nเกลือ: 1 ช้อนชา\""
},
{
    'ชื่ออาหาร': 'ยำปลากระป๋องทรงเครื่อง',
    'ingredient_full_json': "\"ปลากระป๋อง: 1 กระป๋อง\nตะไคร้: 2 ต้น\nหอมแดงซอย: 5 หัว\nผักชีฝรั่ง: 1 ต้น\nใบโพระพา: 5-6 ใบ\nใบมะกรูดซอย: 2 ใบ\nพริกขี้หนูซอย: 5 เม็ด\nมะนาว: 1-2 ซีก\""
},
{
    'ชื่ออาหาร': 'น้ำพริกกะปิสูตรอร่อยเด็ด',
    'ingredient_full_json': "\"กระเทียม: 1 ช้อนโต๊ะ\nกะปิ: 1 ช้อนโต๊ะ\nน้ำตาลปี๊บ: 1/2 ช้อนโต๊ะ\nพริกขี้หนูสวน: 20 เม็ด\nมะเขือพวง: 1 ช้อนโต๊ะ\nน้ำมะนาวคั้นสด: 4 1/2 ช้อนโต๊ะ\""
},
{
    'ชื่ออาหาร': 'ผัดซีอิ๊ว + สอนเทคนิคผัดเส้นระดับโปร ♥️',
    'ingredient_full_json': "\"เส้นใหญ่: 200 g\nหมูหมัก หรือ เนื้อมัก ดูสูตรได้ที่หมูหมักแบบภัตราคารจีน: 200 g\nคะน้า: 200 g\nไข่ไก่: 2 ฟอง\nซีอิ๊วขาว น้ำมันหอย ซีอิ๊วดำ: 3-4-5 เหยาะ\""
},
{
    'ชื่ออาหาร': 'แกงเขียวหวานเนื้อพริกขี้หนู',
    'ingredient_full_json': "\"เนื้อวัว(ล้ำ): 500 กรัม\nพริกแกงเขียวหวาน: 100 กรัม\nกะทิ: 1/2 กก.\nน้ำปลา: 4 ช้อนโต๊ะ\nน้ำตาลตะโหนด: 1 ช้อนโต๊ะ\nมะเขือเปราะ: 6 ลูก\nมะเขือพวง: \nใบโหระพา: \nพริกขี้หนู: \nใบมะกรูดฉีก:\""
},
{
    'ชื่ออาหาร': 'แกงส้มชะอมกุ้งพริกแกงใต้',
    'ingredient_full_json': "\"กุ้ง: 5 ขีด\nชะอม: 1 กำ\nพริกแกงส้มใต้: 2-3 ช้อน\nไข่ไก่: 4 ฟอง\nน้ำตาลปีบ: 1-2 ช้อน\nน้ำปลา: ตามรสชาติที่ชอบ\nน้ำมัน: 1 ถ้วย\nน้ำมะขามเปียก: ตามรสชาติที่ชอบ\""
},
{
    'ชื่ออาหาร': 'ยำปลากระป๋องแบบบ้าน',
    'ingredient_full_json': "\"ปลากระป๋อง: 3 กระป๋อง\nหอมแดงซอย: 2 ช้อนโต๊ะ\nพริกขี้หนู: 2 กรัม\nมะนาว: 2 ลูก\""
},
{
    'ชื่ออาหาร': 'แกงมัสมั่นเนื้อ',
    'ingredient_full_json': "\"เนื้อวัว(น่องลาย): 300 g.\nพริกแกงมัสมั่น: 100 g.\nกะทิเรียลไทย: 500 ml.\nอบเชย: 3 แท่ง\nดอกจันทร์: 3 ดอก\nลูกกระวาน: 6 ลูก\nถั่วลิสงคั่ว: 50 g.\nน้ำตาลมะพร้าว: 3 ช้อนโต๊ะ\nน้ำมะขามเปียก: 2 ช้อนโต๊ะ\nน้ำปลาดี: 2 ช้อนโต๊ะ\nเกลือ: หยิบมือ\nน้ำส้มซ่า: 1 ช้อนโต๊ะ\nมันฝรั่ง: 2 หัว\nหอมหัวใหญ่: 1 หัว\nซุบเนื้อก้อนคนอร์: 1 ก้อน\""
},
{
    'ชื่ออาหาร': 'น้ำพริกกะปิ ปลาทูทอด',
    'ingredient_full_json': "\"น้ำพริกกะปิ: \nกระเทียม: 4 กลีบใหญ่\nพริก: 6 เม็ด\nน้ำตาลแว่น/น้ำตาลมะพร้าว: 1.5 แว่น\nกะปิอย่างดี: 1 ช้อนพูนๆ\nมะนาว: 1.5 ลูกเล็ก\nผักต้ม: \nถั่วฝักยาว: 5 ต้น\nผักบุ้ง: 4 ต้น\nน้ำเปล่า: สำหรับลวก\nน้ำเย็นจัด: สำหรับแช่ผัก\nปลาทูทอด: \nปลาทูขนาดกลาง: 2 ตัว\nน้ำมันปาล์ม: 1 ถ้วย\""
},
{
    'ชื่ออาหาร': 'แกงมัสมั่นหมู',
    'ingredient_full_json': "\"เนื้อหมู: 500 กรัม\nพริกแกงมัสมั่น: 100 กรัม\nหอมใหญ่: 2ลูก\nมันฝรั่ง: 3 หัว\nถั่วลิสงคั่ว: 150 กรัม\nน้ำตาลปีบ: 3ช้อน\nน้ำมะขามเปียก: 2ช้อน\nเกลือ: 1ช้อนครึ่ง\nใบกระวาน: 2ใบ\nกะทิ วันนี้ใช้แบบ UHT: 1กล่อง\""
},
{
    'ชื่ออาหาร': 'แกงเขียวหวานไก่ใส่ฟัก',
    'ingredient_full_json': "\"สะโพกไก่: 2 ชิ้น\nฟักแก่: 3 ขีด\nตีนไก่: 2 ขีด\nพริกแกงเขียวหวาน: 1.5 ขีด\nกระทิสด: 1 โล\nมะเขือ: 3-4 ลูก\nใบโหระพา: 1 กำเล็ก\nพริกชี้ฟ้า: 4-5 เม็ด\nน้ำปลา: 2 ช้อน\nน้ำตาลปีบ: 1/2 ช้อน\nมะเขือพวง: 1 ขีด\""
},
{
    'ชื่ออาหาร': 'ไข่เจียวหมูสับหน้ากรอบ',
    'ingredient_full_json': "\"เนื้อหมูสับ: 2-3ขีด\nไข่ไก่: 5 ฟอง\nน้ำปลา: ตามชอบ\nซอสหอยนางรม: ตามชอบ\nน้ำตาล: ตามชอบ\""
},
{
    'ชื่ออาหาร': 'ผัดพริกแกงหมูใส่มะเขือเปราะ',
    'ingredient_full_json': "\"น้ำมัน: 4ช้อนโต๊ะ\nกระเทียม: 2ช้อนโต๊ะ\nเนื้อหมู: 4ขีด\nพริกชี้ฟ้าหรือพริกขี้หนู: \nพริกแกง: 2ช้อนโต๊ะ\nมะเขือเปราะ: \nใบมะกรูด: \nมะเขือพวง: \nน้ำปลา: \nน้ำเปล่า: \nน้ำตาล: 2ช้อนชา\nน้ำมันหอย: 2ช้อนโต๊ะ\""
},
{
    'ชื่ออาหาร': 'เทคนิค กะเพราหมูสับ แบบแห้ง อร่อยกว่าร้าน',
    'ingredient_full_json': "\"หมูสับ: 1 ถ้วย\nพริกเขียว + กระเทียม สับ: 1 ถ้วย\nใบกะเพรา: 2-3 ต้น\nซีอิ๊วขาว: 2-3 ช้อนชา\nน้ำปลา: 1 ช้อนชา\nพริกไทย: 2-3 เหยาะ\""
},
{
    'ชื่ออาหาร': 'แกงเขียวหวานไก่ผัดแห้ง',
    'ingredient_full_json': "\"เนื้อไก่หั่นเป็นชิ้น: 140 กรัม\nมะเขือเปราะหั่น: 200 กรัม\nมะเขือพวง: 2 ช้อนโต๊ะ\nพริกแดงหั่นแฉลบ: 4 เม็ด\nใบโหระพา: 1 ถ้วย\nพริกแกงเขียวหวาน: 2 ช้อนโต๊ะ\nน้ำตาลปี๊บ: 1 /2ช้อนโต๊ะ\nใบมะกรูดฉีก: 4-5ใบ\nนมข้นจืด.: 6 ช้อนโต๊ะ\nน้ำมันพืช.: เล็กน้อย\nน้ำเปล่า: เล็กน้อย\""
},
{
    'ชื่ออาหาร': '“ปูหลน”',
    'ingredient_full_json': "\"กะทิ: 2 กล่อง\nหมูสับ: 400 กรัม\nน้ำสะอาด: 3 กล่อง\nหอมแดงซอย: 1 ถ้วย\nปูเค็ม: 10 ตัว\nน้ำตาลปี๊บ: 5 ช้อนโต๊ะ\nผงปรุงรส: 3 ช้อนชา\nเกลือป่น: 1 ช้อนชา\nน้ำปลา: 5 ช้อนโต๊ะ\nน้ำมะขามเปียก: 20 ช้อนโต๊ะ\nตะไคร้ซอย: 5 ต้น\nใบมะกรูดแบบฉีก: 10 ใบ\nพริกใหญ่: 20 เม็ด\nใบมะกรูดแบบซอย: 10 ใบ\""
},
{
    'ชื่ออาหาร': 'ขนมจีนแกงเขียวหวานไก่ 💚',
    'ingredient_full_json': "\"อกไก่: \nเลือดไก่: \nกะทิ: \nพริกแกงเขียวหวาน: \nมะเขือเปราะ: \nมะเขือพวง: \nใบโหระพา: \nน้ำปลา: \nรสดี: \nใบมะกรูด:\""
},
{
    'ชื่ออาหาร': '🌱 ยำสามกรอบ 🌶',
    'ingredient_full_json': "\"หมูแผ่นอบกรอบ: \nหนังไก่กรอบ: \nเมล็ดมะม่วงหิมพานต์: \nหัวหอมใหญ่: \nขึ้นฉ่าย: \nพริกขี้หนู: \nน้ำปลา: \nมะนาว: \nน้ำเชื่อม: \nน้ำเปล่า:\""
},
{
    'ชื่ออาหาร': 'ขนมจีนน้ำยาปลาทู',
    'ingredient_full_json': "\"ปลาทูนึงแกะเอาแต่เนื้อ: 2 ตัว\nน้ำพริกแกงเผ็ดใต้: 100 กรัม\nกะทิ: 250 กรัม\nลูกชิ้นปลา: 6-7 ลูก\nกระชาย ล้างให้สะอาด ตำให้ละเอียด: 100 กรัม\nขนมจีน: \nผักเครื่องเคียงตามชอบ: \nน้ำตาลมะพร้าว: 2 ช้อนโต๊ะ\nน้ำปลา: 2 ช้อนโต๊ะ\""
},
{
    'ชื่ออาหาร': 'แกงส้มปลาหน่อไม้ดอง',
    'ingredient_full_json': "\"ปลาทับทิม: 1 ตัว\nเครื่องแกงส้ม: 1 ขีด\nหน่อไม้ดอง: 1/2 กก.\nกะปิ: 1 ช้อนพูน\nน้ำตาลมะพร้าว: 1 ช้อนโต๊ะ\nเกลือ: 1 ช้อนชา\nน้ำปลา: 1 ช้อนโต๊ะ\nน้ำมะขามเปียก: 1 ถ้วย\nมะนาว: 1.5 ลูก\""
},
{
    'ชื่ออาหาร': 'พริกแกงมัสมั่น​',
    'ingredient_full_json': "\"เม็ดผักชีคั่วป่น: 1+1/2 ช้อนชา\nเม็ดยี่หร่าคั่วป่น: 1/2 ช้อนชา\nเม็ดกระวานคั่วป่น​ (แกะเอาเฉพาะเม็ดที่อยู่ด้านใน)​: 4 เม็ด\nกานพลูคั่วป่น: 4 ดอก\nลูกจันทน์​คั่วป่น: 1 ลูก\nดอกจันทน์​คั่วป่น: 1 ดอก\nอบเชยท่อน​ 1 นิ้ว​ คั่วป่น: 1 ท่อน\nพริกชี้ฟ้าแช่น้ำซับแห้ง: 10 เม็ด\nเกลือสมุทร​: 1 ช้อนชา\nข่าแก่หั่นละเอียด: 1 ช้อนโต๊ะ​\nตะไคร้หั่นละเอียด: 2 ต้น\nผิวมะกรูด: 1 ช้อนชา\nกระเทียม​ไทย: 20​ กลีบ\nหอมแดง: 5 หัว\nกะปิห่อใบตองย่างจนหอม: 1 ช้อนชา\nพริกไทยขาวเม็ดคั่วป่น: 1/2 ช้อนชา\""
},
{
    'ชื่ออาหาร': 'ขนมครกสิงคโปร์',
    'ingredient_full_json': "\"แป้งสาลี: 2ถ้วย\nแป้งมัน: 1ถ้วย\nนมสดรสจืด: 1ถ้วย\nใบเตย12ใบแก่ๆ คั้นน้ำกรองกาก: 1ถ้วย\nผงฟู: 2ช้อนกาแฟพูนๆ\nเกลือ: 1ช้อนกาแฟพูนๆ\nน้ำตาลทราย: 1ถ้วย\nน้ำมันพืช: 1ช้อนกาแฟ\nไข่ไก่: 2ฟอง\""
},
{
    'ชื่ออาหาร': 'ไก่ผัดเม็ดมะม่วงหิมพานต์ (น้ำพริกเผา) Gai Pad Med Mamuang',
    'ingredient_full_json': "\"เนื้อไก่หั่นชิ้นพอดีคำ: 400 กรัม\nแป้งทอดกรอบ: 1/2 ถต.\nเม็ดมะม่วงหิมพานต์ทอด: 100 กรัม\nพริกทอดกรอบ หั่นท่อน: 10 เม็ด\nหอมหัวใหญ่: 1 หัว\nพริกหวานสามสี (3 สี แดง เหลือง เขียว ใช้สีละอย่างละ: 1/2 ลูก\nพุทราเชื่อม/พุทราอบแห้ง (ใข้พุทราเชื่อมอร่อยกว่า) ส่วนนี้ไม่ใส่ก็ได้: 50 กรัม\nต้นหอมหั่นท่อน (มากน้อยตามชอบ): 5 ต้น\nกระเทียมสับละเอียด: 1 ช้อนโต๊ะ\nซอสหอยนางรม: 2 ช้อนโต๊ะ\nซีอิ้วขาว/ซอสปรุงรส: 1 ช้อนโต๊ะ\nน้ำตาลทราย(ความหวานปรับเพิ่มลดได้ตามความชอบ): 1 1/2 ช้อนโต๊ะ\nน้ำพริกเผา (ถ้าทำให้เด็กทานด้วยสามารถลดในส่วนนี้ลงได้): 2 ช้อนโต๊ะ\""
},
{
    'ชื่ออาหาร': 'แกงส้มผักบุ้งกุ้งลอยน้ำ',
    'ingredient_full_json': "\"กุ้งสดตัวใหญ่: 3 ขีด\nพริกแกงส้ม: 1 ช้อนโต๊ะ\nผักบุ้ง: 2 กำ\nน้ำปลา: 1 ช้อนชา\nหัวหอม: 2 หัว\nกระชาย: 1 ต้น\nกะปิ: ครึ่งช้อนชา\nน้ำตาลทราย: 1 ช้อนชา\nมะขามเปียก: 4 ฝัก\nใบมะกรูด: 4 - 5 ใบ\""
},
{
    'ชื่ออาหาร': 'ข้าวผัดซีอิ๊วดำ',
    'ingredient_full_json': "\"ข้าวสวย: 3 ถ้วย\nเนื้อหมู: 50กรัม\nไข่ไก่: 2ฟอง\nคะน้า: 30กรัม\nมะเขือเทศ: 1ลูก\nหอมหัวใหญ่: 1/2หัว\nกระเทียมสับ: 4กลีบ\nซีอิ๊วดำ: 1ช้อนโต๊ะ\nซีอิ๊วขาว: 1/2ช้อนโต๊ะ\nน้ำปลา: 1ชต\nน้ำตาลทราย: 1ช้อนชา\nน้ำมันพืช:\""
},
{
    'ชื่ออาหาร': 'ขนมจีนน้ำยากะทิไก่',
    'ingredient_full_json': "\"กะทิ: 1 Kg\nเนื้อไก่ส่วนหน้าอกต้ม: 500 กรัม\nพริกแห้ง: 15-20 เม็ด\nกระชายหั่น: 7 หัว\nตะไคร้ซอย: 3 ต้น\nหัวหอมแดงหั่น: 7 หัว\nข่าหั่น: 1 หัว\nกระเทียมซอย: 3 หัว\nน้ำซุปที่เหลือจากต้มไก่: 2 ถ้วยตวง\nเกลือป่น: 1 ช้อนโต๊ะ\nน้ำปลา: 4 ช้อนโต๊ะ\nน้ำตาลทราย: 2 ช้อนโต๊ะ\nใบมะกรูด: 10 ใบ\nลูกชิ้นปลา: 300 กรัม\nขนมจีน: 1 Kg\""
},
{
    'ชื่ออาหาร': 'ผัดกะเพราเนื้อสับ',
    'ingredient_full_json': "\"เนื้อบด: 2 ขีด\nใบกะเพรา: 10 ใบ\nกระเทียม: 5 กลีบ\nพริกขี้หนูสวน: ตามใจชอบ\nน้ำปลา: 1 ช้อนโต๊ะ\nซอสปรุงรส: 1 ช้อนโต๊ะ\nซอสหอยนางรม: 1 1/2 ช้อนโต๊ะ\nน้ำตาล: 1 ช้อนชา\nน้ำต้มสุก: 2-3 ช้อนโต๊ะ\""
},
{
    'ชื่ออาหาร': 'แกงเขียวหวานตีนไก่',
    'ingredient_full_json': "\"ตีนไก่: 1 กิโล\nเนื้อไก่ส่วนสะโพก: 200 กรัม\nกระทิคั้น(ซื้อที่ตลาด): 1 กิโล\nพริกแกงเขียวหวาน: 300 กรัม\nหน่อไม้ หรือ ยอดมะพร้าว: 200 กรัม\nพริกชี้ฟ้าแดง: 5-6 เม็ด\nใบมะกรูด: 5 ใบ\nใบโหระพา: 2-3 กำมือ\""
},
{
    'ชื่ออาหาร': 'ต้มยำปลาทู',
    'ingredient_full_json': "\"ปลาทูแม่กลอง (ตัวเล็ก): 10 ตัว\nเครื่องต้มยำ / ข่า / ตะไคร้ /ใบมะกรูด: มีขายเป็นชุดๆ ใช้ 1 ชุด\nมะนาว: 2 ลูก\nมะเขือเทศ: 1 ลูก\nพริกชี้ฟ้า: 3-4 เม็ด\nเกลือ: 1 ช้อนชา\nผงปรุงรส: ตามใจชอบ\nน้ำปลา: 2 ช้อนโต๊ะ\""
},
{
    'ชื่ออาหาร': 'ฉู่ฉี่กุ้งปลาหมึก 🦐🦑',
    'ingredient_full_json': "\"กุ้ง: 200 กรัม\nปลาหมึก: 200 กรัม\nกะทิ: 150 กรัม\nพริกแกงเผ็ด: 1 ช้อนโต๊ะ\nมันกุ้ง: 1 ช้อนโต๊ะ\nน้ำตาลปี๊บ: ปลายช้อน\nใบมะกรูด: 8 ใบ\nพริกแดง: 5 เม็ด\""
},
{
    'ชื่ออาหาร': 'มาม่าผัดกะเพราหมูสับ',
    'ingredient_full_json': "\"บะหมี่กึ่งสำเร็จรูป(มาม่า)ลวก: 70 กรัม\nหมูสับ: 40 กรัม\nใบกะเพรา: 1 ถ้วย\nคนอร์ซอสข้นปรุงรส รสหมู: 1 ช้อนโต๊ะ\nน้ำตาลทราย: 1 ช้อนชา\nซีอิ๊วดำ: 1 ช้อนชา\nกระเทียม.: 4 กลีบ\nพริกแดงจินดา: 8 เม็ด\nน้ำมันพืช.: เล็กน้อย\nน้ำเปล่า: เล็กน้อย\""
},
{
    'ชื่ออาหาร': 'ฉู่ฉี่ปลาทูสด',
    'ingredient_full_json': "\"ปลาทูสด: 2 ตัวใหญ่\nพริกแกงฉูฉี่: 1+1/2 ช้อนโต๊ะ\nกะทิ: 1 ถ้วย(กล่องเล็ก)\nใบมะกรูดซอย: 3 ใบ\nพริกชี้ฟ้าหั่น: 2 เม็ด\nน้ำปลา: 1/2-1 ช้อนโต๊ะ\nน้ำตาลปี๊บ: 1/2-1 ช้อนโต๊ะ\nผงคนอร์อร่อยชัวร์: 1 ช้อนชา\""
},
{
    'ชื่ออาหาร': '“ฉู่ฉี่ปลาทูทอด"',
    'ingredient_full_json': "\"น้ำมัน: 2 ช้อนโต๊ะ\nพริกแกงเผ็ด: 2-3 ช้อนโต๊ะ\nกะทิ: 400 กรัม\nน้ำตาลทราย: 4-5 ช้อนชา\nเกลือ: 1 ช้อนชา\nน้ำปลา: 2-3 ช้อนโต๊ะ\nปลาทูสดทอด: 15 ตัว\nใบมะกรูดซอย: 7 ใบ\nพริกใหญ่: 2 เม็ด\""
},
{
    'ชื่ออาหาร': 'แกงเขียวหวาน​(หมู)​🐷',
    'ingredient_full_json': "\"หมู​หั่นชิ้น: 1กิโลกรัม​\nมะเขือเปาะ: 1/2กิโลกรัม​\nมะเขือ​พวง: 100​กรัม​\nกระชายหั่นซอย: 100กรัม\nใบมะกรูด​ฉีก: 20ใบ\nพริกชี้ฟ้า​แดง: 4เม็ด\nใบโหระพา​: 40ใบ\nพริกแกง​เขียวหวาน​: 5ช้อนโต๊ะ​\nพริกแกงเผ็ด​: 1ช้อนโต๊ะ​\nกะทิกล่องสำเร็จ​แบบหัวกะทิ: 1000มล.\nน้ำตาลปี้บ: 0.5ช้อนโต๊ะ​\nผงปรุงรส​: 1ช้อนโต๊ะ​\nเกลือ​: หยิบมือ\nน้ำเปล่า​: 250มล.\""
},
{
    'ชื่ออาหาร': 'มาม่าผัดต้มยำกุ้ง',
    'ingredient_full_json': "\"เส้นบะหมี่กึ่งสำเร็จรูป: 50กรัม\nเห็ดฟาง: 40กรัม\nกุ้งสดปอกเปลือกผ่าหลัง: 3ตัว\nพริกเผา: 1ช้อนโต๊ะ\nซอสหอยนางรม: 1ช้อนโต๊ะ\nน้ำปลา: 1ช้อนโต๊ะ\nน้ำตาลทราย: 1ช้อนชา\nตะไคร้ทุบหั่นท่อนเล็ก: 2ต้า\nหอมแดง: 3หัว\nข่าสับ: 1ช้อนโต๊ะ\nใบมะกรูดฉีก: 6ใบ\nพริกแดงจินดา: 8เม็ด\nกระเทียม: 5กลีบ\nคนอร์ อร่อยชัวร์ ผงรสไก่: 1ช้อนชา\nมะนาว: 1/2ลูก\nน้ำมันพืช:\""
},
{
    'ชื่ออาหาร': 'โรลข้าวน้ำพริกกะปิ',
    'ingredient_full_json': "\"น้ำพริกกะปิ: 1 ถ้วยตวง\nปลาทูย่างสุก: 2 ตัว\nแตงกวา: 2 ลูก\nแครอท: 1 ลูก\nชะอม (หั่นซอย): 1 ถ้วยตวง\nไข่ไก่: 1 ฟอง\nข้าวสวย: 1 ถ้วยตวง\""
},
{
    'ชื่ออาหาร': 'แกงส้มผักรวมเจ',
    'ingredient_full_json': "\"พริกแกงส้มเจ: 3 ช้อนโต๊ะ\nถั่วเน่า(ใช้แทนกะปิ): 1/2 แผ่น\nขาเห็ดนางฟ้าต้ม: 10 ขา\nน้ำตาลปี๊บ: 1 ช้อนชา\nน้ำมะขามเปียก: 3 ช้อนโต๊ะ\nเกลือ: 1 ช้อนชา\nผงปรุงรสเห็ดหอมเจ: 1 ช้อนชา\nถั่วฟักยาว: 5 ฟัก\nหัวไชเท้า: 1/2 หัว\nเห็ดนางฟ้าส่วนดอก: 10 ดอก\nกวางตุ้ง: 3 ต้น\nดอกแค: 1 ถ้วย\nน้ำเปล่า: 6 ถ้วย\""
},
{
    'ชื่ออาหาร': 'ผัดไทยกุ้งสด หัวกุ้งทอดกรอบ',
    'ingredient_full_json': "\"เส้นหมี่: 1 ห่อ 200 กรัม\nกุ้งสด: 8 ตัว\nกุยช่าย: ตามชอบ\nหอมแดง: 5 หัว\nพริกแห้ง: 5\nกระเทียม: 3 หัว\nน้ำมะขาม: 3 ช้อนโต๊ะ\nน้ำตาลทราย: 1 ช้อนโต๊ะ\nเต้าหู้ขาว: ตามชอบ\nถั่วงอก: ตามชอบ\nน้ำปลา:\""
},
{
    'ชื่ออาหาร': 'ข้าวมันไก่คลีน ❤️',
    'ingredient_full_json': "\"อกไก่: 6 ขีด\nข้าวกล้อง: 2ถ้วย\nข้าวขาว: 1 ถ้วย\nแครอท: 1หัว\nไช้เท้า: 1หัว\nหอมใหญ่: 1หัว\nขิงหั่นแว่น: ตามชอบ\nกระเทียมทุบ: ตามชอบ\nน้ำมันมะกอก:\""
},
{
    'ชื่ออาหาร': 'ขนมจีนน้ำยาไก่',
    'ingredient_full_json': "\"เนื้อไก่: ครึ่งโล\nกระทิ: ครึ่งโล\nข่า ตะไคร้ ใบมะกรูด: 1 กำ\nตีนไก่: ครึ่งโล\nลูกชิ้นปลาอย่างดี: 1 ถุงเล็ก\nพริกแกงเผ็ด: 2 ขีด\nเกลือ: 1 ช้อน\nกระชาย: 2 ขีด\nเส้นขนมจีนสด: 1 ห่อ\""
},
{
    'ชื่ออาหาร': 'ต้มยำกุ้งน้ำข้น',
    'ingredient_full_json': "\"กุ้ง: 10 ตัว\nตะไคร้: 2 ต้น\nใบมะกรูด: 1 กำ\nข่า: 1/2 หัว\nเห็ดฟาง: 1 ขีด\nคนอร์ต้มยำ: 1 ก้อน\nนมจืด: 1/2 กล่อง\nน้ำพริกเผา: 2 ช้อน\nน้ำพริกเผาเผ็ด: 1 ช้อน\nพริก: 1 กำ\nเกลือ: \nน้ำปลา: \nน้ำตาล: \nมะนาว: 2 ลูก\""
},
{
    'ชื่ออาหาร': 'แกงเลียงเห็ด 3 อย่าง',
    'ingredient_full_json': "\"เห็ดฟาง: 1 ขีด\nเห็ดเข็มทอง: 1 ขีด\nเห็ดออรินจิ: 2-3 ดอก\nฝักทอง: 100กรัม\nบวบ: 1 หัว\nตำลึง: 200 กรัม\nใบแมงลัก: 1 กำ\nพริกไทยขาว: 2 ชช\nหอมแดง: 5-8หัว\nกะปิน้ำพริก: 1 ชต\nข้าวโพดอ่อน: 100กรัม\nแครอท: 50กรัม\nน้ำสะอาด: 1 1/2 ถ้วย\nเกลือ: 1/3 ชช\nกุ้งแห้ง: 3 ชต\nพริกแดง: 2 เม็ด\""
},
{
    'ชื่ออาหาร': 'ข้าวผัดแกงเขียวหวาน',
    'ingredient_full_json': "\"เนื้อหมู: 100 กรัม\nข้าวสวย: 1 ถ้วย\nน้ำพริกแกงเขียวหวาน: 1/2 ช้อนโต๊ะ\nมะเขือเปราะหั่น 4 หรือ 6: 1 ลูก\nมะเขือพวงเด็ด: 10 เม็ด\nใบโหระพา(เด็ดเป็นใบ): 10-15 ใบ\nพริกชี้ฟ้าแดงหั่นเฉียง: 5 ชิ้น\nกะทิ: 2 ช้อนโต๊ะ\nน้ำตาลปี๊บ: 1 ช้อนชา\nน้ำปลา: 2 ช้อนชา\""
},
{
    'ชื่ออาหาร': 'ต้มยำปลากระป๋อง',
    'ingredient_full_json': "\"ปลากระป๋อง: 3 กระป๋อง\nตะไคร้: 6 ท่อน\nข่า: 2 กิ่ง\nใบมะกรูด: 2 กิ่ง\nเห็ดนางฟ้า: 200 กรัม\nหอมแดง: 10 หัว\nผักชีฝรั่ง: 5 ต้น\nผงปรุงรส: 2 ก้อน\nพริกป่น: 1 ช้อนโต๊ะ\nพริกจินดา: 10 เม็ด\nมะนาว: 4 ลูก\""
},
{
    'ชื่ออาหาร': 'ข้าวผัดน้ำพริกลงเรือสูตรโบราณแกล้มหมูกรอบทอดน้ำปลา',
    'ingredient_full_json': "\"หมูสามชั้น: 1 ชิ้น\nปลาดุกฟู: 1 ถ้วยตวง\nพริกขี้หนู: 15 เม็ด\nกะปิย่าง: 2 ช้อนโต๊ะ\nน้ำตาลปีบ: 2 ช้อนชา\nกระเทียมกลีบเล็ก: 3 กลีบ\nถั่วฝักยาว: 1/3 ถ้วยตวง\nไข่เค็ม: 1 ฟอง\nแครอทต้มสุก: 1/3 ถ้วยตวง\nน้ำปลา: 3 ช้อนโต๊ะ\nซอสหอยนางรม: 1 ช้อนโต๊ะ\nซอสปรุงรส: 2 ช้อนโต๊ะ\nน้ำตาลทราย: 2 ช้อนโต๊ะ\""
},
{
    'ชื่ออาหาร': '✿ แกงมัสมั่นไก่ ✿',
    'ingredient_full_json': "\"น้ำพริกแกงมัสมั่น: 100 กรัม\nสะโพกไก่: 3 ชิ้น\nกะทิ: 500 ml\nมันฝรั่ง: 1\nหัวหอมใหญ่: 1 ลูก\nขิง: 2 แว่น(ซอย)\nคนอร์รสไก่: 1 ก้อน\nน้ำเปล่า: 200 ml\nอบเชย โป๊ยกั้ก ลูกกระวาน (ที่ซื้อมาไม่มีลูกกระวาน): 1 ห่อเล็ก\nน้ำมะขามเปียก: \nน้ำตาลปี๊บ: \nเกลือ:\""
},
{
    'ชื่ออาหาร': 'ต้มยำกุ้งน้ำข้น',
    'ingredient_full_json': "\"กุ้งขาว: 200\nข่า: 5 แว่น\nตะไคร้: 3 ต้น\nใบมะกรูด: 4 ใบ\nหอมแดง: 5 หัว\nนมข้นจืด: 1/4-1/2 ถ้วย\nน้ำพริกเผา: 1 ช้อนโต๊ะ\nน้ำเปล่า: 3 ถ้วย\nเห็ดต่างๆ: ตามชอบ\nคนอร์ซุปต้มยำ(ก้อน): 2 ก้อน\nผักชีฝรั่ง: 2 ต้น\nต้นหอม: 2 ต้น\nพริกแห้งทอด: 4 เม็ด\nน้ำปลา: \nน้ำมะนาว:\""
},
{
    'ชื่ออาหาร': 'แกงส้มผักรวม',
    'ingredient_full_json': "\"ผักสด (ตามสะดวก): \nปลา(ตามสะดวก): \nพริกแห้ง: \nหอมแดง: \nกะปิ: \nน้ำตาลปี๊บ: \nน้ำปลา: \nเกลือ: \nน้ำมะขามเปียก:\""
},
{
    'ชื่ออาหาร': 'ข้าวมันไก่เด็กหอ',
    'ingredient_full_json': "\"น่องไก่ติดสะโพก: 2น่อง\nข้าว: 4กรัม\nกระเทียม: 1หัว\nขิง: 1แง่ง\nพริกสด: 1ขีด\nน้ำตาลทราย: 3ช้อน\nมะนาว: 3ลูก\nซอสปรุงรสสูตร1: 2ช้อน\nเต้าเจี้ยว: 4ช้อน\nซุปคนอร์: 2ก้อน\""
},
{
    'ชื่ออาหาร': 'แกงส้มปลาช่อนทอด',
    'ingredient_full_json': "\"ปลาช่อน: 1 ตัว\nแป้งทอดกรอบ: 5 ช้อนโต๊ะ\nน้ำมัน: 1/2 ถ้วย\nพริกแกงส้มสำเร็จ: 300 กรัม\nปลาทูน่า: 3 กระป๋องใหญ่\nหัวไชเท้า: 1 หัว\nถั่วฝักยาว: 500 กรัม\nผักกาดขาว: 1 หัว\nมะขามเปียก: 1 ปั้น\nน้ำตาลปี๊บ: 2 ช้อนโต๊ะ\nน้ำปลา (อาจไม่ใส่): 3 ช้อนโต๊ะ\""
},
{
    'ชื่ออาหาร': 'หมูสับผัดซีอิ๊วดำหวาน',
    'ingredient_full_json': "\"หมูสับ: 300 กรัม\nหมอแดง: 150 กรัม\nกระเทียม: 10 กลีบ\nพริกไทยป่น: 1 ช้อนชา\nซีอิ๊วดำ: 1 ช้อนโต๊ะ\nน้ำตาลอ้อย: 1/2 ก้อน\nน้ำมัน: 1 ช้อนชา\""
},
{
    'ชื่ออาหาร': 'แกงส้มปลาทูสด',
    'ingredient_full_json': "\"ปลาทูสด: 4ตัว\nพริกแกงส้ม: 2ช้อนโต๊ะ\nน้ำปลา: 1 1/2ช้อนโต๊ะ\nน้ำตาล: 1ช้อนโต๊ะ\nน้ำมะขามเปียก: 2ช้อนโต๊ะ\nผักบุ้ง: 1กำ\""
},
{
    'ชื่ออาหาร': 'เครื่องในไก่ทอดกระเทียม',
    'ingredient_full_json': "\"เครื่องในไก่: \nพริกไทยขาวป่น: \nผงปรุงรส: \nแป้งชุบทอด: \nกระเทียม: \nน้ำมันพืช:\""
},
{
    'ชื่ออาหาร': 'ต้มยำกุ้งน้ำใส',
    'ingredient_full_json': "\"กุ้ง 3 ตัว: 250 กรัม\nเห็ดนางรมหลวง: 60 กรัม\nตะไคร้: 2 ต้น\nใบมะกรูด: 6 ใบ\nพริกขี้หนูสวน สีแดง: 15 เม็ด\nน้ำมะนาว: 1.5 ช้อนโต๊ะ\nซีอิ๊วขาว: 1.5 ช้อนโต๊ะ\nน้ำสต๊อก: 350 กรัม\nข่าแก่: 6 แว่น\""
},
{
    'ชื่ออาหาร': 'ข้าวกะเพราเนื้อไข่ดาว เมนูนี้ไม่มีเบื่อ',
    'ingredient_full_json': "\"ไข่ไก่: 1 ฟอง\nเนื้อสับ หรือหั่นเป็นชิ้น/หรือจะใช้เนื้อสัตว์อย่างอื่นก็ได้ค่ะ: 250 กรัม\nซอสหอยนางรม: 1 ช้อนชา\nน้ำปลา หรือ ซอสปรุงรส: 1 ช้อนชา\nน้ำตาล: 1/2 ช้อนชา\nใบกระเพรา: 2 กำมือ\nกระเทียม: 3 กลีบ\nพริก: 3-4 เม็ด\""
},
{
    'ชื่ออาหาร': 'ผัดกะเพราโบราณ, ผัดกะเพราเนื้อสับ',
    'ingredient_full_json': "\"เนื้อสับ: 300 กรัม\nพริกขี้หนูเน้นสีแดง: 35 เม็ด\nกระเทียมจีน: 1 หัว\nใบกะเพรา: ตามชอบ\nซอสปรุงรส: 2 ช้อนโต๊ะ\nน้ำปลา: 1/2 ช้อนโต๊ะ\nน้ำตาลทราย: 1 ช้อนชา\nซอสหอยนางรม: 1 ช้อนโต๊ะ\nน้ำดื่ม: 1 ทัพพี\""
},
{
    'ชื่ออาหาร': 'แกงเทโพหมูสามชั้น',
    'ingredient_full_json': "\"หมู 3 ชั้น: 400 g.\nพริกแกงใต้(แกงเผ็ด): 100 g.\nน้ำตาลมะพร้าว: 20 กรัม\nใบมะกรูด: 3 ใบ\nมะขามเปียก: 1/2 ช้อนโต๊ะ\nน้ำปลาแท้: 2 ช้อนโต๊ะ\nผักบุ้งไทย: 8-10 ต้น\nน้ำมันพืช: 1 ช้อนชา\nกะทิ: 250 ml.\""
},
{
    'ชื่ออาหาร': 'แกงเลียงปลากรอบ',
    'ingredient_full_json': "\"ปลากรอบเอาไปปิ้งหรือเอาไปอบให้หอม แกะเอาแต่เนื้อ: 1 ตัว\nน้ำเต้าปอกเปลือก ล้างให้สะอาด หั่นเป็นชิ้นพอดีคำ: 1 ลูกเล็ก\nบวบ ฝานคมออกให้หมด ล้างน้ำให้สะอาด หั่นชิ้นพอดีคำ: 1/2 ลูก\nข้าวโพดอ่อน หั่นชิ้นพอดีคำ: 2-3 ฝัก\nใบแมงลักเด็ด ล้างน้ำให้สะอาด สะเด็ดน้ำ: 1/2 ถ้วย\nพริกไทยเม็ด: 1/2 ช้อนโต๊ะ\nหอมแดง: 4-5 หัว\nกุ้งแห้งแช่น้ำให้นิ่ม สะเด็ดน้ำ: 25 กรัม\nพริกขี้หนูสด: 10 เม็ด\nกะปิ: 1/2 ช้อนโต๊ะ\""
},
{
    'ชื่ออาหาร': 'แกงส้มผักกระเฉด',
    'ingredient_full_json': "\"ผักกระเฉด: 300กรัม\nกุ้งผ่าหลัง: 5-6ตัว\nปลากระป๋อง: 2กระป๋อง\nพริกสด: 50กรัม\nพริกแห้งป่น: 2ช้อนชา\nหอมแดง: 7-8หัว\nกระชาย: 2ช้อนโต๊ะ\nกระปิ: 2ช้อนโต๊ะ\nเกลือป่น: 1/2ช้อนชา\nน้ำตาล: 1ช้อนโต๊ะ\nน้ำปลา: 3ช้อนโต๊ะ\nน้ำมะขามเปียก: 4ช้อนโต๊ะ\nมะนาว: 3ลูก\""
},
{
    'ชื่ออาหาร': 'ก๋วยเตี๋ยวคั่วไก่',
    'ingredient_full_json': "\"เส้นใหญ่: \nอกไก่: \nเห็ดหูหนูขาว (ใช้แทนหมึกกรอบ): \nากผักชี, กระเทียม, พริกไทย (สำหรับหมักไก่): \nไข่ไก่: \nซีอิ๊วขาว, ซีอิ๊วดำ, น้ำปลา, ซอสพริก: \nผักกาดหอม: \nพริกเหลือง, น้ำส้มสายชู (สำหรับทำพริกดอง): \nไก่เชียง, หนังไก่ (เครื่องโรยหน้า):\""
},
{
    'ชื่ออาหาร': 'แกงเขียวหวานสำเร็จรูป',
    'ingredient_full_json': "\"หมูสันใน: 200 กรัม\nผงปรุงรสแกงเขียวหวาน: 1 ซอง\nน้ำกะทิ: 100 มล.\nใบมะกรูด: \nโหระพา: \nพริกชี้ฟ้าแดง: \nมะแว้งเขียว: 150 กรัม\nน้ำเปล่า: 50 มล.\""
},
{
    'ชื่ออาหาร': 'แกงมัสมั่นไก่',
    'ingredient_full_json': "\"สะโพกไก่: 500 กรัม\nพริกแกงมัสมั่น: 60 กรัม\nกะทิเรียลไทย: 750 มล\nถั่วลิสงคั่ว: 50 กรัม\nมันฝรั่ง (หั่นเต๋า): 4-5 ลูก\nหอมใหญ่: 2 หัว\nน้ำตาลมะพร้าว: 2-3 ชต\nน้ำปลาดี: 1-2 ชต\nน้ำมะขามเปียก น้ำส้มซ่า: 2-3 ชต\nอบเชย โป๊ยกั๊ก: \nลูกกระวาน ใบกระวาน: \nเกลือ: 1/2 ชช\""
},
{
    'ชื่ออาหาร': 'ข้าวกะเพราไก่ไข่ดาว',
    'ingredient_full_json': "\"เนื้อไก่สับ: 70กรัม\nใบกะเพรา: 1ถ้วย\nพริกแดงจินดา: 8เม็ด\nกระเทียม: 5กลีบ\nซีอิ๊วดำ: 1/2 ชช\nซอสหอยนางรม: 1/2 ช้อนโต๊ะ\nน้ำปลา: 1/2 ชต\nน้ำตาลทราย: 1ช้อนชา\nคนอร์ เนเชอรัล ผงรสหมูสูตรไม่ใส่ผงชูรส: 1ช้อนชา\nไข่ไก่: 1ฟอง\nน้ำมันพืช: \nข้าวสวย: 1ถ้วย\""
},
{
    'ชื่ออาหาร': 'แกงส้มกุ้งสับปะรด',
    'ingredient_full_json': "\"กุ้งขาว: 4 ขีด\nสับปะรดเปรี้ยวอมหวาน: 1/2 ลูกเล็ก\nเครื่องแกงส้มใต้: 2 ช้อนโต๊ะ\nกะปิ: 1.5ช้อนโต๊ะ\nน้ำปลา: 1.5 ช้อนโต๊ะ\nเกลือป่น: 1 หยิบมือ\nน้ำตาล: 1.5 ช้อนโต๊ะ\nน้ำมะขามเปียก: 1 ถ้วยน้ำซุป\nมะนาว: 1.5 ลูก\""
},
{
    'ชื่ออาหาร': 'แกงเขียวหวาน สันในหมู',
    'ingredient_full_json': "\"เครื่องแกงเขียวหวาน: 100g\nสันในหมู: 400g\nมะเขือเปราะ: 100g\nมะเขือพวง (ไม่ใส่เพราะไม่ชอบครับ): 0\nพริกชี้ฟ้า: นิดหน่อย\nโหระพา: นิดหน่อย\nกะทิ: 500ml\nซอสหอยนางรม: 3 ชต\nน้ำปลา: 4 ชต\nน้ำตาล: 4-5 ชช\""
},
{
    'ชื่ออาหาร': 'ฉู่ฉี่ปลาทู',
    'ingredient_full_json': "\"ปลาทูสด: 3ตัว\nกะทิกล่องอร่อยดี: 250 ml.\nพริกแกงเผ็ด: 3 ชต\nน้ำปลา: 2 ช้อนโต๊ะ\nน้ำตาลปี้บ: 1/2 ช้อนโต๊ะ\nใบมะกรูด: \nพริกแดง:\""
},
{
    'ชื่ออาหาร': 'แกงเลียงกะทิสด',
    'ingredient_full_json': "\"กุ้งขาวแกะเปลือกผ่าหลัง: 2 ขีด\nหัวหอมแดง: 3 หัว\nข่า(ใส่ดับกลิ่นคาวนิดนึง): 1ช้อนชา\nกระชาย: 2ช้อนชา\nกะปิ: 1ช้อนชา\nพริกไทยขาวเม็ด: 2-3 ช้อนชา\nกุ้งแห้ง: 2 ช้อนชา\nฟักทอง: \nข้าวโพดอ่อน: \nบวบ: \nเห็ดโคนญี่ปุ่น: \nใบแมงลัก: 1ขีด\nกะทิสด: 1/2 ถ้วย\nน้ำปลา ตามชอบ เราใส่แค่: 1ช้อน\""
},
{
    'ชื่ออาหาร': 'แกงส้มชะอมทอด',
    'ingredient_full_json': "\"กุ้ง: 3 ขีด\nปลาทูทอดแกะก้าง: 1 ตัว\nพริกแกงส้มใต้: 1 1/2 ช้อนโต๊ะ\nพริกแกงส้มกลาง: 1 1/2 ช้อนโต๊ะ\nน้ำตาลปี้บ: 2 ช้อนโต๊ะ\nน้ำปลา: 1/2 ทัพพี\nเกลือป่น: 1 หยิบมือ\nน้ำมะขามเปียก: 1/2 ถ้วยตวง\nน้ำสะอาด: 750 มล.\nผักกาดขาว: 1 หัว\nแครอท: 1 หัว\nหัวไชท้าว: 1 หัว\nชะอมทอด: 1 แพ\""
},
{
    'ชื่ออาหาร': '“แกงเลียงกุ้งสด"',
    'ingredient_full_json': "\"พริกแห้ง: 5-6 เม็ด\nหอมแดง: 10 หัว\nกระชาย: 10 แง่ง\nเกลือ: 1 ช้อนชา\nกะปิ: 1/2 ช้อนโต๊ะ\nกุ้งสด: 10 ตัว\nน้ำสะอาด: 3 ถ้วย\nฟักทอง: 400 กรัม\nบวบ: 2 ลูก\nข้าวโพด: 2 ฝัก\nเห็ดออรินจิ: 6 ดอก\nใบแมงลัก: 1 กำ\nน้ำตาลทราย: 4-5 ช้อนชา\nน้ำปลา: 5-6 ช้อนโต๊ะ\nผงปรุงรส: 1 ช้อนชา\nพริกไทยป่น: 1 1/2 ช้อนชา\""
},
{
    'ชื่ออาหาร': 'ฉู่ฉี่ปลานิล (สูตรคุณยาย)',
    'ingredient_full_json': "\"ปลานิล: 1 ตัว\nพริกแกงเผ็ด: 3 ช้อนโต๊ะ\nใบมะกรูดหั่นฝอย ประมาณ: 1 ½ ช้อนโต๊ะ\nน้ำปลา: 3 ช้อนโต๊ะ\nน้ำตาล: 1 ½ ช้อนโต๊ะ\nผงชูรส: 1 ช้อนชา\nน้ำมันพืช:\""
},
{
    'ชื่ออาหาร': 'แกงส้มผักรวมปลากระพง',
    'ingredient_full_json': "\"เนื้อปลากระพง: 250 g.\nพริกแกงส้ม: 2-3 ช้อนโต๊ะ\nมะละกอ: 100 g.\nหัวไชเท้า,แครอท: 100 g.\nผักบุ้งไทย: 100 g.\nถั่วฝักยาว,ถั่วพู: 100 g.\nน้ำมะขามเปียก: 4-5 ช้อนโต๊ะ\nน้ำตาลมะพร้าว: 1-2 ช้อนโต๊ะ\nน้ำปลาดี: 3 ช้อนโต๊ะ\nเกลือ: 1/2 ช้อนชา\nน้ำเปล่า: 3 ถต.\""
},
{
    'ชื่ออาหาร': 'ขนมจีนน้ำยากะทิไก่ข้น (หลัวรักหลัวหลง)',
    'ingredient_full_json': "\"เนื้ออกไก่: \nกะทิ: \nน้ำปลา: \nปลาร้า (ตามชอบ): \nพริกแห้ง หอมแดง กระเทียม ตะไคร้ ใบมะกรูด กระชาย:\""
},
{
    'ชื่ออาหาร': 'ขนมจีนแกงไตปลา',
    'ingredient_full_json': "\"ไตปลา: 1 ถ้วย\nข่า: 6 แว่น\nตะไคร้: 3 ต้น\nใบมะกรูด: 10 ใบ\nน้ำเปล่า: 4 ถ้วย\nพริกแกงไตปลา: 1/4 ถ้วย\nเนื้อปลาย่าง: 1 ถ้วย\nหน่อไม้ต้ม: 1 ถ้วย\nฟักทอง: 1 ถ้วย\nถั่วฟักยาว: 1/2 ถ้วย\nมะเขือเปราะ: 1/2 ถ้วย\nมะเขือพวง: 1/4 ถ้วย\n้น้ำมะขามเปียก: 1/4 ถ้วย\nน้ำตาลปี๊บ: 1 ช้อนโต๊ะ\nขนมจีน: ตามชอบ\""
},
{
    'ชื่ออาหาร': 'ผัดกะเพรากุ้ง',
    'ingredient_full_json': "\"กุ้งแกะเปลือก: 15 ตัว\nพริกชี้ฟ้าและกระเทียมโขลก: 1 ช้อนโต๊ะ\nใบกะเพรา: ตามชอบ\nน้ำตาลทราย: 2 ช้อนชา\nน้ำปลา: 1 ช้อนโต๊ะ\nน้ำมันรำข้าวสำหรับผัด:\""
},
{
    'ชื่ออาหาร': 'ข้าวกะเพราเนื้อสับ-ไข่ดาว',
    'ingredient_full_json': "\"เนื้อวัวสับ: 70กรัม\nพริกแดงจินดา: 4 เม็ด\nกระเทียมสับ: 3 กลีบ\nน้ำปลา: 1 ช้อนโต๊ะ\nซีอิ๊วขาว: 1/2 ช้อนโต๊ะ\nน้ำตาลทราย: 1 ช้อนชา\nใบกะเพรา (ตามชอบ): 1กำ\nน้ำมันรำข้าว 2 ช้อนโต๊ะ: 2 ช้อนโต๊ะ\""
},
{
    'ชื่ออาหาร': 'ผัดกะเพรากุ้ง',
    'ingredient_full_json': "\"กุ้งสดปอกเปลือก: 500 กรัม\nผงปรุงรสผัดกะเพราสำเร็จรูป: 1 ช้อนโต๊ะ\nน้ำตาลทราย: 1/2 ช้อนชา\nกะเพรา: 1 กำมือ\nพริกชี้ฟ้าเขียว: 1 ดอก\nพริกขี้หนูสด: 2 ดอก\nกระเทียมสับ 5-6 กลีบ: 1-2 ช้อนชา\nน้ำมันมะกอก: 1 ช้อนโต๊ะ\nน้ำอุ่น: 50 มล.\""
},
{
    'ชื่ออาหาร': 'ผัดเปรี้ยวหวานหมู',
    'ingredient_full_json': "\"เนื้อหมู: 100 กรัม\nแตงกวา: 3 ลูก\nสับปะรดเนื้อ 2: 100 กรัม\nหอมหัวใหญ่: 1 หัว\nมะเขือเทศ: 6 ลูก\nพริกหยวกสีเขียว: 3 เม็ด\nกระเทียมสับ: 1 ช้อนโต๊ะ\nน้ำตาล: 1/2 ช้อนโต๊ะ\nน้ำปลา: 1 ช้อนโต๊ะ\nซอสมะเขือเทศ: 3 ช้อนโต๊ะ\nน้ำเปล่าหรือน้ำซุป: 1/4 ถ้วย\nน้ำมันสำหรับผัด: 2 ช้อนโต๊ะ\nต้นหอมหั่นท่อน: 1 ต้น\""
},
{
    'ชื่ออาหาร': 'น้ำจิ้มปลาเผา (มะขาม)',
    'ingredient_full_json': "\"มะขาม: 1 ปั้น\nน้ำตาลปิ้บ: 1 ช้อนโต๊ะ\nน้ำเปล่า: 1 ถ้วย\nพริกขี้หนู: 10 เม็ด\nหอมแดง: 8 หัว\""
},
{
    'ชื่ออาหาร': 'แกงส้มผักรวมน้ำข้น',
    'ingredient_full_json': "\"น้ำ: 1/2ลิตร\nหัวไชเท้า: 1หัว\nแครอท: 1หัว\nถั่วฝักยาว: 1กำ\nเนื้อปลาดอลลี่แช่แข็ง(หรือจะใช้ปลาชนิดอื่นได้ แต่ควรเป็นปลาเนื้ออ่อน): 2ชิ้น\nผงทำแกงส้มคนอร์: 1ซอง\nน้ำมะขามเปียก (ตอนอยู่ที่อเมริกาไม่มี เราแอบใช้น้ำส้มสายชูแทน แต่ถ้าหาได้น้ำมะขามจะหอมกว่าเยอะ): 1ถ้วยเล็ก\nน้ำตาลทราย: 2ช้อนโต๊ะ\nน้ำปลา: 1ช้อนโต๊ะ\""
},
{
    'ชื่ออาหาร': 'แกงส้มปลาทู (แกงส้มใต้)',
    'ingredient_full_json': "\"ปลาทู: 3 ตัว\nมะละกอ: 300 กรัม\nผักบุ้งไทย: 100 กรัม\nน้ำมะขามเปียก: 2 ช้อนโต๊ะ\nน้ำตาลทราย: 1 ช้อนชา\nน้ำสะอาด: 600 มล\nเครื่องแกงส้มใต้: 1 1/2 ช้อนโต๊ะ\nกะปิ: 1 ช้อนชา\nมะนาว: 1 ลูก\""
},
{
    'ชื่ออาหาร': 'ขนมจีนน้ำยาปลาช่อน X ตีนไก่+ลูกชิ้นปลา',
    'ingredient_full_json': "\"ขนมจีน: 2กก\nปลาช่อน: 1ตัว\nกะทิหัวหาง: 1กก\nพริกแกงเผ็ด: 2ขีด\nกระชายซอย: 20บาท\nปลาอินทรีย์เค็ม: 1ชิ้น\nกะปิ: 1ชต\nน้ำปลา: 1-2ถ้วย\nผักสดต่างๆ: \nผักกาดดอง: \nใบแมงลัก: \nพริกแห้ง:\""
},
{
    'ชื่ออาหาร': 'เส้นใหญ่ผัดซีอิ๊วไก่',
    'ingredient_full_json': "\"เส้นใหญ่: 350 กรัม\nไก่หั่นเป็นชิ้น: 200 กรัม\nไข่ไก่: 2 ฟอง\nคะน้าหั่นท่อน: 3 ต้น\nกระเทียมสับ: 1 ช้อนโต๊ะ\nซีอิ๊วดำ: 2 ช้อนโต๊ะ\nน้ำปลา: 1 ช้อนโต๊ะ\nซอสปรุงรส: 2 ช้อนชา\nซีอิ๊วขาว: 1 ช้อนโต๊ะ\nน้ำมันพืช: \nมะนาว. พริกไทย:\""
},
{
    'ชื่ออาหาร': 'ยำวุ้นเส้นเครื่องล้น',
    'ingredient_full_json': "\"วุ้นเส้นสด: 1ห่อ\nหมูสับ: 2กรัม\nเห็ดเข็มทอง: 1ห่อ\nหอมแขก: ครึ่งหัว\nขึ้นช่าย: 2ต้น\nแครอท: เล็กน้อย\nผักกาดขาว: 3ใบ\nน้ำปลา: 2ช้อนโต๊ะ\nน้ำมะนาวสด: 2ช้อนโต๊ะ\nน้ำตาล: 1ช้อนชา\nพริกป่น: 1ช้อนโต๊ะ\""
},
{
    'ชื่ออาหาร': 'แกงเลียงใบตำลึง',
    'ingredient_full_json': "\"ใบตำลึง: 2 กำ\nไข่ไก่: 2 ฟอง\nกะปิ: 1 ช้อนโต๊ะ\nปลาฉิ้งฉ้าง: 1/2 ถ้วย\""
},
{
    'ชื่ออาหาร': 'ผัดฟักทองใส่ไข่ นิ่ม ฟิน',
    'ingredient_full_json': "\"ฟักทอง: 500 กรัม\nไข่ไก่: 2 ฟอง\nน้ำตาล: 1 ช้อนโต๊ะ\nน้ำปลา: 1/2 ช้อน\nแมกกี้: เหยาะๆให้หอม\nน้ำมันหอย: 2 ช้อนโต๊ะ\nกระเทียม: 4 กลีบ\""
},
{
    'ชื่ออาหาร': 'น้ำพริกกะปิกุ้งแห้ง',
    'ingredient_full_json': "\"กะปิอย่างดี: 30 กรัม\nกุ้งแห้ง: 1+1/2 ช้อนโต๊ะ\nพริกขี้หนูสวน: 25 เม็ด\nกระเทียมไทยกลีบเล็ก: 15 กลีบ\nน้ำปลา: ตามชอบ\nน้ำตาลปี๊บ: ตามชอบ\nน้ำมะนาว: ตามชอบ\nน้ำเปล่าต้มสุก: 1 ช้อนโต๊ะ\nใบตองหรือใบต้นกระชาย: 1 ใบ\nมะเขือพวง: 10 เม็ด\""
},
{
    'ชื่ออาหาร': 'น้ำพริกกะปิปลาทู',
    'ingredient_full_json': "\"กะปิ 5 ช้อนโต๊ะ: \nน้ำตาลปี๊บ 1 ช้อนโต๊ะ: \nมะนาว 7 ช้อนโต๊ะ: \nกระเทียม 6 ช้อนโต๊ะ: \nพริกขี้หนู 20 เม็ด: \nปลาทู 2 ตัว: \nน้ำต้มสุก 6 ช้อนโต๊ะ:\""
},
{
    'ชื่ออาหาร': 'แกงส้มไหลบัวปลากระพงปักษ์ใต้',
    'ingredient_full_json': "\"ไหลบัว: 8 เส้น\nพริกป่นแบบใต้ที่ละเอียด: 2 ช้อนโต๊ะ\nกะปิ: 1 ช้อนโต๊ะ\nเกลือ: 1/2 ช้อนชา\nปลากระพงหั่นชิ้นขนาดพอคำ: 1 ตัว\nมะนาว: 7 ช้อนโต๊ะ\nพริกไทยเม็ดดำ: 10 เม็ด\""
},
{
    'ชื่ออาหาร': 'ข้าวต้มหมูทรงเครื่อง',
    'ingredient_full_json': "\"ข้าวสวย: 2 ถ้วย\nหมูสับปั้นเป็นก้อนกลม: 150 กรัม\nคนอร์ซุปก้อน: 1 ก้อน\nน้ำเปล่า: 3-4 ถ้วย\nขิงแก่ซอย: 2 ช้อนโต๊ะ\nกระเทียมสดแกะเปลือก: 1 ช้อนโต๊ะ\nกุ้งแห้ง: 1 ช้อนโต๊ะ\nปลาหมึกแห้ง: 1 ช้อนโต๊ะ\nคื่นช่ายหั่นซอย: 1 ช้อนโต๊ะ\nพริกไทยป่น: \nเกลือ: 1/3 ช้อนชา\nซอลแม็กกี้: 1 1/2 ช้อนชา\""
},
{
    'ชื่ออาหาร': 'ต้มยำกุ้งแม่น้ำ (น้ำข้น)',
    'ingredient_full_json': "\"กุ้งแม่น้ำ: 5ขีด\nเม็ดฟาง: \nข่า: \nตะไคร้: \nใบมะกรูด: \nมะนาว: \nพริก: \nน้ำปลา: \nน้ำตาล: \nนมสดจืด:\""
},
{
    'ชื่ออาหาร': 'ผัดเผ็ดไก่มะเขือเปาะ',
    'ingredient_full_json': "\"อกไก่: 1อก\nตับไก่: 20บาท\nมะเขือเปาะ: 6-8ลูก\nโหระพา: 5บาท\nใบมะกรูดฉีก: 5-6ใบ\nพริกแกงเผ็ด: 10บาท\nกะทิกล่องเล็ก: 1กล่อง\nน้ำตาลปึก: 2/4:ก้อน\nน้ำปลา: 3-5ชต\""
},
{
    'ชื่ออาหาร': 'แกงส้มฟักแม้วกุ้งสด',
    'ingredient_full_json': "\"ฟักแม้ว: 2 หัว\nปลานิล: 1 ตัว\nพริกแกงส้ม: 1 ขีด\nน้ำมะขามเปียก: 5 ช้อน\nน้ำปลา: 4 ช้อน\nน้ำตาลปีบ: 1 ช้อน\nกุ้ง: 6-7 ตัว\nเกลือป่น: 1/2\""
},
{
    'ชื่ออาหาร': 'แกงเขียวหวานหน่อไม้ไก่',
    'ingredient_full_json': "\"เนื้อสะโพกไก่: 3 ชิ้น\nพริกแกงเขียวหวานสำเร็จรูปตามตลาดสด: 10 บาท\nกะทิ: 0.5 กิโล\nใบโหระพา: 5 บาท\nหน่อไม้ดอง: 0.5 กิโล\nน้ำปลา: ตามชอบ\nน้ำตาล: ตามชอบ\""
},
{
    'ชื่ออาหาร': 'ขนมจีนน้ำยา สูตรเด็ด',
    'ingredient_full_json': "\"ปลาทับทิม: 1 โล\nกะทิ: 1 โล\nหางกะทิ: 1 โล\nลูกชิ้นปลา: ตามใจชอบ\nกระชาย: 2 ขีด\nกะปิ: 1 ช้อนโต๊ะ\nน้ำปลา: 1 ช้อนโต๊ะ\nพริกแกงน้ำยา: 2 ขีด\nคนอร์: 2 ก้อน\nน้ำตาลปี๊บ: 1 ช้อนชา\""
},
{
    'ชื่ออาหาร': 'ข้าวผัดต้มยำกุ้ง',
    'ingredient_full_json': "\"ข้าวสวย: 1ถ้วย\nกุ้งสดปอกเปลือกผ่าหลัง: 40กรัม\nข่าซอย: 1ช้อนโต๊ะ\nตะไคร้ซอย: 2ต้น\nใบมะกรูดซอย: 1ช้อนโต๊ะ\nหอมแดงซอย: 2หัว\nมะเขือเทศหั่นเต๋าเล็ก: 1ช้อนโต๊ะ\nน้ำมะนาว: 1ช้อนโต๊ะ\nพริกแดงซอย: 1ช้อนโต๊ะ\nเห็ดฟาง: ตามชอบ\nกระเทียมสับ: 1ช้อนโต๊ะ\nน้ำพริกเผา: 1 1/2 ช้อนโต๊ะ\nน้ำปลา: 1/2ชต\nน้ำตาลทราย: 1/2ช้อนชา\nน้ำมันพืช: \nต้นหอมซอย:\""
},
{
    'ชื่ออาหาร': 'แกงส้มชะอมไข่ใส่ปลาทู',
    'ingredient_full_json': "\"ชะอมเด็ดเอาแต่ใบ: 1ถ้วย\nไข่ไก่: 1ฟอง\nผักกาดขาว: 1หัว\nหัวไชเท้า: 1หัว\nพริกแกงส้มตามสูตรเคยที่ให้ไว้นะคะ: 3 ช้อน\nน้ำมะขามเปียก: 5 ช้อน\nน้ำตาลปีบ: 2ช้อน\nน้ำปลา: 3ช้อน\nน้ำมันพืชสำหรับทำไข่ชะอม: 1 ช้อนชา\nปลาทูย่างแกะเอาแต่เนื้อ: 2 ตัว\""
},
{
    'ชื่ออาหาร': 'ต้มยำปลากระป๋อง',
    'ingredient_full_json': "\"1.ปลากระป๋อง: 2 กระป๋อง\n2.ข่า: 8 แว่น\n3.ตะไคร้: 3 ต้น\n4.ใบมะกรูด: 5-6 ใบ\n5.หอมแดง: 3 หัว\n6.น้ำเปล่า: 3 ถ้วย\n7.มะนาว: 2 ลูก\n8.น้ำปลา: 1+1/2 ช้อนโต๊ะ\n9.ซุปคนอร์ก้อน: 1 ก้อน\n10.พริกขี้หนูบุบ: 10 เม็ด\n11.ผักชีใบเลื่อย: 3 ใบ\n12.เห็ดนางฟ้า: 1 ถ้วย\""
},
{
    'ชื่ออาหาร': 'แกงส้มใต้มันขี้หนู',
    'ingredient_full_json': "\"มันขี้หนู: 300 กรัม\nปลาทูสดหรือปลาอะไรก็ได้: 4-5 ตัว\nน้ำพริกแกงเหลือง: 2 ช้อนโต๊ะ\nน้ำเปล่า: 4 ถ้วย\nน้ำปลา: 3 ช้อนโต๊ะ\nน้ำตาลปี๊บ: 1 ช้อนโต๊ะ\nน้ำมะขามเปียก: 3 ช้อนโต๊ะ\nส้มแขก: 3 ชิ้น\nน้ำมะนาว: ตามชอบ\nกะปิ: 2 ช้อนชา\""
},
{
    'ชื่ออาหาร': 'สูตร แกงเลียง ระดับเทพ อร่อยกว่าร้านดังแน่นอน',
    'ingredient_full_json': "\"ผักหวาน: 1 กำ\nกวางตุ้งแบบมีดอก: 1 กำ\nชะอม: 1 กำ\nใบแมงลัก: 1 กำ\nบวบ: 5-6 อัน\nฟักทอง: ซีกนึง\nเห็ดนางฟ้า: 1 กำ\nเห็ดหูหนู: 1 กำ\nเห็ดเข็มทอง: 1 กำ\nเห็ดฟาง: 1 กำ\nกุ้ง: ครึ่ง กก\nกระดูกหมู: 1 กิโลกรัม\nพริกกระเหรี่ยง: 1 กำ\nกระชาย: 1 กำ\nหอมแดง: 1 กำ\nกระปิอย่างดี: 2 ช้อนโต๊ะ\nพริกไทยขาว: 2 ช้อนโต๊ะ\nปลาทูนึ่ง: 12 ตัว\nน้ำปลาตราปลาหมึก: ตามความชอบ\""
},
{
    'ชื่ออาหาร': 'แกงเขียวหวานไก่',
    'ingredient_full_json': "\"เนื้ออกไก่: 2 กิโลกรัม\nเลือดไก่: 2 ก้อน\nเครื่องในไก่: 5-6 พวง\nน้ำพริกแกงเขียวหวาน: 6-8 ขีด แล้วแต่ความเผ็ด\nมะเขือเปราะ: 1/2 กิโลกรัม\nหัวกะทิ: 1 กิโลกรัม\nหางกะทิ: 2 กิโลกรัม\nน้ำปลา: 6 ช้อนโต๊ะ\nเกลือ: 1-2 ช้อนโต๊ะ\nใบโหระพาเด็ด: ปริมาณตามชอบ\nพริกชี้ฟ้าหั่นแฉลบ: ปริมาณตามชอบ\nน้ำตาลปี๊บ: เล็กน้อย\""
},
{
    'ชื่ออาหาร': 'แกงเขียวหวานลูกชิ้นปลากราย',
    'ingredient_full_json': "\"ลูกชิ้นปลากรายเม็ดจิ๋ว: 1/2กก\nพริกแกงเขียวหวาน: 1ขีด\nกะทิ: 2กล่อง\nมะเขือเปาะ: 10-15ลูก\nกระชายฝอย: 1/2ขีด\nโหรภา: 1กำ\nพริกชี้ฟ้าแดง: 3เม็ด\nใบมะกรูดฉีก: 5-6ใบ\nน้ำตาลปึก: 3 ก้อน\nน้ำปลา: 1ถ้วย\nน้ำตาลทราย: 3-5ชช\""
},
{
    'ชื่ออาหาร': 'ขนมจีนน้ำยากะทิไก่ไม่เผ็ดสำหรับเด็ก',
    'ingredient_full_json': "\"เนื้อไก่บด (ไก่ต้มที่ได้จากทำน้ำสต็อก): 100 กรัม\nกะทิ (แบ่ง 2ส่วน ส่วนละ150มล): 300 มล.\nพริกแกงเด็ก(ตามสูตรที่ลงไว้): 80 กรัม\nน้ำสต็อกไก่: 2 ถ้วย\nเลือดไก่: 80 กรัม\nน้ำปลา: 2 ช้อนโต๊ะ\nน้ำตาลปี๊บ: 1/2 ช้อนโต๊ะ\nต้นหอมหั่น: 2 ต้น\nใบมะกรูดฉีก: 3 ใบ\nน้ำมันพืช: 1 ช้อนโต๊ะ\nเส้นขนมจีนอัญชัน: ตามชอบ\nผักเครื่องเคียง: ตามชอบ\nไข่ต้ม:\""
},
{
    'ชื่ออาหาร': 'ยำปลากระป๋องทอดกร๊อบกรอบ',
    'ingredient_full_json': "\"ปลากระป๋อง: 3 กระป๋อง\nมะนาว: 3 ลูก\nน้ำปลา: 1 ช้อนโต๊ะ\nต้นหอมหั่นท่อน: 4 ต้น\nพริกขี้หนูซอย: 3 ช้อนโต๊ะ\nแครอทซอยเป็นเส้นๆ: 1 ถ้วย\nขึ้นฉ่ายหั่นท่อน: 1 ต้น\nน้ำตาลทราย: 1 ช้อนชา\nไข่ไก่: 1 ฟอง\nเกล็ดขนมปัง: 1 จาน\nแป้งเอนกประสงค์: 1 จาน\nน้ำมัน:\""
},
{
    'ชื่ออาหาร': 'ข้าวผัดรถไฟ (ข้าวผัดซีอิ๊ว)​',
    'ingredient_full_json': "\"หมู: 50 กรัม\nไข่ไก่: 2 ฟอง\nข้าวสวย: 3 ถ้วย\nต้มหอม: 2 ต้น\nหอมใหญ่: 1/4 หัว\nมะเขือเทศ: 1 ลูก\nคะน้า: 2 ต้น\nน้ำตาล: 1 ชต\nซีอิ๊ว: 1 ชต\nเกลือ: 1 ชต\nน้ำมันหอย: 1 ชต\nซีอิ๊วดำ: 1 ชช\nกระเทียม: 3 กลีบ\""
},
{
    'ชื่ออาหาร': 'แกงส้มดอกแคเนื้อปลานินทอดกรอบ',
    'ingredient_full_json': "\"พริกแกงส้ม: 2ขีด\nน้ำเปล่า: 1ลิตร\nน้ำมะขามเปียก: 1ถ้วยเล็ก\nน้ำตาลปี้ป: 1/2ทัพพี\nดอกแค: 20ดอก\nน้ำปลา: 2 ช้อนโต๊ะ\nเนื้อปลานิน: 1ตัว\""
},
{
    'ชื่ออาหาร': 'ผัดเผ็ดปลาดุกพริกสด',
    'ingredient_full_json': "\"ปลาดุก: \nมะเขือเจ้าพระยา: \nใบมะกรูด: \nกระชาย: \nพริกไทยอ่อน: \nซอสปรุงรส: \nน้ำมันหอย: \nผงปรุงรส: \nกระเทียม: \nพริกขี้หนู:\""
},
{
    'ชื่ออาหาร': 'แกงส้มไข่ปลาเรียวเซียว',
    'ingredient_full_json': "\"ยอดมะพร้าว: 200กรัม\nไข่ปลาเรียวเซียว: 200กรัม\nเนื้อปลาช่อน: 100กรัม\nน้ำสต็อก: 2ถ้วย\nพริกแกงส้ม: 1ชต\nข่า ตะไคร้ ใบมะกรูด: 1/2 ถ้วย\nน้ำปลา: 1ชต\nน้ำตาลปี๊บ: 1ชต\nมะขามเปียก: 1/2ถ้วย\""
},
{
    'ชื่ออาหาร': 'ขนมจีนน้ำยากะทิหมู',
    'ingredient_full_json': "\"หมูบด: 250 กรัม\nพริกแกงเผ็ด: 70 กรัม\nกระชายซอย: 50 กรัม\nกะทิ: 500 มล.\nใบมะกรูด: 1 กิ่ง\nผงปรุงรส: 1 ก้อน\nขนมจีน ผัก ตามชอบ: 1 ชุด\""
},
{
    'ชื่ออาหาร': 'หอยทอด(ทะเลทอด)',
    'ingredient_full_json': "\"แป้งทอดกรอบ: 1ถ้วย\nกุ้ง: 12ตัว\nหมึก: 3ตัว\nหอยแมงภู่: 100กรัม\nน้ำเย็ดจัด: 1ถ้วย\nนมสด: 1/2ถ้วย\nไข่ไก่: 3ฟอง\nถั่วงอกดิบ: ตามชอบ\nพริกไทยป่น: ตามชอบ\nซีอิ้วขาว: 2ช้อนโต๊ะ\nน้ำปลา: 1ช้อนโต๊ะ\nน้ำตาล: 1ช้อนโต๊ะ\nต้นหอมผักชี: 2-3ต้น\""
},
{
    'ชื่ออาหาร': 'แกงเทโพหมูสามชั้น',
    'ingredient_full_json': "\"หมูสามชั้น: 200 กรัม\nผักบุ้ง: 500 กรัม\nพริกแกงเผ็ด: 100 กรัม\nมะขามเปียก: 1 กำ\nน้ำตาลมะพร้าว: 1 ช้อนโต๊ะ\nน้ำปลา: เหยาะๆ ลงไป\nมะกรูด: 3 ลูก\nใบมะกรูด: 10 ใบ\nกะทิ: 1000 มล\""
},
{
    'ชื่ออาหาร': 'เส้นหมี่ผัดซีอิ๊วหมูนุ่ม',
    'ingredient_full_json': "\"เส้นหมี่สำเร็จรูป: 180 กรัม\nหมูนุ่ม: 200 กรัม\nกระเทียมสับ: 1 ช้อนโต๊ะ\nน้ำมันพืช: 2-3 ช้อนโต๊ะ\nซีอิ๊วดำสำหรับคลุกเส้น: \nซีอิ๊วขาว: 3 ช้อนโต๊ะ\nน้ำปลา: 1 ช้อนโต๊ะ\nน้ำตาลทราย: 1 ช้อนชา\nผักคะน้า: 2 ต้น\nไข่ไก่เบอร์ 1: 3 ฟอง\""
},
{
    'ชื่ออาหาร': 'ต้มยำกุ้งมะพร้าวอ่อน',
    'ingredient_full_json': "\"พริกขี้หนู: 7 เม็ด\nตะไคร้: เล็กน้อย\nใบมะกรูด: เล็กน้อย\nข่า: เล็กน้อย\nผักชีฝรั่ง: เล็กน้อย\nเห็ดนางฟ้า: 70 กรัม\nเห็ดหลินขาว: 40 กรัม\nเห็ดฟาง: 100 กรัม\nเนื้อมะพร้าวอ่อน: 80 กรัม\nน้ำมะพร้าว: 700 ml.\nกุ้งแกะเปลือก: 200 กรัม\nน้ำตาลทราย: 2 ช้อนชา\nน้ำปลา: 6 ช้อนโต๊ะ\nน้ำมะนาว: 6 ช้อนโต๊ะ\nกะทิ: 100 ml.\nน้ำพริกเผา: 2 ช้อนโต๊ะ\nมันกุ้ง: 1 ช้อนโต๊ะ\""
},
{
    'ชื่ออาหาร': 'หน่อไม้ผัดพริกแกงหมูสับ',
    'ingredient_full_json': "\"หน่อไม้ต้ม ซอยบางๆ: 1 ถ้วย\nน้ำพริกแกงเผ็ด: 2 ช้อนโต๊ะ\nหมูสับ: 1/4 ถ้วย\nใบมะกรูดฉีก: 4-5 ใบ\nพริกไทยอ่อนตัดสั้นๆ: 3-4 ฝัก\nพริกชี้ฟ้าซอย: 1 เม็ด\nน้ำตาลทราย: 1/2 ช้อนโต๊ะ\nน้ำปลา: 1-2 ช้อนโต๊ะ\""
},
{
    'ชื่ออาหาร': 'แกงส้มผักบุ้งปลาน้ำดอกไม้',
    'ingredient_full_json': "\"ผักบุ้งไทย: 2 กำ\nปลาน้ำดอกไม้: 2 ตัว\nพริกแกงส้ม: 2 ขีด\nมะขามเปียก: 5 ฝัก\nน้ำปลา: 5ช้อนโต้ะ\nน้ำตาลปี๊บ: 3ช้อนโต้ะ\nเกลือ: 2ช้อนโต้ะ\nน้ำเปล่า: 4 ลิตร\""
},
{
    'ชื่ออาหาร': 'ฉู่ฉี่ปลาหมอ',
    'ingredient_full_json': "\"ปลาหมอตัวใหญ่ๆ: 2 ตัว\nเครื่องแกงผัดเผ็ดภาคกลาง: 200 กรัม\nเครื่องแกงพะแนงกับกระชายสับละเอียด: 100 กรัม\nกระชายซอย: 50 กรัม\nใบมะกรูดซอย: 20 กรัม\nกะทิคั้น: 400 กรัม\nคะไคร้หั่นท่อน: 2 ต้น\nข่า: 20 กรัม\nใบมะกรูดฉีก: 15 กรัม\nพริกขี้หนูสวน: 10-15 เม็ด\""
},
{
    'ชื่ออาหาร': 'แกงเทโพใส่หมูสามชั้น',
    'ingredient_full_json': "\"หมูสามชั้น (หั่นชิ้นพอคำ ไม่ต้องหนามาก): 200 กรัม\nผักบุ้งไทย (หั่นท่อนพอคำ ล้างให้สะอาด): 400 กรัม\nหัวกะทิ: 1 ถ้วย\nหางกะทิ: 2 1/2 ถ้วย\nน้ำมะขามเปียก: 3-4 ช้อนโต๊ะ\nน้ำตาลปี๊บ: 1 ช้อนโต๊ะ\nน้ำปลา: 3 ช้อนโต๊ะ\nมะกรูด ผ่าครึ่ง เอาเมล็ดออก): 2 ลูก\nเกลือ: 1 ช้อนชา\nใบมะกรูด: 4-5 ใบ\nผงปรุงรสคนอร์ อร่อยชัวร์: 2 ช้อนชา\nน้ำพริกแกงเผ็ด: 100 กรัม\""
},
{
    'ชื่ออาหาร': 'ขนมจีนน้ำยาป่าปลาดุกย่าง',
    'ingredient_full_json': "\"ปลาดุกย่าง: 2 ตัว\nกระเทียม: 5 กลีบ\nหอมแดง: 5 หัว\nกระชาย: 8 ราก\nตะไคร้: 2 ต้น\nใบมะกรูด​: 10 ใบ\nพริกแห้ง: 7 เม็ด\nขนมจีน: 1 กิโล​กรัม\nน้ำเปล่า: 6 ถ้วย\nเกลือ: ปรุงรส\""
},
{
    'ชื่ออาหาร': 'ผัดเปรี้ยวหวานไก่กรอบ',
    'ingredient_full_json': "\"สันในไก่หั่นชิ้นพอดีคำ: 2-3 เส้น\nแป้งอเนกประสงค์: 1 ถ้วย\nหอมใหญ่ปอก หั่นเสี้ยว: 1 ลูก\nมะเขือเทศสีดาผ่าครึ่ง: 2-3 ลูก\nพริกหวานหั่นพอดีคำ: 1/2 ลูก\nแตงร้าน ปอกเปลือก หั่นชิ้นพอดีคำ: 1/2 ลูก\nเห็ดหอมสดผ่าสี่: 2 ดอก\nต้นหอมหั่นท่อน: 3-4 ต้น\nกระเทียมสับ: 1 ช้อนโต๊ะ\nน้ำตาลทราย: 1 ช้อนโต๊ะ\nซอสปรุงรส: 1 ช้อนโต๊ะ\nซอสมะเขือเทศ: 1/2 ถ้วย\nน้ำส้มสายชู: 1 ช้อนโต๊ะ\""
},
{
    'ชื่ออาหาร': 'บะหมี่ผัดเย็นตาโฟแห้ง',
    'ingredient_full_json': "\"บะหมี่: 1\nลูกชิ้นปลา: ตามชอบ\nลูกชิ้นกุ้ง: ตามชอบ\nฮื่อก๊วย: ตามชอบ\nเกี๊ยวปลา: ตามชอบ\nปลาหมึกกรอบ: ตามชอบ\nผักบุ้งไทย: ตามชอบ\nซอสเย็นตาโฟ: 1\nพริกแดงจินดา: 4-5 เม็ด\nกระเทียม: 3-4 กลีบ\nซอสหอยนางรม: 1/2 ช้อนโต๊ะ\nน้ำตาล: 1/2 ช้อนชา\nซีอิ๊วขาว: 1/2 ช้อนชา\nน้ำส้มสายชู: 1 ช้อนชา\nน้ำมัน: 1/2 ช้อนโต๊ะ\""
},
{
    'ชื่ออาหาร': 'แกงเขียวหวานไก่ใส่หน่อไม้',
    'ingredient_full_json': "\"ไก่สับ: 1/2 ตัว\nเลือดไก่: 1 ก้อน\nมะเขือเปราะ: 500 กรัม\nหน่อไม้: 1 หน่อ\nโหระพา: 4 กิ่ง\nพริกแกงเขียวหวาน: 150 กรัม\nกะทิ: 1000 มิลลิลิตร\nน้ำตาลปี๊บ: 1 ช้อนโต๊ะ\nผงปรุงรส: 2 ก้อน\nน้ำปลา: 2 ช้อนโต๊ะ\nมะเขือพวง: 50 กรัม\""
}
]

new_recipe_df = pd.DataFrame(new_recipe_data)

def transform_ingredients(json_str):
    try:
        data = json.loads(json_str)
        recipe_data = list(data.values())[0]
        ingredients = recipe_data.get('วัตถุดิบ', [])
        return {ing['ชื่อ']: ing['ปริมาณ'] for ing in ingredients}
    except:
        return {}

new_recipe_df['simplified_ingredients'] = new_recipe_df['ingredient_full_json'].apply(transform_ingredients)

def find_closest_match(ingredient, thai_names):
    matches = get_close_matches(ingredient, thai_names, n=1, cutoff=0)
    return matches[0] if matches else None

def calculate_calories(fat, protein, carbs):
    return (fat * 9) + (protein * 4) + (carbs * 4)

def get_nutrition_info(ingredient, nutrition_data):
    closest_match = find_closest_match(ingredient, nutrition_data['Thai_Name'].astype(str))
    if closest_match:
        nutrition_info = nutrition_data[nutrition_data['Thai_Name'] == closest_match]
        if not nutrition_info.empty:
            fat = float(nutrition_info['Fat(g)'].iloc[0]) if nutrition_info['Fat(g)'].iloc[0] not in ('-', '') else 0
            protein = float(nutrition_info['Protein(g)'].iloc[0]) if nutrition_info['Protein(g)'].iloc[0] not in ('-', '') else 0
            carbs = float(nutrition_info['Carbs(g)'].iloc[0]) if nutrition_info['Carbs(g)'].iloc[0] not in ('-', '') else 0
            calories = calculate_calories(fat, protein, carbs)
            return {'protein': protein, 'fat': fat, 'carbs': carbs, 'calories': calories}
    return {'protein': 0, 'fat': 0, 'carbs': 0, 'calories': 0}

new_recipe_df['nutrition_info'] = new_recipe_df['simplified_ingredients'].apply(
    lambda ingredients_dict: {
        ingredient: get_nutrition_info(ingredient, nutrition_data)
        for ingredient in ingredients_dict
    }
)

def calculate_total_nutrition(nutrition_info_dict):
    total_protein = sum(info.get('protein', 0) for info in nutrition_info_dict.values())
    total_fat = sum(info.get('fat', 0) for info in nutrition_info_dict.values())
    total_carbs = sum(info.get('carbs', 0) for info in nutrition_info_dict.values())
    total_calories = sum(info.get('calories', 0) for info in nutrition_info_dict.values())
    return pd.Series({
        'total_protein': total_protein,
        'total_fat': total_fat,
        'total_carbs': total_carbs,
        'total_calories': total_calories
    })

nutrition_totals = new_recipe_df['nutrition_info'].apply(calculate_total_nutrition)
final_df = pd.concat([new_recipe_df[['ชื่ออาหาร', 'simplified_ingredients', 'nutrition_info']], nutrition_totals], axis=1)

final_df['simplified_ingredients'] = final_df['simplified_ingredients'].astype(str)
final_df['nutrition_info'] = final_df['nutrition_info'].astype(str)


from google.colab import sheets
sheet = sheets.InteractiveSheet(df=final_df)
# Out:
# https://docs.google.com/spreadsheets/d/1xcVZ3zmJ3akf-wx1-BenQKUXBePgVwwfigiTopckA4o/edit#gid=0
#         <iframe
#             width="100%"
#             height="600"
#             src="https://docs.google.com/spreadsheets/d/1xcVZ3zmJ3akf-wx1-BenQKUXBePgVwwfigiTopckA4o/edit?rm=embedded#gid=0"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %% [markdown]
# ใส่วัตถุดิบ

# %%
# อันนี้ที่แอดเพิ่มให้ครบ
import pandas as pd

df = pd.read_csv("recipe_original.csv")

dish_list = [
    "ข้าวไข่ข้นกุ้ง",
    "แกงจืดเต้าหู้หมูสับ",
    "แกงเหลือง",
    "ปลานึ่งมะนาว",
    "แกงป่า",
    "น้ำพริกหนุ่ม",
    "หมูฮ้อง",
    "ข้าวคลุกกะปิ",
    "ปลากะพงทอดน้ำปลา",
    "แกงบวดฟักทอง",
    "พะแนงเนื้อ",
    "ปลาทอดขมิ้น",
    "ต้มโคล้งปลากรอบ",
    "น้ำตกเนื้อ",
    "ต้มจืดมะระยัดไส้",
    "ข้าวขาหมู",
    "ต้มยำปลาคัง",
    "ไก่ผัดขิง",
    "ยำไข่ดาว",
    "แกงเผ็ดเป็ดย่าง",
    "หมูทอดกระเทียม",
    "ขนมจีนน้ำพริก",
    "ก๋วยเตี๋ยวคั่วไก่ แบบง่าย",
    "ข้าวหมูแดง ไมโครเวฟ",
    "แกงเขียวหวานไก่ ไมโครเวฟ",
    "ต้มยำกุ้งน้ำข้นยอดมะพร้าว",
    "มาม่าผัดขี้เมาทะเล",
    "แกงเขียวหวานหมู (มือใหม่หัดแกง)",
    "แกงส้มปลากระพงผักรวม (แกงส้มปักษ์ใต้)",
    "ต้มยำกุ้งน้ำใส",
    "แกงส้มใต้",
    "ปลาเผาผักสด/เมี่ยงปลาเผา/ปลานิลเผาเกลือ แบบใช้เตาอบ",
    "น้ำพริกกะปิสูตรคุณยาย",
    "แกงเขียวหวานไก่",
    "แกงส้มมะละกอปลากระป๋อง",
    "พริกแกงเหลือง (แกงส้มใต้)",
    "น้ำพริกกะปิสูตรอร่อยเด็ด",
    "ผัดซีอิ๊ว + สอนเทคนิคผัดเส้นระดับโปร",
    "แกงส้มชะอมกุ้งพริกแกงใต้",
    "ยำปลากระป๋องแบบบ้าน",
    "น้ำพริกกะปิ ปลาทูทอด",
    "แกงเขียวหวานไก่ใส่ฟัก",
    "ไข่เจียวหมูสับหน้ากรอบ",
    "เทคนิค กะเพราหมูสับ แบบแห้ง อร่อยกว่าร้าน",
    "แกงเขียวหวานไก่ผัดแห้ง",
    "ปูหลน",
    "ขนมจีนแกงเขียวหวานไก่",
    "ยำสามกรอบ",
    "ขนมจีนน้ำยาปลาทู",
    "แกงส้มปลาหน่อไม้ดอง",
    "พริกแกงมัสมั่น​",
    "ขนมครกสิงคโปร์",
    "ไก่ผัดเม็ดมะม่วงหิมพานต์ (น้ำพริกเผา) Gai Pad Med Mamuang",
    "แกงส้มผักบุ้งกุ้งลอยน้ำ",
    "ข้าวผัดซีอิ๊วดำ",
    "ขนมจีนน้ำยากะทิไก่",
    "ผัดกะเพราเนื้อสับ",
    "แกงเขียวหวานตีนไก่",
    "ต้มยำปลาทู",
    "ฉู่ฉี่กุ้งปลาหมึก",
    "มาม่าผัดกะเพราหมูสับ",
    "ฉู่ฉี่ปลาทูสด",
    "ฉู่ฉี่ปลาทูทอด",
    "แกงเขียวหวาน​(หมู)​",
    "มาม่าผัดต้มยำกุ้ง",
    "โรลข้าวน้ำพริกกะปิ",
    "แกงส้มผักรวมเจ",
    "ผัดไทยกุ้งสด หัวกุ้งทอดกรอบ",
    "ข้าวมันไก่คลีน",
    "ขนมจีนน้ำยาไก่",
    "ต้มยำกุ้งน้ำข้น",
    "ข้าวผัดแกงเขียวหวาน",
    "ต้มยำปลากระป๋อง",
    "ข้าวผัดน้ำพริกลงเรือสูตรโบราณแกล้มหมูกรอบทอดน้ำปลา",
    "แกงมัสมั่นไก่",
    "แกงส้มผักรวม",
    "ข้าวมันไก่เด็กหอ",
    "แกงส้มปลาทูสด",
    "เครื่องในไก่ทอดกระเทียม",
    "ข้าวกะเพราเนื้อไข่ดาว เมนูนี้ไม่มีเบื่อ",
    "ผัดกะเพราโบราณ, ผัดกะเพราเนื้อสับ",
    "แกงเทโพหมูสามชั้น",
    "แกงเลียงปลากรอบ",
    "แกงส้มผักกระเฉด",
    "ก๋วยเตี๋ยวคั่วไก่",
    "แกงเขียวหวานสำเร็จรูป",
    "ข้าวกะเพราไก่ไข่ดาว",
    "แกงส้มกุ้งสับปะรด",
    "แกงเขียวหวาน สันในหมู",
    "ฉู่ฉี่ปลาทู",
    "แกงเลียงกะทิสด",
    "แกงเลียงกุ้งสด",
    "ฉู่ฉี่ปลานิล (สูตรคุณยาย)",
    "แกงส้มผักรวมปลากระพง",
    "ขนมจีนน้ำยากะทิไก่ข้น (หลัวรักหลัวหลง)",
    "ขนมจีนแกงไตปลา",
    "ผัดกะเพรากุ้ง",
    "ข้าวกะเพราเนื้อสับ-ไข่ดาว",
    "น้ำจิ้มปลาเผา (มะขาม)",
    "แกงส้มผักรวมน้ำข้น",
    "แกงส้มปลาทู (แกงส้มใต้)",
    "ขนมจีนน้ำยาปลาช่อน X ตีนไก่+ลูกชิ้นปลา",
    "เส้นใหญ่ผัดซีอิ๊วไก่",
    "ยำวุ้นเส้นเครื่องล้น",
    "น้ำพริกกะปิกุ้งแห้ง",
    "น้ำพริกกะปิปลาทู",
    "แกงส้มไหลบัวปลากระพงปักษ์ใต้",
    "ข้าวต้มหมูทรงเครื่อง",
    "ต้มยำกุ้งแม่น้ำ (น้ำข้น)",
    "ผัดเผ็ดไก่มะเขือเปาะ",
    "แกงส้มฟักแม้วกุ้งสด",
    "แกงเขียวหวานหน่อไม้ไก่",
    "ขนมจีนน้ำยา สูตรเด็ด",
    "ข้าวผัดต้มยำกุ้ง",
    "แกงส้มชะอมไข่ใส่ปลาทู",
    "แกงส้มใต้มันขี้หนู",
    "สูตร แกงเลียง ระดับเทพ อร่อยกว่าร้านดังแน่นอน",
    "ขนมจีนน้ำยากะทิไก่ไม่เผ็ดสำหรับเด็ก",
    "ยำปลากระป๋องทอดกร๊อบกรอบ",
    "ข้าวผัดรถไฟ (ข้าวผัดซีอิ๊ว)",
    "แกงส้มดอกแคเนื้อปลานินทอดกรอบ",
    "ผัดเผ็ดปลาดุกพริกสด",
    "แกงส้มไข่ปลาเรียวเซียว",
    "ขนมจีนน้ำยากะทิหมู",
    "หอยทอด(ทะเลทอด)",
    "เส้นหมี่ผัดซีอิ๊วหมูนุ่ม",
    "ต้มยำกุ้งมะพร้าวอ่อน",
    "หน่อไม้ผัดพริกแกงหมูสับ",
    "ฉู่ฉี่ปลาหมอ",
    "แกงเทโพใส่หมูสามชั้น",
    "ขนมจีนน้ำยาป่าปลาดุกย่าง",
    "ผัดเปรี้ยวหวานไก่กรอบ",
    "บะหมี่ผัดเย็นตาโฟแห้ง",
    "แกงเขียวหวานไก่ใส่หน่อไม้"
]

matched = df[df["ชื่ออาหาร"].isin(dish_list)]

not_found = [dish for dish in dish_list if dish not in df["ชื่ออาหาร"].values]
if not_found:
    print(" เมนูที่ไม่พบใน DataFrame:")
    for name in not_found:
        print("-", name)
    print("\n---\n")

for _, row in matched.iterrows():
    dish = row['ชื่ออาหาร']
    ingredients = row['วัตถุดิบ']

    if isinstance(ingredients, float):
        ingredients = ""
    else:
        ingredients = ingredients.strip().replace('"', '\\"').replace('\n', '\\n')

    print(f"{{\n    'ชื่ออาหาร': '{dish}',")
    print(f"    'ingredient_full_json': \"\\\"{ingredients}\\\"\"\n}},")
# Out:
#  เมนูที่ไม่พบใน DataFrame:
# - ผัดซีอิ๊ว + สอนเทคนิคผัดเส้นระดับโปร
# - ปูหลน
# - ขนมจีนแกงเขียวหวานไก่
# - ยำสามกรอบ
# - ฉู่ฉี่กุ้งปลาหมึก
# - ฉู่ฉี่ปลาทูทอด
# - แกงเขียวหวาน​(หมู)​
# - ข้าวมันไก่คลีน
# - ข้าวผัดรถไฟ (ข้าวผัดซีอิ๊ว)
# - ขนมจีนน้ำยากะทิหมู
#
# ---
#
# {
#     'ชื่ออาหาร': 'ก๋วยเตี๋ยวคั่วไก่ แบบง่าย',
#     'ingredient_full_json': "\"เส้นใหญ่300กรัม\nไข่ไก่2 ฟอง\nซีอิ๊วขาว2 ช้อนโต๊ะ\nน้ำตาล2 ช้อนชา\nเกลือ 1/2 ช้อนชา1/2 ช้อนชา\nต้นหอม ผักชีซอย1 ช้อนโต๊ะ\nน้ำมันพืชหรือน้ำมันหมูเล็กน้อย\n--เครื่องปรุงหมักไก่--\nอกไก่หั่นชิ้นพอคำ200 กรัม\nน้ำตาลทราย1 ช้อนชา\nแป้งมัน1 ช้อนโต๊ะ\nพริกไทย1/2 ช้อนชา\""
# },
# {
#     'ชื่ออาหาร': 'ข้าวหมูแดง ไมโครเวฟ',
#     'ingredient_full_json': "\"สันในหมู 400 กรัม\nน้ำมันงา 1 ช้อนโต๊ะ\nซอสหอยนางรม 1 ช้อนโต๊ะ\nซีอิ๊วขาว 1 ช้อนโต๊ะ\nผงหมักหมูแดง 4 ช้อนโต๊ะ\nน้ำผึ้ง 1 ช้อนโต๊ะ\nเหล้าจีน 1 ช้อนโต๊ะ\nน้ำเปล่า 1 ถ้วยตวง\nรากผักชี กระเทียม พริกไทย โขลก 2 ช้อนโต๊ะ\nแป้งข้าวโพด 1 ช้อนโต๊ะ\""
# },
# {
#     'ชื่ออาหาร': 'ข้าวไข่ข้นกุ้ง',
# ...

# %%
import pandas as pd
from difflib import get_close_matches


nutrition_data = pd.read_csv("ingredientdnewnew.csv")

new_recipe_data = [
   {
    'ชื่ออาหาร': 'ก๋วยเตี๋ยวคั่วไก่ แบบง่าย',
    'ingredient_full_json': '"เส้นใหญ:่,่่300กรัม\nไข่ไก:่,่่2 ฟอง\nซีอิ๊วขาว:,2 ช้อนโต๊ะ\nน้ำตาล:,2 ช้อนชา\nเกลือ:, 1/2 ช้อนชา\nต้นหอม:,ผักชีซอย:,1 ช้อนโต๊ะ\nอกไก่:,200 กรัม\nน้ำตาลทราย:,1 ช้อนชา\nแป้งมัน:,1 ช้อนโต๊ะ\nพริกไทย:,1/2 ช้อนชา\"'
},
{
    'ชื่ออาหาร': 'ขนมจีนน้ำยากะทิตีนไก่',
    'ingredient_full_json': '"เนื้อไก่:,3 ขีด\nน้ำกะทิ:, 500 กรัม \nพริกแกง:,2 ขีด\nกระชาย1 หัว\nใบมะกรูด:,4-5 ใบ\nตีนไก ่:่,่่1 โล\nเลือดไก่:, 1 ก้อน\nลูกชิ้นปลา:, 500 กรัม \nน้ำตาลทรายแดง:,3 ช้อนโต๊ะ\nเกลือ:,1 ช้อนโต๊ะ\nรสดี:,1 ช้อนโต๊ะ\nขนมจีน :, 1 โล"'
},
{
    'ชื่ออาหาร': 'ผัดเผ็ดไก่บ้าน',
    'ingredient_full_json': '"ไก่:, 500 กรัม\nพริกแกงิ:,2​ ช้อนโต๊ะ\nน้ำมันพืชิ:,2​ ช้อนโต๊ะ\nใบมะกรูดิ:,8​ ใบ\nใบกะเพราิ:,1​ กำมือ\nน้ำปลาิ:,1​ ช้อนโต๊ะ\nซอสปรุงรสิ:,1​ ช้อนชา\nน้ำตาลิ:, 1/2 ช้อนชา"'
},
{
    'ชื่ออาหาร': 'ข้าวต้มหมูสับ',
    'ingredient_full_json': '"ข้าวสวย:,2 ถ้วย\nน้ำเปล่า:,1 ลิตร\nคนอร์ซุปก้อนหมู:,2 ก้อน\nหมูสับ:,200 กรัม\nรากผักชี:,2 ช้อนชา\nน้ำปลา:,1 ช้อนโต๊ะ\nต้นหอมซอย:, 1 ต้น"'
},
{
    'ชื่ออาหาร': 'ข้าวต้มหมูสับ',
    'ingredient_full_json': '"เนื้อหมู:,2 ขีด\nข้าวสวย:,1 ทัพพี\nต้นหอม:,1 ต้น\nผักชี:,1 ต้น\nซีอิ๊วขาว:,1 ช้อนชา\nน้ำตาล:,1 ช้อนชา\nคนอร์:, 1/2ก้อน"'
},
{
    'ชื่ออาหาร': 'เส้นแก้วผัดสุกี้แห้ง',
    'ingredient_full_json': '"น้ำจิ้มสุกี้:, 150 กรัม\nเส้นแก้ว:,200 กรัม\nกระเทียม:,1 ช้อนโต๊ะ\nน้ำมันหอย:,1 ช้อนโต๊ะ\nหมูชิ้น:,100 กรัม\nกุ้ง:,100 กรัม\nผักบุ้ง:,50 กรัม\nแคร์รอต:,50 กรัม\nผักกาดขาว:,50 กรัม\nไข่ไก่:,3 ฟอง\nต้นหอม:,20 กรัม\nขึ้นฉ่าย:,10 กรัม\nน้ำมันพืช:,2 ช้อนโต๊ะ\"'
},
{
    'ชื่ออาหาร': 'ข้าวมันไก่สามสหาย',
    'ingredient_full_json': '"ข้าวหอมมะลิ:,300 กรัม\nน้ำซุปกระดูกไก่:,390 มิลลิลิตร\nกระเทียม:,5 กลีบ\nรากผักชี:,5 ราก \nขิงแก่:, 6 แผ่น\nน้ำมันพืช:,40 มิลลิลิตร\nสะโพกไก่:,600 กรัม\nซอสหอยนางรม:,3 ช้อนโต๊ะ่\nซอสปรุงรส:,3 ช้อนโต๊ะ ่\nน้ำตาล:,2 ช้อนโต๊ะ\nแป้งทอดกรอบ:, 200 กรัม\nน้ำสะอาด:, 150 มิลลิลิตร\nเกลือ:,1 ช้อนชา\nรากผักชี:,3ราก สำหรับทำไก่ต้ม \nกระเทียม:,7 กลีบ"'
},
{
    'ชื่ออาหาร': 'ข้าวหมูแดง ไมโครเวฟ',
    'ingredient_full_json': '"สันในหมู:,400 กรัม\nน้ำมันงา:,1 ช้อนโต๊ะ\nซอสหอยนางรม:,1 ช้อนโต๊ะ\nซีอิ๊วขาว:,1 ช้อนโต๊ะ\nผงหมักหมูแดง:,4 ช้อนโต๊ะ\nน้ำผึ้ง:,1 ช้อนโต๊ะ\nเหล้าจีน:,1 ช้อนโต๊ะ\nน้ำเปล่า:,1 ถ้วยตวง\nรากผักชี กระเทียม พริกไทย โขลก:,2 ช้อนโต๊ะ\nแป้งข้าวโพด:,1 ช้อนโต๊ะ\"'
},
{
    'ชื่ออาหาร': 'ไข่ตุ๋นแกงเขียวหวาน',
    'ingredient_full_json': '"ไข่ไก่:, 5 ฟอง\nน้ำเชื่อม:,1 ช้อนโต๊ะ\nน้ำปลา:,1 ช้อนโต๊ะ\nนมสดจืด:,¼ ถ้วยตวง\nปูอัด:,50 กรัม\nไส้กรอกไก่:,50 กรัม"'
},
{
    'ชื่ออาหาร': 'แกงเขียวหวานไก่ ไมโครเวฟ',
    'ingredient_full_json': '"กะทิ:,1 กล่อง\nน้ำพริกแกงเขียวหวาน:,2 ช้อนโต๊ะ\nน้ำ:,1/2 ถ้วย\nน้ำปลา:,1 ช้อนโต๊ะ\nน้ำตาลปี๊บ:,1 ช้อนโต๊ะ\nเนื้อไก่:,200 กรัม\nมะเขือเปราะ:,4 ลูก\nใบมะกรูด:,3 ใบ\nใบโหระพา:,1 ถ้วย\nพริกชี้ฟ้า:,1 เม็ด"'
},
{
    'ชื่ออาหาร': 'ต้มยำกุ้งน้ำข้นยอดมะพร้าว',
    'ingredient_full_json': '"กุ้งสด:,400 กรัม\nเห็ด:,100 กรัม\nมะเขือเทศ:,4 ลูก\nพริกขี้หนู:,10 เม็ด\nใบมะกรูด:,3-4 ใบ\nตะไคร้:,1 ก้าน\nยอดมะพร้าว:,120 กรัม\nข่า:,4 ชิ้น\nมะนาว:,2 ลูก\nน้ำพริกเผา:,4 ช้อนโต๊ะ\nนมข้นจืด:,100 กรัม\nน้ำปลา:,2 ช้อนโต๊ะ\nน้ำเปล่า:,1 ลิตร"'
},
{
    'ชื่ออาหาร': 'ผัดเปรี้ยวหวานหมู',
    'ingredient_full_json': '"เนื้อหมู:,250 กรัม\nหอมหัวใหญ่:,1 หัว\nแตงกวา:,5 ลูก\nมะเขือเทศ:,1 ลูก\nกระเทียม:,1 ช้อนโต๊ะ\nต้นหอม:,2 ต้น\nซอสมะเขือเทศ:,3 ช้อนโต๊ะ"'
},
{
    'ชื่ออาหาร': 'ผัดพริกแกงหมูสับถั่วฝักยาว',
    'ingredient_full_json': '"หมูสับ:,100 กรัม\nน้ำพริกแกงเผ็ด:,2 ช้อนโต๊ะ\nถั่วฝักยาว:,1 ถ้วย\nน้ำมันสำหรับผัด:,2 ช้อนโต๊ะ\nน้ำตาลทราย:,1 ช้อนโต๊ะ\nน้ำปลา:,1 ช้อนโต๊ะ\"'
},
{
    'ชื่ออาหาร': 'ผัดเผ็ดไก่หน่อไม้ดอง',
    'ingredient_full_json': '"เนื้ออกไก่:,1 อกใหญ่\nหน่อไม้ดอง:,1/2 กก.\nพริกชี้ฟ้า:,30 เม็ด หรือตามชอบ\nกระเทียม:,20 กลีบ\nใบโหระพา:,2 ต้น\nน้ำปลา:,2 ช้อนโต๊ะ\nน้ำตาล:,1 ช้อนโต๊ะ\nน้ำมันหอย:,2 ช้อนโต๊ะ\nน้ำเปล่า:,3-4 ช้อนโต๊ะ\"'
},
{
    'ชื่ออาหาร': 'แกงส้มผักรวมกุ้งสด',
    'ingredient_full_json': '"พริกแกงส้ม:,1 ช้อนโต๊ะ\nน้ำเปล่า:,3-4 ถ้วยตวง\nกุ้งสด:,5 ตัว\nน้ำมะขามเปียก:,1 ช้อนโต๊ะ\nน้ำตาลปี๊บ:,1 ช้อนโต๊ะ\nน้ำปลา:,1 ช้อนโต๊ะ\nแครอท:,¼ ถ้วยตวง\"'
},
{
    'ชื่ออาหาร': 'ไข่เจียวหมูสับผัดกะเพรา',
    'ingredient_full_json': '"ไข่ไก่:, 4 ฟอง \nหมูสับ:,100 กรัม \nใบกะเพรา:,50 กรัม \nพริกสับ:,2 ช้อนโต๊ะ \nกระเทียมสับ:,2 ช้อนโต๊ะ \nซอสหอยนางรม:,1 ช้อนโต๊ะ \nน้ำปลา:,1 ช้อนโต๊ะ \nน้ำตาล:,1 ช้อนชา\"'
},
{
    'ชื่ออาหาร': 'แกงเลียงกุ้งสด',
    'ingredient_full_json': "\"กุ้งสดปอกเปลือกผ่าหลัง: 250กรัม\nข้าวโพดอ่อนหั่น: 80กรัม\nฟักทองหั่นชิ้นพอดีคำ: 240กรัม\nบวบหั่นเป็นชิ้นๆ: 230กรัม\nเห็ดรวม (ตามชอบ): 250กรัม\nใบแมงลัก: 1ถ้วย\nน้ำซุป: 4ถ้วย\nน้ำปลา: 2ช้อนโต๊ะ\nซีอิ๊วขาว: 1ช้อนโต๊ะ\nน้ำตาล: 1ช้อนชา\n---พริกแกงเลียง--: \nหอมแดง: 6หัว\nกุ้งแห้งป่น: 3ช้อนโต๊ะ\nกุ้งสดลวก: 3ตัว\nกระชาย: 3แง่ง\nพริกไทยเม็ด: 1ช้อนโต๊ะ\nกะปิ: 1 1/2ช้อนโต๊ะ\nพริกขี้หนูสวน: 8เม็ด\nรากผักชี: 1ราก\""
},
{
    'ชื่ออาหาร': 'มาม่าผัดขี้เมาทะเล',
    'ingredient_full_json': "\"กุ้ง เนื้อปลา ปลาหมึก: ไม่ต้องเยอะมากอะ กะเอาเอง\nมาม่าบิ๊กแพ๊ครสต้มยำ: 1 ซอง\nใบโหระพา: \nเม็ดพริกไทย: \nไข่ไก่: \nพริกขี้หนูสด: \nกระเทียม: \nซีอิ๊วดำ:\""
},
{
    'ชื่ออาหาร': 'ผัดพริกแกงหมูสับถั่วฝักยาว',
    'ingredient_full_json': "\"หมูสับ: 100 กรัม\nน้ำพริกแกงเผ็ด: 2 ช้อนโต๊ะ\nถั่วฝักยาว ล้างให้สะอาดแล้วหั่นท่อนสั้นๆ: 1 ถ้วย\nน้ำมันสำหรับผัด: 2 ช้อนโต๊ะ\nน้ำตาลทราย: 1 ช้อนโต๊ะ\nน้ำปลา: 1 ช้อนโต๊ะ\""
},
{
    'ชื่ออาหาร': 'ผัดเผ็ดไก่หน่อไม้ดอง',
    'ingredient_full_json': "\"เนื้ออกไก่ (เลาะหนังออก): 1 อกใหญ่\nหน่อไม้ดอง: 1/2 กก.\nพริกชี้ฟ้าแดงและเขียว: 30 เม็ด หรือตามชอบ\nกระเทียม: 20 กลีบ\nใบโหระพาเด็ด: 2 ต้น\nน้ำปลา: 2 ช้อนโต๊ะ\nน้ำตาล: 1 ช้อนโต๊ะ\nน้ำมันหอย: 2 ช้อนโต๊ะ\nน้ำเปล่า (ไว้สำหรับล้างพริกแกงก้นครก): 3-4 ช้อนโต๊ะ\""
},
{
    'ชื่ออาหาร': 'แกงเขียวหวานหมู (มือใหม่หัดแกง)',
    'ingredient_full_json': "\"เนื้อหมู: 1 Kg\nพริกแกงเขียวหวาน: 2 ขีด\nหัวกะทิ: 500 ml\nใบโหระพา: \nมะเขือเปราะ: \nมะเขือพวง: \nพริกชี้ฟ้า: \nใบมะกรูด: \nน้ำตาลมะพร้าว: \nน้ำปลา: \nน้ำมันพืช:\""
},
{
    'ชื่ออาหาร': 'แกงส้มปลากระพงผักรวม (แกงส้มปักษ์ใต้)',
    'ingredient_full_json': "\"ปลากระพง(ประมาณ1กิโล): 1ตัว\nพริกแกงเหลือง: 3-4ช้อนโต๊ะ\nผักตามชอบ(มะละกอ แครอท ถั่วฟักยาว: ตามชอบ\nส้มแขก: 4-5ชิ้น\nน้ำปลา: 3-4ช้อนโต๊ะ\nน้ำตาล: 2-3ช้อนโต๊ะ\""
},
{
    'ชื่ออาหาร': 'ต้มยำกุ้งน้ำใส',
    'ingredient_full_json': "\"กุ้งไซส์กลาง-ใหญ่ 6 ตัว: \nเห็ดฟาง 200 กรัม: \nข่าหั่นเป็นชิ้นบางๆ 15 ชิ้น: \nตะไคร้ 3 ต้น: \nใบมะกรูด 5 ใบ: \nหอมแดง 5 หัว: \nพริกขี้หนูสวน 10 เม็ด: \nคนอร์ขวดซอสข้นปรุงรส 2 ช้อนโต๊ะ: \nมะนาว 6 ช้อนโต๊ะ: \nน้ำปลา 2 ช้อนโต๊ะ:\""
},
{
    'ชื่ออาหาร': 'แกงส้มใต้',
    'ingredient_full_json': "\"มะละกอ: 1 ลูก\nปลาทับทิม: 1 ตัว\nน้ำพริกแกงส้มใต้: 1 ซอง\nน้ำมะขามเปียก: 5 ช้อนโต๊ะ\nน้ำปลา: 3 ช้อนโต๊ะ\nเกลือ: 1 ช้อนชา\nน้ำตาลปีบ: 1 ช้อนโต๊ะ\""
},
{
    'ชื่ออาหาร': 'ปลาเผาผักสด/เมี่ยงปลาเผา/ปลานิลเผาเกลือ แบบใช้เตาอบ',
    'ingredient_full_json': "\"ปลา: 1 ตัว\nเกลือป่น: 250 กรัม\nแป้งสาลีเอนกประสงค์หรือแป้งมัน: 1 ช้อนโต๊ะ\nตะไคร้: 2ต้น\nใบเตย: 2 ใบ\nผักแกล้มผักต่างๆตามชอบ: \nซีฟู้ดกุ้ง,ปลาหมึก ตามชอบ: \nเส้นหมี่ ตามชอบ:\""
},
{
    'ชื่ออาหาร': 'น้ำพริกกะปิสูตรคุณยาย',
    'ingredient_full_json': "\"กะปิ: 1 ทัพพี\nน้ำตาลปี๊บ: 1 ทัพพี\nพริกสด: 1 กำมือ\nกระเทียม: 1 กำมือ\nมะเขือพวง: 1/2 ถ้วย\nน้ำมะนาวคั้นสด: 1 ทัพพี\nน้ำเปล่า: 1 ทัพพี\""
},
{
    'ชื่ออาหาร': 'แกงเขียวหวานไก่',
    'ingredient_full_json': "\"น้ำพริกแกงเขียวหวาน(สำเร็จรูป): \nกะทิ (กล่องใหญ่1 กล่อง+กล่องเล็กสุด 1 กล่อง): \nไก่สด+เครื่องใน: \nเลือดไก่(ก้อน): \nมะเขือเปราะ: \nมะเขือพวง: \nใบโหระพา: \nพริกชีฟ้าสีแดง: \nพริกขี้หนูสด: \nน้ำตาล:\""
},
{
    'ชื่ออาหาร': 'แกงส้มมะละกอปลากระป๋อง',
    'ingredient_full_json': "\"มะละกอออกสีแต้มๆ ลูกกลางๆ: 1ลูก\nปลากระป๋อง: 1กระป๋อง\nน้ำตาลปี๊บ: 2ทัพพี\nน้ำส้มมะขาม ตามความชอบ: 1ทัพพี\nน้ำปลา แล้วแต่ชอบ: \nน้ำเปล่า: 2ถ้วยตวง\nพริกแกงส้ม: 1ทัพพี\nผักชี:\""
},
{
    'ชื่ออาหาร': 'พริกแกงเหลือง (แกงส้มใต้)',
    'ingredient_full_json': "\"พริกจินดาแห้ง(ใช้พริกขี้หนูสดได้): 30 เม็ด\nกระเทียมไทย: 30 กลีบ\nขมิ้นยาว 2 นิ้ว: 1 ชิ้น\nกะปิ: 1 ช้อนโต๊ะ\nเกลือ: 1 ช้อนชา\""
},
{
    'ชื่ออาหาร': 'ยำปลากระป๋องทรงเครื่อง',
    'ingredient_full_json': "\"ปลากระป๋อง: 1 กระป๋อง\nตะไคร้: 2 ต้น\nหอมแดงซอย: 5 หัว\nผักชีฝรั่ง: 1 ต้น\nใบโพระพา: 5-6 ใบ\nใบมะกรูดซอย: 2 ใบ\nพริกขี้หนูซอย: 5 เม็ด\nมะนาว: 1-2 ซีก\""
},
{
    'ชื่ออาหาร': 'น้ำพริกกะปิสูตรอร่อยเด็ด',
    'ingredient_full_json': "\"กระเทียม: 1 ช้อนโต๊ะ\nกะปิ: 1 ช้อนโต๊ะ\nน้ำตาลปี๊บ: 1/2 ช้อนโต๊ะ\nพริกขี้หนูสวน: 20 เม็ด\nมะเขือพวง: 1 ช้อนโต๊ะ\nน้ำมะนาวคั้นสด: 4 1/2 ช้อนโต๊ะ\""
},
{
    'ชื่ออาหาร': 'ผัดซีอิ๊ว + สอนเทคนิคผัดเส้นระดับโปร ♥️',
    'ingredient_full_json': "\"เส้นใหญ่: 200 g\nหมูหมัก หรือ เนื้อมัก ดูสูตรได้ที่หมูหมักแบบภัตราคารจีน: 200 g\nคะน้า: 200 g\nไข่ไก่: 2 ฟอง\nซีอิ๊วขาว น้ำมันหอย ซีอิ๊วดำ: 3-4-5 เหยาะ\""
},
{
    'ชื่ออาหาร': 'แกงเขียวหวานเนื้อพริกขี้หนู',
    'ingredient_full_json': "\"เนื้อวัว(ล้ำ): 500 กรัม\nพริกแกงเขียวหวาน: 100 กรัม\nกะทิ: 1/2 กก.\nน้ำปลา: 4 ช้อนโต๊ะ\nน้ำตาลตะโหนด: 1 ช้อนโต๊ะ\nมะเขือเปราะ: 6 ลูก\nมะเขือพวง: \nใบโหระพา: \nพริกขี้หนู: \nใบมะกรูดฉีก:\""
},
{
    'ชื่ออาหาร': 'แกงส้มชะอมกุ้งพริกแกงใต้',
    'ingredient_full_json': "\"กุ้ง: 5 ขีด\nชะอม: 1 กำ\nพริกแกงส้มใต้: 2-3 ช้อน\nไข่ไก่: 4 ฟอง\nน้ำตาลปีบ: 1-2 ช้อน\nน้ำปลา: ตามรสชาติที่ชอบ\nน้ำมัน: 1 ถ้วย\nน้ำมะขามเปียก: ตามรสชาติที่ชอบ\""
},
{
    'ชื่ออาหาร': 'ยำปลากระป๋องแบบบ้าน',
    'ingredient_full_json': "\"ปลากระป๋อง: 3 กระป๋อง\nหอมแดงซอย: 2 ช้อนโต๊ะ\nพริกขี้หนู: 2 กรัม\nมะนาว: 2 ลูก\""
},
{
    'ชื่ออาหาร': 'แกงมัสมั่นเนื้อ',
    'ingredient_full_json': "\"เนื้อวัว(น่องลาย): 300 g.\nพริกแกงมัสมั่น: 100 g.\nกะทิเรียลไทย: 500 ml.\nอบเชย: 3 แท่ง\nดอกจันทร์: 3 ดอก\nลูกกระวาน: 6 ลูก\nถั่วลิสงคั่ว: 50 g.\nน้ำตาลมะพร้าว: 3 ช้อนโต๊ะ\nน้ำมะขามเปียก: 2 ช้อนโต๊ะ\nน้ำปลาดี: 2 ช้อนโต๊ะ\nเกลือ: หยิบมือ\nน้ำส้มซ่า: 1 ช้อนโต๊ะ\nมันฝรั่ง: 2 หัว\nหอมหัวใหญ่: 1 หัว\nซุบเนื้อก้อนคนอร์: 1 ก้อน\""
},
{
    'ชื่ออาหาร': 'น้ำพริกกะปิ ปลาทูทอด',
    'ingredient_full_json': "\"น้ำพริกกะปิ: \nกระเทียม: 4 กลีบใหญ่\nพริก: 6 เม็ด\nน้ำตาลแว่น/น้ำตาลมะพร้าว: 1.5 แว่น\nกะปิอย่างดี: 1 ช้อนพูนๆ\nมะนาว: 1.5 ลูกเล็ก\nผักต้ม: \nถั่วฝักยาว: 5 ต้น\nผักบุ้ง: 4 ต้น\nน้ำเปล่า: สำหรับลวก\nน้ำเย็นจัด: สำหรับแช่ผัก\nปลาทูทอด: \nปลาทูขนาดกลาง: 2 ตัว\nน้ำมันปาล์ม: 1 ถ้วย\""
},
{
    'ชื่ออาหาร': 'แกงมัสมั่นหมู',
    'ingredient_full_json': "\"เนื้อหมู: 500 กรัม\nพริกแกงมัสมั่น: 100 กรัม\nหอมใหญ่: 2ลูก\nมันฝรั่ง: 3 หัว\nถั่วลิสงคั่ว: 150 กรัม\nน้ำตาลปีบ: 3ช้อน\nน้ำมะขามเปียก: 2ช้อน\nเกลือ: 1ช้อนครึ่ง\nใบกระวาน: 2ใบ\nกะทิ วันนี้ใช้แบบ UHT: 1กล่อง\""
},
{
    'ชื่ออาหาร': 'แกงเขียวหวานไก่ใส่ฟัก',
    'ingredient_full_json': "\"สะโพกไก่: 2 ชิ้น\nฟักแก่: 3 ขีด\nตีนไก่: 2 ขีด\nพริกแกงเขียวหวาน: 1.5 ขีด\nกระทิสด: 1 โล\nมะเขือ: 3-4 ลูก\nใบโหระพา: 1 กำเล็ก\nพริกชี้ฟ้า: 4-5 เม็ด\nน้ำปลา: 2 ช้อน\nน้ำตาลปีบ: 1/2 ช้อน\nมะเขือพวง: 1 ขีด\""
},
{
    'ชื่ออาหาร': 'ไข่เจียวหมูสับหน้ากรอบ',
    'ingredient_full_json': "\"เนื้อหมูสับ: 2-3ขีด\nไข่ไก่: 5 ฟอง\nน้ำปลา: ตามชอบ\nซอสหอยนางรม: ตามชอบ\nน้ำตาล: ตามชอบ\""
},
{
    'ชื่ออาหาร': 'ผัดพริกแกงหมูใส่มะเขือเปราะ',
    'ingredient_full_json': "\"น้ำมัน: 4ช้อนโต๊ะ\nกระเทียม: 2ช้อนโต๊ะ\nเนื้อหมู: 4ขีด\nพริกชี้ฟ้าหรือพริกขี้หนู: \nพริกแกง: 2ช้อนโต๊ะ\nมะเขือเปราะ: \nใบมะกรูด: \nมะเขือพวง: \nน้ำปลา: \nน้ำเปล่า: \nน้ำตาล: 2ช้อนชา\nน้ำมันหอย: 2ช้อนโต๊ะ\""
},
{
    'ชื่ออาหาร': 'เทคนิค กะเพราหมูสับ แบบแห้ง อร่อยกว่าร้าน',
    'ingredient_full_json': "\"หมูสับ: 1 ถ้วย\nพริกเขียว + กระเทียม สับ: 1 ถ้วย\nใบกะเพรา: 2-3 ต้น\nซีอิ๊วขาว: 2-3 ช้อนชา\nน้ำปลา: 1 ช้อนชา\nพริกไทย: 2-3 เหยาะ\""
},
{
    'ชื่ออาหาร': 'แกงเขียวหวานไก่ผัดแห้ง',
    'ingredient_full_json': "\"เนื้อไก่หั่นเป็นชิ้น: 140 กรัม\nมะเขือเปราะหั่น: 200 กรัม\nมะเขือพวง: 2 ช้อนโต๊ะ\nพริกแดงหั่นแฉลบ: 4 เม็ด\nใบโหระพา: 1 ถ้วย\nพริกแกงเขียวหวาน: 2 ช้อนโต๊ะ\nน้ำตาลปี๊บ: 1 /2ช้อนโต๊ะ\nใบมะกรูดฉีก: 4-5ใบ\nนมข้นจืด.: 6 ช้อนโต๊ะ\nน้ำมันพืช.: เล็กน้อย\nน้ำเปล่า: เล็กน้อย\""
},
{
    'ชื่ออาหาร': '“ปูหลน”',
    'ingredient_full_json': "\"กะทิ: 2 กล่อง\nหมูสับ: 400 กรัม\nน้ำสะอาด: 3 กล่อง\nหอมแดงซอย: 1 ถ้วย\nปูเค็ม: 10 ตัว\nน้ำตาลปี๊บ: 5 ช้อนโต๊ะ\nผงปรุงรส: 3 ช้อนชา\nเกลือป่น: 1 ช้อนชา\nน้ำปลา: 5 ช้อนโต๊ะ\nน้ำมะขามเปียก: 20 ช้อนโต๊ะ\nตะไคร้ซอย: 5 ต้น\nใบมะกรูดแบบฉีก: 10 ใบ\nพริกใหญ่: 20 เม็ด\nใบมะกรูดแบบซอย: 10 ใบ\""
},
{
    'ชื่ออาหาร': 'ขนมจีนแกงเขียวหวานไก่ 💚',
    'ingredient_full_json': "\"อกไก่: \nเลือดไก่: \nกะทิ: \nพริกแกงเขียวหวาน: \nมะเขือเปราะ: \nมะเขือพวง: \nใบโหระพา: \nน้ำปลา: \nรสดี: \nใบมะกรูด:\""
},
{
    'ชื่ออาหาร': '🌱 ยำสามกรอบ 🌶',
    'ingredient_full_json': "\"หมูแผ่นอบกรอบ: \nหนังไก่กรอบ: \nเมล็ดมะม่วงหิมพานต์: \nหัวหอมใหญ่: \nขึ้นฉ่าย: \nพริกขี้หนู: \nน้ำปลา: \nมะนาว: \nน้ำเชื่อม: \nน้ำเปล่า:\""
},
{
    'ชื่ออาหาร': 'ขนมจีนน้ำยาปลาทู',
    'ingredient_full_json': "\"ปลาทูนึงแกะเอาแต่เนื้อ: 2 ตัว\nน้ำพริกแกงเผ็ดใต้: 100 กรัม\nกะทิ: 250 กรัม\nลูกชิ้นปลา: 6-7 ลูก\nกระชาย ล้างให้สะอาด ตำให้ละเอียด: 100 กรัม\nขนมจีน: \nผักเครื่องเคียงตามชอบ: \nน้ำตาลมะพร้าว: 2 ช้อนโต๊ะ\nน้ำปลา: 2 ช้อนโต๊ะ\""
},
{
    'ชื่ออาหาร': 'แกงส้มปลาหน่อไม้ดอง',
    'ingredient_full_json': "\"ปลาทับทิม: 1 ตัว\nเครื่องแกงส้ม: 1 ขีด\nหน่อไม้ดอง: 1/2 กก.\nกะปิ: 1 ช้อนพูน\nน้ำตาลมะพร้าว: 1 ช้อนโต๊ะ\nเกลือ: 1 ช้อนชา\nน้ำปลา: 1 ช้อนโต๊ะ\nน้ำมะขามเปียก: 1 ถ้วย\nมะนาว: 1.5 ลูก\""
},
{
    'ชื่ออาหาร': 'พริกแกงมัสมั่น​',
    'ingredient_full_json': "\"เม็ดผักชีคั่วป่น: 1+1/2 ช้อนชา\nเม็ดยี่หร่าคั่วป่น: 1/2 ช้อนชา\nเม็ดกระวานคั่วป่น​ (แกะเอาเฉพาะเม็ดที่อยู่ด้านใน)​: 4 เม็ด\nกานพลูคั่วป่น: 4 ดอก\nลูกจันทน์​คั่วป่น: 1 ลูก\nดอกจันทน์​คั่วป่น: 1 ดอก\nอบเชยท่อน​ 1 นิ้ว​ คั่วป่น: 1 ท่อน\nพริกชี้ฟ้าแช่น้ำซับแห้ง: 10 เม็ด\nเกลือสมุทร​: 1 ช้อนชา\nข่าแก่หั่นละเอียด: 1 ช้อนโต๊ะ​\nตะไคร้หั่นละเอียด: 2 ต้น\nผิวมะกรูด: 1 ช้อนชา\nกระเทียม​ไทย: 20​ กลีบ\nหอมแดง: 5 หัว\nกะปิห่อใบตองย่างจนหอม: 1 ช้อนชา\nพริกไทยขาวเม็ดคั่วป่น: 1/2 ช้อนชา\""
},
{
    'ชื่ออาหาร': 'ขนมครกสิงคโปร์',
    'ingredient_full_json': "\"แป้งสาลี: 2ถ้วย\nแป้งมัน: 1ถ้วย\nนมสดรสจืด: 1ถ้วย\nใบเตย12ใบแก่ๆ คั้นน้ำกรองกาก: 1ถ้วย\nผงฟู: 2ช้อนกาแฟพูนๆ\nเกลือ: 1ช้อนกาแฟพูนๆ\nน้ำตาลทราย: 1ถ้วย\nน้ำมันพืช: 1ช้อนกาแฟ\nไข่ไก่: 2ฟอง\""
},
{
    'ชื่ออาหาร': 'ไก่ผัดเม็ดมะม่วงหิมพานต์ (น้ำพริกเผา) Gai Pad Med Mamuang',
    'ingredient_full_json': "\"เนื้อไก่หั่นชิ้นพอดีคำ: 400 กรัม\nแป้งทอดกรอบ: 1/2 ถต.\nเม็ดมะม่วงหิมพานต์ทอด: 100 กรัม\nพริกทอดกรอบ หั่นท่อน: 10 เม็ด\nหอมหัวใหญ่: 1 หัว\nพริกหวานสามสี (3 สี แดง เหลือง เขียว ใช้สีละอย่างละ: 1/2 ลูก\nพุทราเชื่อม/พุทราอบแห้ง (ใข้พุทราเชื่อมอร่อยกว่า) ส่วนนี้ไม่ใส่ก็ได้: 50 กรัม\nต้นหอมหั่นท่อน (มากน้อยตามชอบ): 5 ต้น\nกระเทียมสับละเอียด: 1 ช้อนโต๊ะ\nซอสหอยนางรม: 2 ช้อนโต๊ะ\nซีอิ้วขาว/ซอสปรุงรส: 1 ช้อนโต๊ะ\nน้ำตาลทราย(ความหวานปรับเพิ่มลดได้ตามความชอบ): 1 1/2 ช้อนโต๊ะ\nน้ำพริกเผา (ถ้าทำให้เด็กทานด้วยสามารถลดในส่วนนี้ลงได้): 2 ช้อนโต๊ะ\""
},
{
    'ชื่ออาหาร': 'แกงส้มผักบุ้งกุ้งลอยน้ำ',
    'ingredient_full_json': "\"กุ้งสดตัวใหญ่: 3 ขีด\nพริกแกงส้ม: 1 ช้อนโต๊ะ\nผักบุ้ง: 2 กำ\nน้ำปลา: 1 ช้อนชา\nหัวหอม: 2 หัว\nกระชาย: 1 ต้น\nกะปิ: ครึ่งช้อนชา\nน้ำตาลทราย: 1 ช้อนชา\nมะขามเปียก: 4 ฝัก\nใบมะกรูด: 4 - 5 ใบ\""
},
{
    'ชื่ออาหาร': 'ข้าวผัดซีอิ๊วดำ',
    'ingredient_full_json': "\"ข้าวสวย: 3 ถ้วย\nเนื้อหมู: 50กรัม\nไข่ไก่: 2ฟอง\nคะน้า: 30กรัม\nมะเขือเทศ: 1ลูก\nหอมหัวใหญ่: 1/2หัว\nกระเทียมสับ: 4กลีบ\nซีอิ๊วดำ: 1ช้อนโต๊ะ\nซีอิ๊วขาว: 1/2ช้อนโต๊ะ\nน้ำปลา: 1ชต\nน้ำตาลทราย: 1ช้อนชา\nน้ำมันพืช:\""
},
{
    'ชื่ออาหาร': 'ขนมจีนน้ำยากะทิไก่',
    'ingredient_full_json': "\"กะทิ: 1 Kg\nเนื้อไก่ส่วนหน้าอกต้ม: 500 กรัม\nพริกแห้ง: 15-20 เม็ด\nกระชายหั่น: 7 หัว\nตะไคร้ซอย: 3 ต้น\nหัวหอมแดงหั่น: 7 หัว\nข่าหั่น: 1 หัว\nกระเทียมซอย: 3 หัว\nน้ำซุปที่เหลือจากต้มไก่: 2 ถ้วยตวง\nเกลือป่น: 1 ช้อนโต๊ะ\nน้ำปลา: 4 ช้อนโต๊ะ\nน้ำตาลทราย: 2 ช้อนโต๊ะ\nใบมะกรูด: 10 ใบ\nลูกชิ้นปลา: 300 กรัม\nขนมจีน: 1 Kg\""
},
{
    'ชื่ออาหาร': 'ผัดกะเพราเนื้อสับ',
    'ingredient_full_json': "\"เนื้อบด: 2 ขีด\nใบกะเพรา: 10 ใบ\nกระเทียม: 5 กลีบ\nพริกขี้หนูสวน: ตามใจชอบ\nน้ำปลา: 1 ช้อนโต๊ะ\nซอสปรุงรส: 1 ช้อนโต๊ะ\nซอสหอยนางรม: 1 1/2 ช้อนโต๊ะ\nน้ำตาล: 1 ช้อนชา\nน้ำต้มสุก: 2-3 ช้อนโต๊ะ\""
},
{
    'ชื่ออาหาร': 'แกงเขียวหวานตีนไก่',
    'ingredient_full_json': "\"ตีนไก่: 1 กิโล\nเนื้อไก่ส่วนสะโพก: 200 กรัม\nกระทิคั้น(ซื้อที่ตลาด): 1 กิโล\nพริกแกงเขียวหวาน: 300 กรัม\nหน่อไม้ หรือ ยอดมะพร้าว: 200 กรัม\nพริกชี้ฟ้าแดง: 5-6 เม็ด\nใบมะกรูด: 5 ใบ\nใบโหระพา: 2-3 กำมือ\""
},
{
    'ชื่ออาหาร': 'ต้มยำปลาทู',
    'ingredient_full_json': "\"ปลาทูแม่กลอง (ตัวเล็ก): 10 ตัว\nเครื่องต้มยำ / ข่า / ตะไคร้ /ใบมะกรูด: มีขายเป็นชุดๆ ใช้ 1 ชุด\nมะนาว: 2 ลูก\nมะเขือเทศ: 1 ลูก\nพริกชี้ฟ้า: 3-4 เม็ด\nเกลือ: 1 ช้อนชา\nผงปรุงรส: ตามใจชอบ\nน้ำปลา: 2 ช้อนโต๊ะ\""
},
{
    'ชื่ออาหาร': 'ฉู่ฉี่กุ้งปลาหมึก 🦐🦑',
    'ingredient_full_json': "\"กุ้ง: 200 กรัม\nปลาหมึก: 200 กรัม\nกะทิ: 150 กรัม\nพริกแกงเผ็ด: 1 ช้อนโต๊ะ\nมันกุ้ง: 1 ช้อนโต๊ะ\nน้ำตาลปี๊บ: ปลายช้อน\nใบมะกรูด: 8 ใบ\nพริกแดง: 5 เม็ด\""
},
{
    'ชื่ออาหาร': 'มาม่าผัดกะเพราหมูสับ',
    'ingredient_full_json': "\"บะหมี่กึ่งสำเร็จรูป(มาม่า)ลวก: 70 กรัม\nหมูสับ: 40 กรัม\nใบกะเพรา: 1 ถ้วย\nคนอร์ซอสข้นปรุงรส รสหมู: 1 ช้อนโต๊ะ\nน้ำตาลทราย: 1 ช้อนชา\nซีอิ๊วดำ: 1 ช้อนชา\nกระเทียม.: 4 กลีบ\nพริกแดงจินดา: 8 เม็ด\nน้ำมันพืช.: เล็กน้อย\nน้ำเปล่า: เล็กน้อย\""
},
{
    'ชื่ออาหาร': 'ฉู่ฉี่ปลาทูสด',
    'ingredient_full_json': "\"ปลาทูสด: 2 ตัวใหญ่\nพริกแกงฉูฉี่: 1+1/2 ช้อนโต๊ะ\nกะทิ: 1 ถ้วย(กล่องเล็ก)\nใบมะกรูดซอย: 3 ใบ\nพริกชี้ฟ้าหั่น: 2 เม็ด\nน้ำปลา: 1/2-1 ช้อนโต๊ะ\nน้ำตาลปี๊บ: 1/2-1 ช้อนโต๊ะ\nผงคนอร์อร่อยชัวร์: 1 ช้อนชา\""
},
{
    'ชื่ออาหาร': '“ฉู่ฉี่ปลาทูทอด"',
    'ingredient_full_json': "\"น้ำมัน: 2 ช้อนโต๊ะ\nพริกแกงเผ็ด: 2-3 ช้อนโต๊ะ\nกะทิ: 400 กรัม\nน้ำตาลทราย: 4-5 ช้อนชา\nเกลือ: 1 ช้อนชา\nน้ำปลา: 2-3 ช้อนโต๊ะ\nปลาทูสดทอด: 15 ตัว\nใบมะกรูดซอย: 7 ใบ\nพริกใหญ่: 2 เม็ด\""
},
{
    'ชื่ออาหาร': 'แกงเขียวหวาน​(หมู)​🐷',
    'ingredient_full_json': "\"หมู​หั่นชิ้น: 1กิโลกรัม​\nมะเขือเปาะ: 1/2กิโลกรัม​\nมะเขือ​พวง: 100​กรัม​\nกระชายหั่นซอย: 100กรัม\nใบมะกรูด​ฉีก: 20ใบ\nพริกชี้ฟ้า​แดง: 4เม็ด\nใบโหระพา​: 40ใบ\nพริกแกง​เขียวหวาน​: 5ช้อนโต๊ะ​\nพริกแกงเผ็ด​: 1ช้อนโต๊ะ​\nกะทิกล่องสำเร็จ​แบบหัวกะทิ: 1000มล.\nน้ำตาลปี้บ: 0.5ช้อนโต๊ะ​\nผงปรุงรส​: 1ช้อนโต๊ะ​\nเกลือ​: หยิบมือ\nน้ำเปล่า​: 250มล.\""
},
{
    'ชื่ออาหาร': 'มาม่าผัดต้มยำกุ้ง',
    'ingredient_full_json': "\"เส้นบะหมี่กึ่งสำเร็จรูป: 50กรัม\nเห็ดฟาง: 40กรัม\nกุ้งสดปอกเปลือกผ่าหลัง: 3ตัว\nพริกเผา: 1ช้อนโต๊ะ\nซอสหอยนางรม: 1ช้อนโต๊ะ\nน้ำปลา: 1ช้อนโต๊ะ\nน้ำตาลทราย: 1ช้อนชา\nตะไคร้ทุบหั่นท่อนเล็ก: 2ต้า\nหอมแดง: 3หัว\nข่าสับ: 1ช้อนโต๊ะ\nใบมะกรูดฉีก: 6ใบ\nพริกแดงจินดา: 8เม็ด\nกระเทียม: 5กลีบ\nคนอร์ อร่อยชัวร์ ผงรสไก่: 1ช้อนชา\nมะนาว: 1/2ลูก\nน้ำมันพืช:\""
},
{
    'ชื่ออาหาร': 'โรลข้าวน้ำพริกกะปิ',
    'ingredient_full_json': "\"น้ำพริกกะปิ: 1 ถ้วยตวง\nปลาทูย่างสุก: 2 ตัว\nแตงกวา: 2 ลูก\nแครอท: 1 ลูก\nชะอม (หั่นซอย): 1 ถ้วยตวง\nไข่ไก่: 1 ฟอง\nข้าวสวย: 1 ถ้วยตวง\""
},
{
    'ชื่ออาหาร': 'แกงส้มผักรวมเจ',
    'ingredient_full_json': "\"พริกแกงส้มเจ: 3 ช้อนโต๊ะ\nถั่วเน่า(ใช้แทนกะปิ): 1/2 แผ่น\nขาเห็ดนางฟ้าต้ม: 10 ขา\nน้ำตาลปี๊บ: 1 ช้อนชา\nน้ำมะขามเปียก: 3 ช้อนโต๊ะ\nเกลือ: 1 ช้อนชา\nผงปรุงรสเห็ดหอมเจ: 1 ช้อนชา\nถั่วฟักยาว: 5 ฟัก\nหัวไชเท้า: 1/2 หัว\nเห็ดนางฟ้าส่วนดอก: 10 ดอก\nกวางตุ้ง: 3 ต้น\nดอกแค: 1 ถ้วย\nน้ำเปล่า: 6 ถ้วย\""
},
{
    'ชื่ออาหาร': 'ผัดไทยกุ้งสด หัวกุ้งทอดกรอบ',
    'ingredient_full_json': "\"เส้นหมี่: 1 ห่อ 200 กรัม\nกุ้งสด: 8 ตัว\nกุยช่าย: ตามชอบ\nหอมแดง: 5 หัว\nพริกแห้ง: 5\nกระเทียม: 3 หัว\nน้ำมะขาม: 3 ช้อนโต๊ะ\nน้ำตาลทราย: 1 ช้อนโต๊ะ\nเต้าหู้ขาว: ตามชอบ\nถั่วงอก: ตามชอบ\nน้ำปลา:\""
},
{
    'ชื่ออาหาร': 'ข้าวมันไก่คลีน ❤️',
    'ingredient_full_json': "\"อกไก่: 6 ขีด\nข้าวกล้อง: 2ถ้วย\nข้าวขาว: 1 ถ้วย\nแครอท: 1หัว\nไช้เท้า: 1หัว\nหอมใหญ่: 1หัว\nขิงหั่นแว่น: ตามชอบ\nกระเทียมทุบ: ตามชอบ\nน้ำมันมะกอก:\""
},
{
    'ชื่ออาหาร': 'ขนมจีนน้ำยาไก่',
    'ingredient_full_json': "\"เนื้อไก่: ครึ่งโล\nกระทิ: ครึ่งโล\nข่า ตะไคร้ ใบมะกรูด: 1 กำ\nตีนไก่: ครึ่งโล\nลูกชิ้นปลาอย่างดี: 1 ถุงเล็ก\nพริกแกงเผ็ด: 2 ขีด\nเกลือ: 1 ช้อน\nกระชาย: 2 ขีด\nเส้นขนมจีนสด: 1 ห่อ\""
},
{
    'ชื่ออาหาร': 'ต้มยำกุ้งน้ำข้น',
    'ingredient_full_json': "\"กุ้ง: 10 ตัว\nตะไคร้: 2 ต้น\nใบมะกรูด: 1 กำ\nข่า: 1/2 หัว\nเห็ดฟาง: 1 ขีด\nคนอร์ต้มยำ: 1 ก้อน\nนมจืด: 1/2 กล่อง\nน้ำพริกเผา: 2 ช้อน\nน้ำพริกเผาเผ็ด: 1 ช้อน\nพริก: 1 กำ\nเกลือ: \nน้ำปลา: \nน้ำตาล: \nมะนาว: 2 ลูก\""
},
{
    'ชื่ออาหาร': 'แกงเลียงเห็ด 3 อย่าง',
    'ingredient_full_json': "\"เห็ดฟาง: 1 ขีด\nเห็ดเข็มทอง: 1 ขีด\nเห็ดออรินจิ: 2-3 ดอก\nฝักทอง: 100กรัม\nบวบ: 1 หัว\nตำลึง: 200 กรัม\nใบแมงลัก: 1 กำ\nพริกไทยขาว: 2 ชช\nหอมแดง: 5-8หัว\nกะปิน้ำพริก: 1 ชต\nข้าวโพดอ่อน: 100กรัม\nแครอท: 50กรัม\nน้ำสะอาด: 1 1/2 ถ้วย\nเกลือ: 1/3 ชช\nกุ้งแห้ง: 3 ชต\nพริกแดง: 2 เม็ด\""
},
{
    'ชื่ออาหาร': 'ข้าวผัดแกงเขียวหวาน',
    'ingredient_full_json': "\"เนื้อหมู: 100 กรัม\nข้าวสวย: 1 ถ้วย\nน้ำพริกแกงเขียวหวาน: 1/2 ช้อนโต๊ะ\nมะเขือเปราะหั่น 4 หรือ 6: 1 ลูก\nมะเขือพวงเด็ด: 10 เม็ด\nใบโหระพา(เด็ดเป็นใบ): 10-15 ใบ\nพริกชี้ฟ้าแดงหั่นเฉียง: 5 ชิ้น\nกะทิ: 2 ช้อนโต๊ะ\nน้ำตาลปี๊บ: 1 ช้อนชา\nน้ำปลา: 2 ช้อนชา\""
},
{
    'ชื่ออาหาร': 'ต้มยำปลากระป๋อง',
    'ingredient_full_json': "\"ปลากระป๋อง: 3 กระป๋อง\nตะไคร้: 6 ท่อน\nข่า: 2 กิ่ง\nใบมะกรูด: 2 กิ่ง\nเห็ดนางฟ้า: 200 กรัม\nหอมแดง: 10 หัว\nผักชีฝรั่ง: 5 ต้น\nผงปรุงรส: 2 ก้อน\nพริกป่น: 1 ช้อนโต๊ะ\nพริกจินดา: 10 เม็ด\nมะนาว: 4 ลูก\""
},
{
    'ชื่ออาหาร': 'ข้าวผัดน้ำพริกลงเรือสูตรโบราณแกล้มหมูกรอบทอดน้ำปลา',
    'ingredient_full_json': "\"หมูสามชั้น: 1 ชิ้น\nปลาดุกฟู: 1 ถ้วยตวง\nพริกขี้หนู: 15 เม็ด\nกะปิย่าง: 2 ช้อนโต๊ะ\nน้ำตาลปีบ: 2 ช้อนชา\nกระเทียมกลีบเล็ก: 3 กลีบ\nถั่วฝักยาว: 1/3 ถ้วยตวง\nไข่เค็ม: 1 ฟอง\nแครอทต้มสุก: 1/3 ถ้วยตวง\nน้ำปลา: 3 ช้อนโต๊ะ\nซอสหอยนางรม: 1 ช้อนโต๊ะ\nซอสปรุงรส: 2 ช้อนโต๊ะ\nน้ำตาลทราย: 2 ช้อนโต๊ะ\""
},
{
    'ชื่ออาหาร': '✿ แกงมัสมั่นไก่ ✿',
    'ingredient_full_json': "\"น้ำพริกแกงมัสมั่น: 100 กรัม\nสะโพกไก่: 3 ชิ้น\nกะทิ: 500 ml\nมันฝรั่ง: 1\nหัวหอมใหญ่: 1 ลูก\nขิง: 2 แว่น(ซอย)\nคนอร์รสไก่: 1 ก้อน\nน้ำเปล่า: 200 ml\nอบเชย โป๊ยกั้ก ลูกกระวาน (ที่ซื้อมาไม่มีลูกกระวาน): 1 ห่อเล็ก\nน้ำมะขามเปียก: \nน้ำตาลปี๊บ: \nเกลือ:\""
},
{
    'ชื่ออาหาร': 'ต้มยำกุ้งน้ำข้น',
    'ingredient_full_json': "\"กุ้งขาว: 200\nข่า: 5 แว่น\nตะไคร้: 3 ต้น\nใบมะกรูด: 4 ใบ\nหอมแดง: 5 หัว\nนมข้นจืด: 1/4-1/2 ถ้วย\nน้ำพริกเผา: 1 ช้อนโต๊ะ\nน้ำเปล่า: 3 ถ้วย\nเห็ดต่างๆ: ตามชอบ\nคนอร์ซุปต้มยำ(ก้อน): 2 ก้อน\nผักชีฝรั่ง: 2 ต้น\nต้นหอม: 2 ต้น\nพริกแห้งทอด: 4 เม็ด\nน้ำปลา: \nน้ำมะนาว:\""
},
{
    'ชื่ออาหาร': 'แกงส้มผักรวม',
    'ingredient_full_json': "\"ผักสด (ตามสะดวก): \nปลา(ตามสะดวก): \nพริกแห้ง: \nหอมแดง: \nกะปิ: \nน้ำตาลปี๊บ: \nน้ำปลา: \nเกลือ: \nน้ำมะขามเปียก:\""
},
{
    'ชื่ออาหาร': 'ข้าวมันไก่เด็กหอ',
    'ingredient_full_json': "\"น่องไก่ติดสะโพก: 2น่อง\nข้าว: 4กรัม\nกระเทียม: 1หัว\nขิง: 1แง่ง\nพริกสด: 1ขีด\nน้ำตาลทราย: 3ช้อน\nมะนาว: 3ลูก\nซอสปรุงรสสูตร1: 2ช้อน\nเต้าเจี้ยว: 4ช้อน\nซุปคนอร์: 2ก้อน\""
},
{
    'ชื่ออาหาร': 'แกงส้มปลาช่อนทอด',
    'ingredient_full_json': "\"ปลาช่อน: 1 ตัว\nแป้งทอดกรอบ: 5 ช้อนโต๊ะ\nน้ำมัน: 1/2 ถ้วย\nพริกแกงส้มสำเร็จ: 300 กรัม\nปลาทูน่า: 3 กระป๋องใหญ่\nหัวไชเท้า: 1 หัว\nถั่วฝักยาว: 500 กรัม\nผักกาดขาว: 1 หัว\nมะขามเปียก: 1 ปั้น\nน้ำตาลปี๊บ: 2 ช้อนโต๊ะ\nน้ำปลา (อาจไม่ใส่): 3 ช้อนโต๊ะ\""
},
{
    'ชื่ออาหาร': 'หมูสับผัดซีอิ๊วดำหวาน',
    'ingredient_full_json': "\"หมูสับ: 300 กรัม\nหมอแดง: 150 กรัม\nกระเทียม: 10 กลีบ\nพริกไทยป่น: 1 ช้อนชา\nซีอิ๊วดำ: 1 ช้อนโต๊ะ\nน้ำตาลอ้อย: 1/2 ก้อน\nน้ำมัน: 1 ช้อนชา\""
},
{
    'ชื่ออาหาร': 'แกงส้มปลาทูสด',
    'ingredient_full_json': "\"ปลาทูสด: 4ตัว\nพริกแกงส้ม: 2ช้อนโต๊ะ\nน้ำปลา: 1 1/2ช้อนโต๊ะ\nน้ำตาล: 1ช้อนโต๊ะ\nน้ำมะขามเปียก: 2ช้อนโต๊ะ\nผักบุ้ง: 1กำ\""
},
{
    'ชื่ออาหาร': 'เครื่องในไก่ทอดกระเทียม',
    'ingredient_full_json': "\"เครื่องในไก่: \nพริกไทยขาวป่น: \nผงปรุงรส: \nแป้งชุบทอด: \nกระเทียม: \nน้ำมันพืช:\""
},
{
    'ชื่ออาหาร': 'ต้มยำกุ้งน้ำใส',
    'ingredient_full_json': "\"กุ้ง 3 ตัว: 250 กรัม\nเห็ดนางรมหลวง: 60 กรัม\nตะไคร้: 2 ต้น\nใบมะกรูด: 6 ใบ\nพริกขี้หนูสวน สีแดง: 15 เม็ด\nน้ำมะนาว: 1.5 ช้อนโต๊ะ\nซีอิ๊วขาว: 1.5 ช้อนโต๊ะ\nน้ำสต๊อก: 350 กรัม\nข่าแก่: 6 แว่น\""
},
{
    'ชื่ออาหาร': 'ข้าวกะเพราเนื้อไข่ดาว เมนูนี้ไม่มีเบื่อ',
    'ingredient_full_json': "\"ไข่ไก่: 1 ฟอง\nเนื้อสับ หรือหั่นเป็นชิ้น/หรือจะใช้เนื้อสัตว์อย่างอื่นก็ได้ค่ะ: 250 กรัม\nซอสหอยนางรม: 1 ช้อนชา\nน้ำปลา หรือ ซอสปรุงรส: 1 ช้อนชา\nน้ำตาล: 1/2 ช้อนชา\nใบกระเพรา: 2 กำมือ\nกระเทียม: 3 กลีบ\nพริก: 3-4 เม็ด\""
},
{
    'ชื่ออาหาร': 'ผัดกะเพราโบราณ, ผัดกะเพราเนื้อสับ',
    'ingredient_full_json': "\"เนื้อสับ: 300 กรัม\nพริกขี้หนูเน้นสีแดง: 35 เม็ด\nกระเทียมจีน: 1 หัว\nใบกะเพรา: ตามชอบ\nซอสปรุงรส: 2 ช้อนโต๊ะ\nน้ำปลา: 1/2 ช้อนโต๊ะ\nน้ำตาลทราย: 1 ช้อนชา\nซอสหอยนางรม: 1 ช้อนโต๊ะ\nน้ำดื่ม: 1 ทัพพี\""
},
{
    'ชื่ออาหาร': 'แกงเทโพหมูสามชั้น',
    'ingredient_full_json': "\"หมู 3 ชั้น: 400 g.\nพริกแกงใต้(แกงเผ็ด): 100 g.\nน้ำตาลมะพร้าว: 20 กรัม\nใบมะกรูด: 3 ใบ\nมะขามเปียก: 1/2 ช้อนโต๊ะ\nน้ำปลาแท้: 2 ช้อนโต๊ะ\nผักบุ้งไทย: 8-10 ต้น\nน้ำมันพืช: 1 ช้อนชา\nกะทิ: 250 ml.\""
},
{
    'ชื่ออาหาร': 'แกงเลียงปลากรอบ',
    'ingredient_full_json': "\"ปลากรอบเอาไปปิ้งหรือเอาไปอบให้หอม แกะเอาแต่เนื้อ: 1 ตัว\nน้ำเต้าปอกเปลือก ล้างให้สะอาด หั่นเป็นชิ้นพอดีคำ: 1 ลูกเล็ก\nบวบ ฝานคมออกให้หมด ล้างน้ำให้สะอาด หั่นชิ้นพอดีคำ: 1/2 ลูก\nข้าวโพดอ่อน หั่นชิ้นพอดีคำ: 2-3 ฝัก\nใบแมงลักเด็ด ล้างน้ำให้สะอาด สะเด็ดน้ำ: 1/2 ถ้วย\nพริกไทยเม็ด: 1/2 ช้อนโต๊ะ\nหอมแดง: 4-5 หัว\nกุ้งแห้งแช่น้ำให้นิ่ม สะเด็ดน้ำ: 25 กรัม\nพริกขี้หนูสด: 10 เม็ด\nกะปิ: 1/2 ช้อนโต๊ะ\""
},
{
    'ชื่ออาหาร': 'แกงส้มผักกระเฉด',
    'ingredient_full_json': "\"ผักกระเฉด: 300กรัม\nกุ้งผ่าหลัง: 5-6ตัว\nปลากระป๋อง: 2กระป๋อง\nพริกสด: 50กรัม\nพริกแห้งป่น: 2ช้อนชา\nหอมแดง: 7-8หัว\nกระชาย: 2ช้อนโต๊ะ\nกระปิ: 2ช้อนโต๊ะ\nเกลือป่น: 1/2ช้อนชา\nน้ำตาล: 1ช้อนโต๊ะ\nน้ำปลา: 3ช้อนโต๊ะ\nน้ำมะขามเปียก: 4ช้อนโต๊ะ\nมะนาว: 3ลูก\""
},
{
    'ชื่ออาหาร': 'ก๋วยเตี๋ยวคั่วไก่',
    'ingredient_full_json': "\"เส้นใหญ่: \nอกไก่: \nเห็ดหูหนูขาว (ใช้แทนหมึกกรอบ): \nากผักชี, กระเทียม, พริกไทย (สำหรับหมักไก่): \nไข่ไก่: \nซีอิ๊วขาว, ซีอิ๊วดำ, น้ำปลา, ซอสพริก: \nผักกาดหอม: \nพริกเหลือง, น้ำส้มสายชู (สำหรับทำพริกดอง): \nไก่เชียง, หนังไก่ (เครื่องโรยหน้า):\""
},
{
    'ชื่ออาหาร': 'แกงเขียวหวานสำเร็จรูป',
    'ingredient_full_json': "\"หมูสันใน: 200 กรัม\nผงปรุงรสแกงเขียวหวาน: 1 ซอง\nน้ำกะทิ: 100 มล.\nใบมะกรูด: \nโหระพา: \nพริกชี้ฟ้าแดง: \nมะแว้งเขียว: 150 กรัม\nน้ำเปล่า: 50 มล.\""
},
{
    'ชื่ออาหาร': 'แกงมัสมั่นไก่',
    'ingredient_full_json': "\"สะโพกไก่: 500 กรัม\nพริกแกงมัสมั่น: 60 กรัม\nกะทิเรียลไทย: 750 มล\nถั่วลิสงคั่ว: 50 กรัม\nมันฝรั่ง (หั่นเต๋า): 4-5 ลูก\nหอมใหญ่: 2 หัว\nน้ำตาลมะพร้าว: 2-3 ชต\nน้ำปลาดี: 1-2 ชต\nน้ำมะขามเปียก น้ำส้มซ่า: 2-3 ชต\nอบเชย โป๊ยกั๊ก: \nลูกกระวาน ใบกระวาน: \nเกลือ: 1/2 ชช\""
},
{
    'ชื่ออาหาร': 'ข้าวกะเพราไก่ไข่ดาว',
    'ingredient_full_json': "\"เนื้อไก่สับ: 70กรัม\nใบกะเพรา: 1ถ้วย\nพริกแดงจินดา: 8เม็ด\nกระเทียม: 5กลีบ\nซีอิ๊วดำ: 1/2 ชช\nซอสหอยนางรม: 1/2 ช้อนโต๊ะ\nน้ำปลา: 1/2 ชต\nน้ำตาลทราย: 1ช้อนชา\nคนอร์ เนเชอรัล ผงรสหมูสูตรไม่ใส่ผงชูรส: 1ช้อนชา\nไข่ไก่: 1ฟอง\nน้ำมันพืช: \nข้าวสวย: 1ถ้วย\""
},
{
    'ชื่ออาหาร': 'แกงส้มกุ้งสับปะรด',
    'ingredient_full_json': "\"กุ้งขาว: 4 ขีด\nสับปะรดเปรี้ยวอมหวาน: 1/2 ลูกเล็ก\nเครื่องแกงส้มใต้: 2 ช้อนโต๊ะ\nกะปิ: 1.5ช้อนโต๊ะ\nน้ำปลา: 1.5 ช้อนโต๊ะ\nเกลือป่น: 1 หยิบมือ\nน้ำตาล: 1.5 ช้อนโต๊ะ\nน้ำมะขามเปียก: 1 ถ้วยน้ำซุป\nมะนาว: 1.5 ลูก\""
},
{
    'ชื่ออาหาร': 'แกงเขียวหวาน สันในหมู',
    'ingredient_full_json': "\"เครื่องแกงเขียวหวาน: 100g\nสันในหมู: 400g\nมะเขือเปราะ: 100g\nมะเขือพวง (ไม่ใส่เพราะไม่ชอบครับ): 0\nพริกชี้ฟ้า: นิดหน่อย\nโหระพา: นิดหน่อย\nกะทิ: 500ml\nซอสหอยนางรม: 3 ชต\nน้ำปลา: 4 ชต\nน้ำตาล: 4-5 ชช\""
},
{
    'ชื่ออาหาร': 'ฉู่ฉี่ปลาทู',
    'ingredient_full_json': "\"ปลาทูสด: 3ตัว\nกะทิกล่องอร่อยดี: 250 ml.\nพริกแกงเผ็ด: 3 ชต\nน้ำปลา: 2 ช้อนโต๊ะ\nน้ำตาลปี้บ: 1/2 ช้อนโต๊ะ\nใบมะกรูด: \nพริกแดง:\""
},
{
    'ชื่ออาหาร': 'แกงเลียงกะทิสด',
    'ingredient_full_json': "\"กุ้งขาวแกะเปลือกผ่าหลัง: 2 ขีด\nหัวหอมแดง: 3 หัว\nข่า(ใส่ดับกลิ่นคาวนิดนึง): 1ช้อนชา\nกระชาย: 2ช้อนชา\nกะปิ: 1ช้อนชา\nพริกไทยขาวเม็ด: 2-3 ช้อนชา\nกุ้งแห้ง: 2 ช้อนชา\nฟักทอง: \nข้าวโพดอ่อน: \nบวบ: \nเห็ดโคนญี่ปุ่น: \nใบแมงลัก: 1ขีด\nกะทิสด: 1/2 ถ้วย\nน้ำปลา ตามชอบ เราใส่แค่: 1ช้อน\""
},
{
    'ชื่ออาหาร': 'แกงส้มชะอมทอด',
    'ingredient_full_json': "\"กุ้ง: 3 ขีด\nปลาทูทอดแกะก้าง: 1 ตัว\nพริกแกงส้มใต้: 1 1/2 ช้อนโต๊ะ\nพริกแกงส้มกลาง: 1 1/2 ช้อนโต๊ะ\nน้ำตาลปี้บ: 2 ช้อนโต๊ะ\nน้ำปลา: 1/2 ทัพพี\nเกลือป่น: 1 หยิบมือ\nน้ำมะขามเปียก: 1/2 ถ้วยตวง\nน้ำสะอาด: 750 มล.\nผักกาดขาว: 1 หัว\nแครอท: 1 หัว\nหัวไชท้าว: 1 หัว\nชะอมทอด: 1 แพ\""
},
{
    'ชื่ออาหาร': '“แกงเลียงกุ้งสด"',
    'ingredient_full_json': "\"พริกแห้ง: 5-6 เม็ด\nหอมแดง: 10 หัว\nกระชาย: 10 แง่ง\nเกลือ: 1 ช้อนชา\nกะปิ: 1/2 ช้อนโต๊ะ\nกุ้งสด: 10 ตัว\nน้ำสะอาด: 3 ถ้วย\nฟักทอง: 400 กรัม\nบวบ: 2 ลูก\nข้าวโพด: 2 ฝัก\nเห็ดออรินจิ: 6 ดอก\nใบแมงลัก: 1 กำ\nน้ำตาลทราย: 4-5 ช้อนชา\nน้ำปลา: 5-6 ช้อนโต๊ะ\nผงปรุงรส: 1 ช้อนชา\nพริกไทยป่น: 1 1/2 ช้อนชา\""
},
{
    'ชื่ออาหาร': 'ฉู่ฉี่ปลานิล (สูตรคุณยาย)',
    'ingredient_full_json': "\"ปลานิล: 1 ตัว\nพริกแกงเผ็ด: 3 ช้อนโต๊ะ\nใบมะกรูดหั่นฝอย ประมาณ: 1 ½ ช้อนโต๊ะ\nน้ำปลา: 3 ช้อนโต๊ะ\nน้ำตาล: 1 ½ ช้อนโต๊ะ\nผงชูรส: 1 ช้อนชา\nน้ำมันพืช:\""
},
{
    'ชื่ออาหาร': 'แกงส้มผักรวมปลากระพง',
    'ingredient_full_json': "\"เนื้อปลากระพง: 250 g.\nพริกแกงส้ม: 2-3 ช้อนโต๊ะ\nมะละกอ: 100 g.\nหัวไชเท้า,แครอท: 100 g.\nผักบุ้งไทย: 100 g.\nถั่วฝักยาว,ถั่วพู: 100 g.\nน้ำมะขามเปียก: 4-5 ช้อนโต๊ะ\nน้ำตาลมะพร้าว: 1-2 ช้อนโต๊ะ\nน้ำปลาดี: 3 ช้อนโต๊ะ\nเกลือ: 1/2 ช้อนชา\nน้ำเปล่า: 3 ถต.\""
},
{
    'ชื่ออาหาร': 'ขนมจีนน้ำยากะทิไก่ข้น (หลัวรักหลัวหลง)',
    'ingredient_full_json': "\"เนื้ออกไก่: \nกะทิ: \nน้ำปลา: \nปลาร้า (ตามชอบ): \nพริกแห้ง หอมแดง กระเทียม ตะไคร้ ใบมะกรูด กระชาย:\""
},
{
    'ชื่ออาหาร': 'ขนมจีนแกงไตปลา',
    'ingredient_full_json': "\"ไตปลา: 1 ถ้วย\nข่า: 6 แว่น\nตะไคร้: 3 ต้น\nใบมะกรูด: 10 ใบ\nน้ำเปล่า: 4 ถ้วย\nพริกแกงไตปลา: 1/4 ถ้วย\nเนื้อปลาย่าง: 1 ถ้วย\nหน่อไม้ต้ม: 1 ถ้วย\nฟักทอง: 1 ถ้วย\nถั่วฟักยาว: 1/2 ถ้วย\nมะเขือเปราะ: 1/2 ถ้วย\nมะเขือพวง: 1/4 ถ้วย\n้น้ำมะขามเปียก: 1/4 ถ้วย\nน้ำตาลปี๊บ: 1 ช้อนโต๊ะ\nขนมจีน: ตามชอบ\""
},
{
    'ชื่ออาหาร': 'ผัดกะเพรากุ้ง',
    'ingredient_full_json': "\"กุ้งแกะเปลือก: 15 ตัว\nพริกชี้ฟ้าและกระเทียมโขลก: 1 ช้อนโต๊ะ\nใบกะเพรา: ตามชอบ\nน้ำตาลทราย: 2 ช้อนชา\nน้ำปลา: 1 ช้อนโต๊ะ\nน้ำมันรำข้าวสำหรับผัด:\""
},
{
    'ชื่ออาหาร': 'ข้าวกะเพราเนื้อสับ-ไข่ดาว',
    'ingredient_full_json': "\"เนื้อวัวสับ: 70กรัม\nพริกแดงจินดา: 4 เม็ด\nกระเทียมสับ: 3 กลีบ\nน้ำปลา: 1 ช้อนโต๊ะ\nซีอิ๊วขาว: 1/2 ช้อนโต๊ะ\nน้ำตาลทราย: 1 ช้อนชา\nใบกะเพรา (ตามชอบ): 1กำ\nน้ำมันรำข้าว 2 ช้อนโต๊ะ: 2 ช้อนโต๊ะ\""
},
{
    'ชื่ออาหาร': 'ผัดกะเพรากุ้ง',
    'ingredient_full_json': "\"กุ้งสดปอกเปลือก: 500 กรัม\nผงปรุงรสผัดกะเพราสำเร็จรูป: 1 ช้อนโต๊ะ\nน้ำตาลทราย: 1/2 ช้อนชา\nกะเพรา: 1 กำมือ\nพริกชี้ฟ้าเขียว: 1 ดอก\nพริกขี้หนูสด: 2 ดอก\nกระเทียมสับ 5-6 กลีบ: 1-2 ช้อนชา\nน้ำมันมะกอก: 1 ช้อนโต๊ะ\nน้ำอุ่น: 50 มล.\""
},
{
    'ชื่ออาหาร': 'ผัดเปรี้ยวหวานหมู',
    'ingredient_full_json': "\"เนื้อหมู: 100 กรัม\nแตงกวา: 3 ลูก\nสับปะรดเนื้อ 2: 100 กรัม\nหอมหัวใหญ่: 1 หัว\nมะเขือเทศ: 6 ลูก\nพริกหยวกสีเขียว: 3 เม็ด\nกระเทียมสับ: 1 ช้อนโต๊ะ\nน้ำตาล: 1/2 ช้อนโต๊ะ\nน้ำปลา: 1 ช้อนโต๊ะ\nซอสมะเขือเทศ: 3 ช้อนโต๊ะ\nน้ำเปล่าหรือน้ำซุป: 1/4 ถ้วย\nน้ำมันสำหรับผัด: 2 ช้อนโต๊ะ\nต้นหอมหั่นท่อน: 1 ต้น\""
},
{
    'ชื่ออาหาร': 'น้ำจิ้มปลาเผา (มะขาม)',
    'ingredient_full_json': "\"มะขาม: 1 ปั้น\nน้ำตาลปิ้บ: 1 ช้อนโต๊ะ\nน้ำเปล่า: 1 ถ้วย\nพริกขี้หนู: 10 เม็ด\nหอมแดง: 8 หัว\""
},
{
    'ชื่ออาหาร': 'แกงส้มผักรวมน้ำข้น',
    'ingredient_full_json': "\"น้ำ: 1/2ลิตร\nหัวไชเท้า: 1หัว\nแครอท: 1หัว\nถั่วฝักยาว: 1กำ\nเนื้อปลาดอลลี่แช่แข็ง(หรือจะใช้ปลาชนิดอื่นได้ แต่ควรเป็นปลาเนื้ออ่อน): 2ชิ้น\nผงทำแกงส้มคนอร์: 1ซอง\nน้ำมะขามเปียก (ตอนอยู่ที่อเมริกาไม่มี เราแอบใช้น้ำส้มสายชูแทน แต่ถ้าหาได้น้ำมะขามจะหอมกว่าเยอะ): 1ถ้วยเล็ก\nน้ำตาลทราย: 2ช้อนโต๊ะ\nน้ำปลา: 1ช้อนโต๊ะ\""
},
{
    'ชื่ออาหาร': 'แกงส้มปลาทู (แกงส้มใต้)',
    'ingredient_full_json': "\"ปลาทู: 3 ตัว\nมะละกอ: 300 กรัม\nผักบุ้งไทย: 100 กรัม\nน้ำมะขามเปียก: 2 ช้อนโต๊ะ\nน้ำตาลทราย: 1 ช้อนชา\nน้ำสะอาด: 600 มล\nเครื่องแกงส้มใต้: 1 1/2 ช้อนโต๊ะ\nกะปิ: 1 ช้อนชา\nมะนาว: 1 ลูก\""
},
{
    'ชื่ออาหาร': 'ขนมจีนน้ำยาปลาช่อน X ตีนไก่+ลูกชิ้นปลา',
    'ingredient_full_json': "\"ขนมจีน: 2กก\nปลาช่อน: 1ตัว\nกะทิหัวหาง: 1กก\nพริกแกงเผ็ด: 2ขีด\nกระชายซอย: 20บาท\nปลาอินทรีย์เค็ม: 1ชิ้น\nกะปิ: 1ชต\nน้ำปลา: 1-2ถ้วย\nผักสดต่างๆ: \nผักกาดดอง: \nใบแมงลัก: \nพริกแห้ง:\""
},
{
    'ชื่ออาหาร': 'เส้นใหญ่ผัดซีอิ๊วไก่',
    'ingredient_full_json': "\"เส้นใหญ่: 350 กรัม\nไก่หั่นเป็นชิ้น: 200 กรัม\nไข่ไก่: 2 ฟอง\nคะน้าหั่นท่อน: 3 ต้น\nกระเทียมสับ: 1 ช้อนโต๊ะ\nซีอิ๊วดำ: 2 ช้อนโต๊ะ\nน้ำปลา: 1 ช้อนโต๊ะ\nซอสปรุงรส: 2 ช้อนชา\nซีอิ๊วขาว: 1 ช้อนโต๊ะ\nน้ำมันพืช: \nมะนาว. พริกไทย:\""
},
{
    'ชื่ออาหาร': 'ยำวุ้นเส้นเครื่องล้น',
    'ingredient_full_json': "\"วุ้นเส้นสด: 1ห่อ\nหมูสับ: 2กรัม\nเห็ดเข็มทอง: 1ห่อ\nหอมแขก: ครึ่งหัว\nขึ้นช่าย: 2ต้น\nแครอท: เล็กน้อย\nผักกาดขาว: 3ใบ\nน้ำปลา: 2ช้อนโต๊ะ\nน้ำมะนาวสด: 2ช้อนโต๊ะ\nน้ำตาล: 1ช้อนชา\nพริกป่น: 1ช้อนโต๊ะ\""
},
{
    'ชื่ออาหาร': 'แกงเลียงใบตำลึง',
    'ingredient_full_json': "\"ใบตำลึง: 2 กำ\nไข่ไก่: 2 ฟอง\nกะปิ: 1 ช้อนโต๊ะ\nปลาฉิ้งฉ้าง: 1/2 ถ้วย\""
},
{
    'ชื่ออาหาร': 'ผัดฟักทองใส่ไข่ นิ่ม ฟิน',
    'ingredient_full_json': "\"ฟักทอง: 500 กรัม\nไข่ไก่: 2 ฟอง\nน้ำตาล: 1 ช้อนโต๊ะ\nน้ำปลา: 1/2 ช้อน\nแมกกี้: เหยาะๆให้หอม\nน้ำมันหอย: 2 ช้อนโต๊ะ\nกระเทียม: 4 กลีบ\""
},
{
    'ชื่ออาหาร': 'น้ำพริกกะปิกุ้งแห้ง',
    'ingredient_full_json': "\"กะปิอย่างดี: 30 กรัม\nกุ้งแห้ง: 1+1/2 ช้อนโต๊ะ\nพริกขี้หนูสวน: 25 เม็ด\nกระเทียมไทยกลีบเล็ก: 15 กลีบ\nน้ำปลา: ตามชอบ\nน้ำตาลปี๊บ: ตามชอบ\nน้ำมะนาว: ตามชอบ\nน้ำเปล่าต้มสุก: 1 ช้อนโต๊ะ\nใบตองหรือใบต้นกระชาย: 1 ใบ\nมะเขือพวง: 10 เม็ด\""
},
{
    'ชื่ออาหาร': 'น้ำพริกกะปิปลาทู',
    'ingredient_full_json': "\"กะปิ 5 ช้อนโต๊ะ: \nน้ำตาลปี๊บ 1 ช้อนโต๊ะ: \nมะนาว 7 ช้อนโต๊ะ: \nกระเทียม 6 ช้อนโต๊ะ: \nพริกขี้หนู 20 เม็ด: \nปลาทู 2 ตัว: \nน้ำต้มสุก 6 ช้อนโต๊ะ:\""
},
{
    'ชื่ออาหาร': 'แกงส้มไหลบัวปลากระพงปักษ์ใต้',
    'ingredient_full_json': "\"ไหลบัว: 8 เส้น\nพริกป่นแบบใต้ที่ละเอียด: 2 ช้อนโต๊ะ\nกะปิ: 1 ช้อนโต๊ะ\nเกลือ: 1/2 ช้อนชา\nปลากระพงหั่นชิ้นขนาดพอคำ: 1 ตัว\nมะนาว: 7 ช้อนโต๊ะ\nพริกไทยเม็ดดำ: 10 เม็ด\""
},
{
    'ชื่ออาหาร': 'ข้าวต้มหมูทรงเครื่อง',
    'ingredient_full_json': "\"ข้าวสวย: 2 ถ้วย\nหมูสับปั้นเป็นก้อนกลม: 150 กรัม\nคนอร์ซุปก้อน: 1 ก้อน\nน้ำเปล่า: 3-4 ถ้วย\nขิงแก่ซอย: 2 ช้อนโต๊ะ\nกระเทียมสดแกะเปลือก: 1 ช้อนโต๊ะ\nกุ้งแห้ง: 1 ช้อนโต๊ะ\nปลาหมึกแห้ง: 1 ช้อนโต๊ะ\nคื่นช่ายหั่นซอย: 1 ช้อนโต๊ะ\nพริกไทยป่น: \nเกลือ: 1/3 ช้อนชา\nซอลแม็กกี้: 1 1/2 ช้อนชา\""
},
{
    'ชื่ออาหาร': 'ต้มยำกุ้งแม่น้ำ (น้ำข้น)',
    'ingredient_full_json': "\"กุ้งแม่น้ำ: 5ขีด\nเม็ดฟาง: \nข่า: \nตะไคร้: \nใบมะกรูด: \nมะนาว: \nพริก: \nน้ำปลา: \nน้ำตาล: \nนมสดจืด:\""
},
{
    'ชื่ออาหาร': 'ผัดเผ็ดไก่มะเขือเปาะ',
    'ingredient_full_json': "\"อกไก่: 1อก\nตับไก่: 20บาท\nมะเขือเปาะ: 6-8ลูก\nโหระพา: 5บาท\nใบมะกรูดฉีก: 5-6ใบ\nพริกแกงเผ็ด: 10บาท\nกะทิกล่องเล็ก: 1กล่อง\nน้ำตาลปึก: 2/4:ก้อน\nน้ำปลา: 3-5ชต\""
},
{
    'ชื่ออาหาร': 'แกงส้มฟักแม้วกุ้งสด',
    'ingredient_full_json': "\"ฟักแม้ว: 2 หัว\nปลานิล: 1 ตัว\nพริกแกงส้ม: 1 ขีด\nน้ำมะขามเปียก: 5 ช้อน\nน้ำปลา: 4 ช้อน\nน้ำตาลปีบ: 1 ช้อน\nกุ้ง: 6-7 ตัว\nเกลือป่น: 1/2\""
},
{
    'ชื่ออาหาร': 'แกงเขียวหวานหน่อไม้ไก่',
    'ingredient_full_json': "\"เนื้อสะโพกไก่: 3 ชิ้น\nพริกแกงเขียวหวานสำเร็จรูปตามตลาดสด: 10 บาท\nกะทิ: 0.5 กิโล\nใบโหระพา: 5 บาท\nหน่อไม้ดอง: 0.5 กิโล\nน้ำปลา: ตามชอบ\nน้ำตาล: ตามชอบ\""
},
{
    'ชื่ออาหาร': 'ขนมจีนน้ำยา สูตรเด็ด',
    'ingredient_full_json': "\"ปลาทับทิม: 1 โล\nกะทิ: 1 โล\nหางกะทิ: 1 โล\nลูกชิ้นปลา: ตามใจชอบ\nกระชาย: 2 ขีด\nกะปิ: 1 ช้อนโต๊ะ\nน้ำปลา: 1 ช้อนโต๊ะ\nพริกแกงน้ำยา: 2 ขีด\nคนอร์: 2 ก้อน\nน้ำตาลปี๊บ: 1 ช้อนชา\""
},
{
    'ชื่ออาหาร': 'ข้าวผัดต้มยำกุ้ง',
    'ingredient_full_json': "\"ข้าวสวย: 1ถ้วย\nกุ้งสดปอกเปลือกผ่าหลัง: 40กรัม\nข่าซอย: 1ช้อนโต๊ะ\nตะไคร้ซอย: 2ต้น\nใบมะกรูดซอย: 1ช้อนโต๊ะ\nหอมแดงซอย: 2หัว\nมะเขือเทศหั่นเต๋าเล็ก: 1ช้อนโต๊ะ\nน้ำมะนาว: 1ช้อนโต๊ะ\nพริกแดงซอย: 1ช้อนโต๊ะ\nเห็ดฟาง: ตามชอบ\nกระเทียมสับ: 1ช้อนโต๊ะ\nน้ำพริกเผา: 1 1/2 ช้อนโต๊ะ\nน้ำปลา: 1/2ชต\nน้ำตาลทราย: 1/2ช้อนชา\nน้ำมันพืช: \nต้นหอมซอย:\""
},
{
    'ชื่ออาหาร': 'แกงส้มชะอมไข่ใส่ปลาทู',
    'ingredient_full_json': "\"ชะอมเด็ดเอาแต่ใบ: 1ถ้วย\nไข่ไก่: 1ฟอง\nผักกาดขาว: 1หัว\nหัวไชเท้า: 1หัว\nพริกแกงส้มตามสูตรเคยที่ให้ไว้นะคะ: 3 ช้อน\nน้ำมะขามเปียก: 5 ช้อน\nน้ำตาลปีบ: 2ช้อน\nน้ำปลา: 3ช้อน\nน้ำมันพืชสำหรับทำไข่ชะอม: 1 ช้อนชา\nปลาทูย่างแกะเอาแต่เนื้อ: 2 ตัว\""
},
{
    'ชื่ออาหาร': 'ต้มยำปลากระป๋อง',
    'ingredient_full_json': "\"1.ปลากระป๋อง: 2 กระป๋อง\n2.ข่า: 8 แว่น\n3.ตะไคร้: 3 ต้น\n4.ใบมะกรูด: 5-6 ใบ\n5.หอมแดง: 3 หัว\n6.น้ำเปล่า: 3 ถ้วย\n7.มะนาว: 2 ลูก\n8.น้ำปลา: 1+1/2 ช้อนโต๊ะ\n9.ซุปคนอร์ก้อน: 1 ก้อน\n10.พริกขี้หนูบุบ: 10 เม็ด\n11.ผักชีใบเลื่อย: 3 ใบ\n12.เห็ดนางฟ้า: 1 ถ้วย\""
},
{
    'ชื่ออาหาร': 'แกงส้มใต้มันขี้หนู',
    'ingredient_full_json': "\"มันขี้หนู: 300 กรัม\nปลาทูสดหรือปลาอะไรก็ได้: 4-5 ตัว\nน้ำพริกแกงเหลือง: 2 ช้อนโต๊ะ\nน้ำเปล่า: 4 ถ้วย\nน้ำปลา: 3 ช้อนโต๊ะ\nน้ำตาลปี๊บ: 1 ช้อนโต๊ะ\nน้ำมะขามเปียก: 3 ช้อนโต๊ะ\nส้มแขก: 3 ชิ้น\nน้ำมะนาว: ตามชอบ\nกะปิ: 2 ช้อนชา\""
},
{
    'ชื่ออาหาร': 'สูตร แกงเลียง ระดับเทพ อร่อยกว่าร้านดังแน่นอน',
    'ingredient_full_json': "\"ผักหวาน: 1 กำ\nกวางตุ้งแบบมีดอก: 1 กำ\nชะอม: 1 กำ\nใบแมงลัก: 1 กำ\nบวบ: 5-6 อัน\nฟักทอง: ซีกนึง\nเห็ดนางฟ้า: 1 กำ\nเห็ดหูหนู: 1 กำ\nเห็ดเข็มทอง: 1 กำ\nเห็ดฟาง: 1 กำ\nกุ้ง: ครึ่ง กก\nกระดูกหมู: 1 กิโลกรัม\nพริกกระเหรี่ยง: 1 กำ\nกระชาย: 1 กำ\nหอมแดง: 1 กำ\nกระปิอย่างดี: 2 ช้อนโต๊ะ\nพริกไทยขาว: 2 ช้อนโต๊ะ\nปลาทูนึ่ง: 12 ตัว\nน้ำปลาตราปลาหมึก: ตามความชอบ\""
},
{
    'ชื่ออาหาร': 'แกงเขียวหวานไก่',
    'ingredient_full_json': "\"เนื้ออกไก่: 2 กิโลกรัม\nเลือดไก่: 2 ก้อน\nเครื่องในไก่: 5-6 พวง\nน้ำพริกแกงเขียวหวาน: 6-8 ขีด แล้วแต่ความเผ็ด\nมะเขือเปราะ: 1/2 กิโลกรัม\nหัวกะทิ: 1 กิโลกรัม\nหางกะทิ: 2 กิโลกรัม\nน้ำปลา: 6 ช้อนโต๊ะ\nเกลือ: 1-2 ช้อนโต๊ะ\nใบโหระพาเด็ด: ปริมาณตามชอบ\nพริกชี้ฟ้าหั่นแฉลบ: ปริมาณตามชอบ\nน้ำตาลปี๊บ: เล็กน้อย\""
},
{
    'ชื่ออาหาร': 'แกงเขียวหวานลูกชิ้นปลากราย',
    'ingredient_full_json': "\"ลูกชิ้นปลากรายเม็ดจิ๋ว: 1/2กก\nพริกแกงเขียวหวาน: 1ขีด\nกะทิ: 2กล่อง\nมะเขือเปาะ: 10-15ลูก\nกระชายฝอย: 1/2ขีด\nโหรภา: 1กำ\nพริกชี้ฟ้าแดง: 3เม็ด\nใบมะกรูดฉีก: 5-6ใบ\nน้ำตาลปึก: 3 ก้อน\nน้ำปลา: 1ถ้วย\nน้ำตาลทราย: 3-5ชช\""
},
{
    'ชื่ออาหาร': 'ขนมจีนน้ำยากะทิไก่ไม่เผ็ดสำหรับเด็ก',
    'ingredient_full_json': "\"เนื้อไก่บด (ไก่ต้มที่ได้จากทำน้ำสต็อก): 100 กรัม\nกะทิ (แบ่ง 2ส่วน ส่วนละ150มล): 300 มล.\nพริกแกงเด็ก(ตามสูตรที่ลงไว้): 80 กรัม\nน้ำสต็อกไก่: 2 ถ้วย\nเลือดไก่: 80 กรัม\nน้ำปลา: 2 ช้อนโต๊ะ\nน้ำตาลปี๊บ: 1/2 ช้อนโต๊ะ\nต้นหอมหั่น: 2 ต้น\nใบมะกรูดฉีก: 3 ใบ\nน้ำมันพืช: 1 ช้อนโต๊ะ\nเส้นขนมจีนอัญชัน: ตามชอบ\nผักเครื่องเคียง: ตามชอบ\nไข่ต้ม:\""
},
{
    'ชื่ออาหาร': 'ยำปลากระป๋องทอดกร๊อบกรอบ',
    'ingredient_full_json': "\"ปลากระป๋อง: 3 กระป๋อง\nมะนาว: 3 ลูก\nน้ำปลา: 1 ช้อนโต๊ะ\nต้นหอมหั่นท่อน: 4 ต้น\nพริกขี้หนูซอย: 3 ช้อนโต๊ะ\nแครอทซอยเป็นเส้นๆ: 1 ถ้วย\nขึ้นฉ่ายหั่นท่อน: 1 ต้น\nน้ำตาลทราย: 1 ช้อนชา\nไข่ไก่: 1 ฟอง\nเกล็ดขนมปัง: 1 จาน\nแป้งเอนกประสงค์: 1 จาน\nน้ำมัน:\""
},
{
    'ชื่ออาหาร': 'ข้าวผัดรถไฟ (ข้าวผัดซีอิ๊ว)​',
    'ingredient_full_json': "\"หมู: 50 กรัม\nไข่ไก่: 2 ฟอง\nข้าวสวย: 3 ถ้วย\nต้มหอม: 2 ต้น\nหอมใหญ่: 1/4 หัว\nมะเขือเทศ: 1 ลูก\nคะน้า: 2 ต้น\nน้ำตาล: 1 ชต\nซีอิ๊ว: 1 ชต\nเกลือ: 1 ชต\nน้ำมันหอย: 1 ชต\nซีอิ๊วดำ: 1 ชช\nกระเทียม: 3 กลีบ\""
},
{
    'ชื่ออาหาร': 'แกงส้มดอกแคเนื้อปลานินทอดกรอบ',
    'ingredient_full_json': "\"พริกแกงส้ม: 2ขีด\nน้ำเปล่า: 1ลิตร\nน้ำมะขามเปียก: 1ถ้วยเล็ก\nน้ำตาลปี้ป: 1/2ทัพพี\nดอกแค: 20ดอก\nน้ำปลา: 2 ช้อนโต๊ะ\nเนื้อปลานิน: 1ตัว\""
},
{
    'ชื่ออาหาร': 'ผัดเผ็ดปลาดุกพริกสด',
    'ingredient_full_json': "\"ปลาดุก: \nมะเขือเจ้าพระยา: \nใบมะกรูด: \nกระชาย: \nพริกไทยอ่อน: \nซอสปรุงรส: \nน้ำมันหอย: \nผงปรุงรส: \nกระเทียม: \nพริกขี้หนู:\""
},
{
    'ชื่ออาหาร': 'แกงส้มไข่ปลาเรียวเซียว',
    'ingredient_full_json': "\"ยอดมะพร้าว: 200กรัม\nไข่ปลาเรียวเซียว: 200กรัม\nเนื้อปลาช่อน: 100กรัม\nน้ำสต็อก: 2ถ้วย\nพริกแกงส้ม: 1ชต\nข่า ตะไคร้ ใบมะกรูด: 1/2 ถ้วย\nน้ำปลา: 1ชต\nน้ำตาลปี๊บ: 1ชต\nมะขามเปียก: 1/2ถ้วย\""
},
{
    'ชื่ออาหาร': 'ขนมจีนน้ำยากะทิหมู 🐷',
    'ingredient_full_json': "\"หมูบด: 250 กรัม\nพริกแกงเผ็ด: 70 กรัม\nกระชายซอย: 50 กรัม\nกะทิ: 500 มล.\nใบมะกรูด: 1 กิ่ง\nผงปรุงรส: 1 ก้อน\nขนมจีน ผัก ตามชอบ: 1 ชุด\""
},
{
    'ชื่ออาหาร': 'หอยทอด(ทะเลทอด)',
    'ingredient_full_json': "\"แป้งทอดกรอบ: 1ถ้วย\nกุ้ง: 12ตัว\nหมึก: 3ตัว\nหอยแมงภู่: 100กรัม\nน้ำเย็ดจัด: 1ถ้วย\nนมสด: 1/2ถ้วย\nไข่ไก่: 3ฟอง\nถั่วงอกดิบ: ตามชอบ\nพริกไทยป่น: ตามชอบ\nซีอิ้วขาว: 2ช้อนโต๊ะ\nน้ำปลา: 1ช้อนโต๊ะ\nน้ำตาล: 1ช้อนโต๊ะ\nต้นหอมผักชี: 2-3ต้น\""
},
{
    'ชื่ออาหาร': 'แกงเทโพหมูสามชั้น',
    'ingredient_full_json': "\"หมูสามชั้น: 200 กรัม\nผักบุ้ง: 500 กรัม\nพริกแกงเผ็ด: 100 กรัม\nมะขามเปียก: 1 กำ\nน้ำตาลมะพร้าว: 1 ช้อนโต๊ะ\nน้ำปลา: เหยาะๆ ลงไป\nมะกรูด: 3 ลูก\nใบมะกรูด: 10 ใบ\nกะทิ: 1000 มล\""
},
{
    'ชื่ออาหาร': 'เส้นหมี่ผัดซีอิ๊วหมูนุ่ม',
    'ingredient_full_json': "\"เส้นหมี่สำเร็จรูป: 180 กรัม\nหมูนุ่ม: 200 กรัม\nกระเทียมสับ: 1 ช้อนโต๊ะ\nน้ำมันพืช: 2-3 ช้อนโต๊ะ\nซีอิ๊วดำสำหรับคลุกเส้น: \nซีอิ๊วขาว: 3 ช้อนโต๊ะ\nน้ำปลา: 1 ช้อนโต๊ะ\nน้ำตาลทราย: 1 ช้อนชา\nผักคะน้า: 2 ต้น\nไข่ไก่เบอร์ 1: 3 ฟอง\""
},
{
    'ชื่ออาหาร': 'ต้มยำกุ้งมะพร้าวอ่อน',
    'ingredient_full_json': "\"พริกขี้หนู: 7 เม็ด\nตะไคร้: เล็กน้อย\nใบมะกรูด: เล็กน้อย\nข่า: เล็กน้อย\nผักชีฝรั่ง: เล็กน้อย\nเห็ดนางฟ้า: 70 กรัม\nเห็ดหลินขาว: 40 กรัม\nเห็ดฟาง: 100 กรัม\nเนื้อมะพร้าวอ่อน: 80 กรัม\nน้ำมะพร้าว: 700 ml.\nกุ้งแกะเปลือก: 200 กรัม\nน้ำตาลทราย: 2 ช้อนชา\nน้ำปลา: 6 ช้อนโต๊ะ\nน้ำมะนาว: 6 ช้อนโต๊ะ\nกะทิ: 100 ml.\nน้ำพริกเผา: 2 ช้อนโต๊ะ\nมันกุ้ง: 1 ช้อนโต๊ะ\""
},
{
    'ชื่ออาหาร': 'หน่อไม้ผัดพริกแกงหมูสับ',
    'ingredient_full_json': "\"หน่อไม้ต้ม ซอยบางๆ: 1 ถ้วย\nน้ำพริกแกงเผ็ด: 2 ช้อนโต๊ะ\nหมูสับ: 1/4 ถ้วย\nใบมะกรูดฉีก: 4-5 ใบ\nพริกไทยอ่อนตัดสั้นๆ: 3-4 ฝัก\nพริกชี้ฟ้าซอย: 1 เม็ด\nน้ำตาลทราย: 1/2 ช้อนโต๊ะ\nน้ำปลา: 1-2 ช้อนโต๊ะ\""
},
{
    'ชื่ออาหาร': 'แกงส้มผักบุ้งปลาน้ำดอกไม้',
    'ingredient_full_json': "\"ผักบุ้งไทย: 2 กำ\nปลาน้ำดอกไม้: 2 ตัว\nพริกแกงส้ม: 2 ขีด\nมะขามเปียก: 5 ฝัก\nน้ำปลา: 5ช้อนโต้ะ\nน้ำตาลปี๊บ: 3ช้อนโต้ะ\nเกลือ: 2ช้อนโต้ะ\nน้ำเปล่า: 4 ลิตร\""
},
{
    'ชื่ออาหาร': 'ฉู่ฉี่ปลาหมอ',
    'ingredient_full_json': "\"ปลาหมอตัวใหญ่ๆ: 2 ตัว\nเครื่องแกงผัดเผ็ดภาคกลาง: 200 กรัม\nเครื่องแกงพะแนงกับกระชายสับละเอียด: 100 กรัม\nกระชายซอย: 50 กรัม\nใบมะกรูดซอย: 20 กรัม\nกะทิคั้น: 400 กรัม\nคะไคร้หั่นท่อน: 2 ต้น\nข่า: 20 กรัม\nใบมะกรูดฉีก: 15 กรัม\nพริกขี้หนูสวน: 10-15 เม็ด\""
},
{
    'ชื่ออาหาร': 'แกงเทโพใส่หมูสามชั้น',
    'ingredient_full_json': "\"หมูสามชั้น (หั่นชิ้นพอคำ ไม่ต้องหนามาก): 200 กรัม\nผักบุ้งไทย (หั่นท่อนพอคำ ล้างให้สะอาด): 400 กรัม\nหัวกะทิ: 1 ถ้วย\nหางกะทิ: 2 1/2 ถ้วย\nน้ำมะขามเปียก: 3-4 ช้อนโต๊ะ\nน้ำตาลปี๊บ: 1 ช้อนโต๊ะ\nน้ำปลา: 3 ช้อนโต๊ะ\nมะกรูด ผ่าครึ่ง เอาเมล็ดออก): 2 ลูก\nเกลือ: 1 ช้อนชา\nใบมะกรูด: 4-5 ใบ\nผงปรุงรสคนอร์ อร่อยชัวร์: 2 ช้อนชา\nน้ำพริกแกงเผ็ด: 100 กรัม\""
},
{
    'ชื่ออาหาร': 'ขนมจีนน้ำยาป่าปลาดุกย่าง',
    'ingredient_full_json': "\"ปลาดุกย่าง: 2 ตัว\nกระเทียม: 5 กลีบ\nหอมแดง: 5 หัว\nกระชาย: 8 ราก\nตะไคร้: 2 ต้น\nใบมะกรูด​: 10 ใบ\nพริกแห้ง: 7 เม็ด\nขนมจีน: 1 กิโล​กรัม\nน้ำเปล่า: 6 ถ้วย\nเกลือ: ปรุงรส\""
},
{
    'ชื่ออาหาร': 'ผัดเปรี้ยวหวานไก่กรอบ',
    'ingredient_full_json': "\"สันในไก่หั่นชิ้นพอดีคำ: 2-3 เส้น\nแป้งอเนกประสงค์: 1 ถ้วย\nหอมใหญ่ปอก หั่นเสี้ยว: 1 ลูก\nมะเขือเทศสีดาผ่าครึ่ง: 2-3 ลูก\nพริกหวานหั่นพอดีคำ: 1/2 ลูก\nแตงร้าน ปอกเปลือก หั่นชิ้นพอดีคำ: 1/2 ลูก\nเห็ดหอมสดผ่าสี่: 2 ดอก\nต้นหอมหั่นท่อน: 3-4 ต้น\nกระเทียมสับ: 1 ช้อนโต๊ะ\nน้ำตาลทราย: 1 ช้อนโต๊ะ\nซอสปรุงรส: 1 ช้อนโต๊ะ\nซอสมะเขือเทศ: 1/2 ถ้วย\nน้ำส้มสายชู: 1 ช้อนโต๊ะ\""
},
{
    'ชื่ออาหาร': 'บะหมี่ผัดเย็นตาโฟแห้ง',
    'ingredient_full_json': "\"บะหมี่: 1\nลูกชิ้นปลา: ตามชอบ\nลูกชิ้นกุ้ง: ตามชอบ\nฮื่อก๊วย: ตามชอบ\nเกี๊ยวปลา: ตามชอบ\nปลาหมึกกรอบ: ตามชอบ\nผักบุ้งไทย: ตามชอบ\nซอสเย็นตาโฟ: 1\nพริกแดงจินดา: 4-5 เม็ด\nกระเทียม: 3-4 กลีบ\nซอสหอยนางรม: 1/2 ช้อนโต๊ะ\nน้ำตาล: 1/2 ช้อนชา\nซีอิ๊วขาว: 1/2 ช้อนชา\nน้ำส้มสายชู: 1 ช้อนชา\nน้ำมัน: 1/2 ช้อนโต๊ะ\""
},
{
    'ชื่ออาหาร': 'แกงเขียวหวานไก่ใส่หน่อไม้',
    'ingredient_full_json': "\"ไก่สับ: 1/2 ตัว\nเลือดไก่: 1 ก้อน\nมะเขือเปราะ: 500 กรัม\nหน่อไม้: 1 หน่อ\nโหระพา: 4 กิ่ง\nพริกแกงเขียวหวาน: 150 กรัม\nกะทิ: 1000 มิลลิลิตร\nน้ำตาลปี๊บ: 1 ช้อนโต๊ะ\nผงปรุงรส: 2 ก้อน\nน้ำปลา: 2 ช้อนโต๊ะ\nมะเขือพวง: 50 กรัม\""
}
]

new_recipe_df = pd.DataFrame(new_recipe_data)

def parse_ingredient_string(ingredient_str):
    lines = ingredient_str.strip('"').split('\n')
    result = {}
    for line in lines:
        if ':' in line:
            parts = line.split(':', 1)
            name = parts[0].strip()
            quantity = parts[1].strip()
            result[name] = quantity
    return result

new_recipe_df['simplified_ingredients'] = new_recipe_df['ingredient_full_json'].apply(parse_ingredient_string)

def find_closest_match(ingredient, thai_names):
    matches = get_close_matches(ingredient, thai_names, n=1, cutoff=0.3)
    return matches[0] if matches else None

def calculate_calories(fat, protein, carbs):
    return (fat * 9) + (protein * 4) + (carbs * 4)


def process_recipe(row, skip_unmatched=True):
    food_name = row['ชื่ออาหาร']
    raw_ingredients = row['ingredient_full_json']
    ingredients = parse_ingredient_string(raw_ingredients)
    nutrition_info_dict = {}

    print(f"\nProcessing recipe: {food_name}")
    for ing_name, quantity in ingredients.items():
        closest = find_closest_match(ing_name, nutrition_data['Thai_Name'].astype(str))
        if closest:
            nut_info = nutrition_data[nutrition_data['Thai_Name'] == closest]
            try:
                fat = float(nut_info['Fat(g)'].iloc[0])
                protein = float(nut_info['Protein(g)'].iloc[0])
                carbs_raw = nut_info['Carbs(g)'].iloc[0]
                carbs = float(carbs_raw) if carbs_raw not in ['-', ''] else 0
                cal = calculate_calories(fat, protein, carbs)

                nutrition_info_dict[closest] = {
                    'fat': fat,
                    'protein': protein,
                    'carbs': carbs,
                    'calories': cal
                }

                print(f"Matched: {ing_name} → {closest}, Calories: {cal:.2f}")
            except Exception as e:
                print(f"Error parsing values for: {closest} | Error: {e}")
        else:
            if skip_unmatched:
                print(f"Skipped (no match): {ing_name}")
            else:
                raise ValueError(f"No match found for: {ing_name}")


    total_protein = sum(info.get('protein', 0) for info in nutrition_info_dict.values())
    total_fat = sum(info.get('fat', 0) for info in nutrition_info_dict.values())
    total_carbs = sum(info.get('carbs', 0) for info in nutrition_info_dict.values())
    total_calories = sum(info.get('calories', 0) for info in nutrition_info_dict.values())

    print(f"\nTotal protein for {food_name}: {total_protein:.2f} g")
    print(f"Total fat for {food_name}: {total_fat:.2f} g")
    print(f"Total carbs for {food_name}: {total_carbs:.2f} g")
    print(f"Total calories for {food_name}: {total_calories:.2f} kcal")
    return {'total_protein': total_protein, 'total_fat': total_fat,
            'total_carbs': total_carbs, 'total_calories': total_calories}

new_recipe_df = pd.DataFrame(new_recipe_data)

new_recipe_df['nutrition_info'] = new_recipe_df.apply(process_recipe, axis=1)

nutrition_df = pd.DataFrame(new_recipe_df['nutrition_info'].tolist())
final_df = pd.concat([new_recipe_df, nutrition_df], axis=1)

for column in final_df.columns:
    if column != 'simplified_ingredients':
        final_df[column] = final_df[column].astype(str)

from google.colab import sheets
sheet = sheets.InteractiveSheet(df=final_df)
# Out:
# Processing recipe: ก๋วยเตี๋ยวคั่วไก่ แบบง่าย
# Matched: เส้นใหญ → เส้นหมี่, Calories: 144.30
# Matched: ไข่ไก → ไข่ไก่, Calories: 236.70
# Matched: ซีอิ๊วขาว → ซีอิ๊วขาว, Calories: 126.40
# Matched: น้ำตาล → น้ำตาล, Calories: 400.00
# Matched: เกลือ → เกลือ, Calories: 0.00
# Matched: ต้นหอม → ต้นหอม, Calories: 118.60
# Matched: อกไก่ → อกไก่, Calories: 263.00
# Matched: น้ำตาลทราย → น้ำตาลทรายแดง, Calories: 386.10
# Matched: แป้งมัน → แป้งมันสำปะหลัง, Calories: 111.30
# Matched: พริกไทย → พริกไทย, Calories: 325.70
#
# Total protein for ก๋วยเตี๋ยวคั่วไก่ แบบง่าย: 56.50 g
# Total fat for ก๋วยเตี๋ยวคั่วไก่ แบบง่าย: 20.90 g
# Total carbs for ก๋วยเตี๋ยวคั่วไก่ แบบง่าย: 424.50 g
# Total calories for ก๋วยเตี๋ยวคั่วไก่ แบบง่าย: 2112.10 kcal
#
# Processing recipe: ขนมจีนน้ำยากะทิตีนไก่
# Matched: เนื้อไก่ → เนื้อไก่, Calories: 290.80
# Matched: น้ำกะทิ → กะทิ, Calories: 148.00
# Matched: พริกแกง → พริกแกง, Calories: 148.70
# Matched: ใบมะกรูด → ใบมะกรูด, Calories: 136.70
# ...

# %%
import pandas as pd

df = pd.read_csv("เมนูอาหาร 515 เหลือลบกับใส่ชื่อวัตถุดิบ - Sheet1.csv")
df_recipe = pd.read_csv("recipes ไข่ไก่, 1 ฟอง.csv")


df_cleaned = df.drop_duplicates(subset='ชื่ออาหาร')
df_merged = pd.merge(df_cleaned, df_recipe[['ชื่ออาหาร', 'วัตถุดิบ']], on='ชื่ออาหาร', how='left')

df_merged.to_csv("ลบชื่ออาหาร_รวมวัตถุดิบ.csv", index=False, encoding='utf-8-sig')

print("Completed! Saved as 'ลบชื่ออาหาร_รวมวัตถุดิบ.csv'")

import pandas as pd

df = pd.read_csv('ลบชื่ออาหาร_รวมวัตถุดิบ.csv')

print(df.head())

from google.colab import sheets
sheet = sheets.InteractiveSheet(df=df)
# Out:
# Completed! Saved as 'ลบชื่ออาหาร_รวมวัตถุดิบ2.csv'
#             ชื่ออาหาร                               ingredient_full_json  \
# 0      แกงเลียงกุ้งสด  "กุ้งสดปอกเปลือกผ่าหลัง: 250กรัม\nข้าวโพดอ่อนห...
# 1      แกงเลียงกุ้งสด  "กุ้งสดปอกเปลือกผ่าหลัง: 250กรัม\nข้าวโพดอ่อนห...
# 2      แกงเลียงกุ้งสด  "กุ้งสดปอกเปลือกผ่าหลัง: 250กรัม\nข้าวโพดอ่อนห...
# 3        ปลานึ่งมะนาว  "ปลา ตามชอบ ปลากะพง ปลาทับทิม ปลานิล ฯลฯ: 1ตัว...
# 4  มาม่าผัดขี้เมาทะเล  "กุ้ง เนื้อปลา ปลาหมึก: ไม่ต้องเยอะมากอะ กะเอา...
#
#    total_protein  total_fat  total_carbs  total_calories  \
# 0          197.1      100.8        506.2          3720.4
# 1          197.1      100.8        506.2          3720.4
# 2          197.1      100.8        506.2          3720.4
# 3           40.7        2.8        238.7          1142.8
# 4          108.8       46.1        188.7          1604.9
#
#                                             วัตถุดิบ
# 0                                                NaN
# ...

# %% [markdown]
# ลบเมนูที่ซ้ำกัน

# %%
import pandas as pd

df = pd.read_csv("แก้ 515 - Sheet1.csv")

df_cleaned = df.drop_duplicates(subset='ชื่ออาหาร')

df_cleaned.to_csv("ลบชื่ออาหาร_รวมวัตถุดิบ2.csv", index=False, encoding='utf-8-sig')

print("Duplicate dish names removed and saved to 'ลบชื่ออาหาร_รวมวัตถุดิบ2.csv'")

df = pd.read_csv('ลบชื่ออาหาร_รวมวัตถุดิบ2.csv')

print(df.head())

from google.colab import sheets
sheet = sheets.InteractiveSheet(df=df)
# Out:
# Duplicate dish names removed and saved to 'ลบชื่ออาหาร_รวมวัตถุดิบ2.csv'
#                          ชื่ออาหาร  \
# 0                   แกงเลียงกุ้งสด
# 1                     ปลานึ่งมะนาว
# 2               มาม่าผัดขี้เมาทะเล
# 3  แกงเขียวหวานหมู (มือใหม่หัดแกง)
# 4                           แกงป่า
#
#                                 ingredient_full_json  total_protein  \
# 0  "กุ้งสดปอกเปลือกผ่าหลัง: 250กรัม\nข้าวโพดอ่อนห...          197.1
# 1  "ปลา ตามชอบ ปลากะพง ปลาทับทิม ปลานิล ฯลฯ: 1ตัว...           40.7
# 2  "กุ้ง เนื้อปลา ปลาหมึก: ไม่ต้องเยอะมากอะ กะเอา...          108.8
# 3  "เนื้อหมู: 1 Kg\nพริกแกงเขียวหวาน: 2 ขีด\nหัวก...           63.6
# 4  "เนื้อไก่: 200 g\nพริกไทย: ตามชอบ\nพริกแดง: ตา...           75.5
#
#    total_fat  total_carbs  total_calories  \
# 0      100.8        506.2          3720.4
# 1        2.8        238.7          1142.8
# 2       46.1        188.7          1604.9
# 3      145.7        210.1          2406.1
# 4       20.1        380.4          2004.5
#
# ...

# %% [markdown]
# label สารอาหารว่ามีปริมาณเท่าไหร่

# %%
import pandas as pd

df = pd.read_csv("500 เมนู - Sheet1.csv")

df['total_calories'] = pd.to_numeric(df['total_calories'], errors='coerce')
df['total_protein'] = pd.to_numeric(df['total_protein'], errors='coerce')
df['total_fat'] = pd.to_numeric(df['total_fat'], errors='coerce')
df['total_carbs'] = pd.to_numeric(df['total_carbs'], errors='coerce')


def label_calorie(cal):
    if cal <= 1000:
        return 'แคลน้อย'
    elif cal <= 2000:
        return 'แคลกลาง'
    else:
        return 'แคลมาก'

def label_protein(p):
    if p <= 50:
        return 'โปรตีนน้อย'
    elif p <= 100:
        return 'โปรตีนกลาง'
    else:
        return 'โปรตีนสูง'

def label_fat(f):
    if f <= 100:
        return 'ไขมันน้อย'
    elif f <= 200:
        return 'ไขมันกลาง'
    else:
        return 'ไขมันสูง'

def label_carbs(c):
    if c <= 100:
        return 'คาร์บน้อย'
    elif c <= 200:
        return 'คาร์บกลาง'
    else:
        return 'คาร์บสูง'

df['ระดับแคลอรี่'] = df['total_calories'].apply(label_calorie)
df['ระดับโปรตีน'] = df['total_protein'].apply(label_protein)
df['ระดับไขมัน'] = df['total_fat'].apply(label_fat)
df['ระดับคาร์บ'] = df['total_carbs'].apply(label_carbs)

print(df[['ชื่ออาหาร','วัตถุดิบ', 'total_calories', 'ระดับแคลอรี่',
          'total_protein', 'ระดับโปรตีน',
          'total_fat', 'ระดับไขมัน',
          'total_carbs', 'ระดับคาร์บ']].head(10))

from google.colab import sheets
sheet = sheets.InteractiveSheet(df=df)
# Out:
#                                            ชื่ออาหาร  \
# 0                                     แกงเลียงกุ้งสด
# 1                                       ปลานึ่งมะนาว
# 2                                 มาม่าผัดขี้เมาทะเล
# 3                    แกงเขียวหวานหมู (มือใหม่หัดแกง)
# 4                                             แกงป่า
# 5              แกงส้มปลากระพงผักรวม (แกงส้มปักษ์ใต้)
# 6                                     ต้มยำกุ้งน้ำใส
# 7                                          แกงส้มใต้
# 8  ปลาเผาผักสด/เมี่ยงปลาเผา/ปลานิลเผาเกลือ แบบใช้...
# 9                              น้ำพริกกะปิสูตรคุณยาย
#
#                                             วัตถุดิบ  total_calories  \
# 0  กุ้งสดปอกเปลือกผ่าหลัง, 250กรัม\nข้าวโพดอ่อนหั...          3720.4
# 1  ปลา ตามชอบ ปลากะพง ปลาทับทิม ปลานิล ฯลฯ:, 1ตัว...          1142.8
# 2  กุ้ง เนื้อปลา ปลาหมึก: ไม่ต้องเยอะมากอะ กะเอาเ...          1604.9
# 3  เนื้อหมู:, 1 Kg\nพริกแกงเขียวหวาน:, 2 ขีด\nหัว...          2406.1
# ...
